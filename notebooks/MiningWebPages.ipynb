# %% [markdown]
# <a href="https://colab.research.google.com/github/leodenale/ColabExamples/blob/master/notebooks/MiningWebPages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mining the Social Web
#
# ## Mining Web Pages
#
# This Jupyter Notebook provides an interactive way to follow along with and explore the examples from the video series. The intent behind this notebook is to reinforce the concepts in a fun, convenient, and effective way.
#
# [Original Repository (github.com/mikhailklassen/):](https://github.com/mikhailklassen/Mining-the-Social-Web-3rd-Edition)
#
# ### Book: Mining the Social Web, 3rd Edition
# The official code repository for Mining the Social Web, 3rd Edition (O'Reilly, 2019). The book is available from Amazon and Safari Books Online.

# %% [markdown]
# ### Mounting Google Drive in Google Colab

# %%
from google.colab import drive
drive.mount('/mydrive')

# %% [markdown]
# ### Navigating to project directory

# %%
cd ..
# Out:
# /

# %%
ls
# Out:
# bin/      dev/   lib32/  mydrive/  run/    sys/                 usr/
# boot/     etc/   lib64/  opt/      sbin/   tensorflow-2.0.0b1/  var/
# content/  home/  media/  proc/     srv/    tmp/
# datalab/  lib/   mnt/    root/     swift/  tools/

# %%
cd mydrive/My Drive/Colab Notebooks/data
# Out:
# /mydrive/My Drive/Colab Notebooks/data

# %%
ls
# Out:
# feed.json  speech1.wav  speech2.wav

# %% [markdown]
# ## Using boilerpipe to extract the text from a web page
#
# Example blog post:
# http://radar.oreilly.com/2010/07/louvre-industrial-age-henry-ford.html

# %%
import matplotlib
matplotlib.use('Agg')

# %%
# May also require the installation of Java runtime libraries
# !pip3 install boilerpipe3
from boilerpipe.extract import Extractor

# If you're interested, learn more about how Boilerpipe works by reading
# Christian Kohlschütter's paper: http://www.l3s.de/~kohlschuetter/boilerplate/

URL='https://www.oreilly.com/ideas/ethics-in-data-project-design-its-about-planning'

extractor = Extractor(extractor='ArticleExtractor', url=URL)

print(extractor.getText())
# Out:
# Collecting boilerpipe3
#   Downloading https://files.pythonhosted.org/packages/6f/53/13795e30c8b6335b4c21ef408a18bc3217380ef24fef05a4e9dc8252ea63/boilerpipe3-1.1.tar.gz (1.3MB)
#      |████████████████████████████████| 1.3MB 2.9MB/s
# Collecting JPype1-py3 (from boilerpipe3)
#   Downloading https://files.pythonhosted.org/packages/9b/81/63f5e4202c598f362ee4684b41890f993d6e58309c5d90703f570ab85f62/JPype1-py3-0.5.5.4.tar.gz (88kB)
#      |████████████████████████████████| 92kB 28.8MB/s
# Collecting charade (from boilerpipe3)
#   Downloading https://files.pythonhosted.org/packages/74/26/565610c87e951b8a3182df890589c280a16c5897cfbca97eebd73705e0c6/charade-1.0.3.tar.gz (168kB)
#      |████████████████████████████████| 174kB 44.5MB/s
# Building wheels for collected packages: boilerpipe3, JPype1-py3, charade
#   Building wheel for boilerpipe3 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/b9/fd/7e/8db2c536d1946876d32cc990bf9e9ea255c563ccf8a76dc25d
#   Building wheel for JPype1-py3 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/52/37/1f/1015d908d12a0e9b239543d031fda0cded9823aa1306939541
#   Building wheel for charade (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/17/e4/b6/f27d4d6c000855ea7180a28099cd8d758b1d5debce4fac2d65
# Successfully built boilerpipe3 JPype1-py3 charade
# Installing collected packages: JPype1-py3, charade, boilerpipe3
# Successfully installed JPype1-py3-0.5.5.4 boilerpipe3-1.1 charade-1.0.3
# Anna Lauren Hoffman will present an online training course, Data Ethics: Designing for Fairness in the Age of Algorithms , October 4-5, 2016. Register now for hands-on practice seeing the warning signs early in your design process.
# When I explain the value of ethics to students and professionals alike, I refer it as an “orientation.” As any good designer, scientist, or researcher knows, how you orient yourself toward a problem can have a big impact on the sort of solution you develop—and how you get there. As Ralph Waldo Emerson once wrote , “perception is not whimsical, but fatal.” Your particular perspective, knowledge of, and approach to a problem shapes your solution, opening up certain paths forward and forestalling others.
# Data-driven approaches to business help optimize measurable outcomes—but the early planning of a project needs to account for the ethical (and in many cases, the literal) landscape to avoid ethically treacherous territory. Several recent cases in the news illustrate this point and show the type of preparation that enables a way to move forward in both a data-driven and ethical fashion: Princeton Review’s ZIP-code-based pricing scheme, which turned out to unfairly target Asian-American families , and Amazon’s same-day-delivery areas , which neglect majority-Black neighborhoods.
# You can approach a new project using a road trip analogy. The destination is straightforward—profit, revenue, or another measurable KPI. But the path you take to get there will need to be determined. If my wife and I, for example, want to drive from our apartment in Oakland (Point A) to visit my wife’s sister in Los Angeles (Point B), we have to figure out how we’d like to approach the trip. If we’re concerned primarily with efficiency, certain questions immediately come to the fore, namely: what’s the fastest route to LA? Determining the fastest route requires us to pay attention to certain features of the possible trip, such as traffic speeds, easily accessible gas stations, and traffic conditions.
# On the other hand, if my wife and I are interested in taking the most scenic route from Oakland to LA, a whole different set of concerns become salient. Gas stations are likely still relevant, but speed is less of a factor. We’ll also want to take into account things like notable landmarks and towns (and my tendency toward car sickness) along the way.
# The destination is the same; the laws we have to abide by are the same, but how we get from Point A to Point B, then, is heavily determined by how we orient ourselves toward the trip in the first place.
# The same goes for research or design projects: how you orient yourself or your team toward solving certain problems or achieving certain goals will fundamentally shape the journey you take. If you’re interested in reaching a goal as quickly as possible—if your only concern is speed or turnaround time—a particular set of concerns are going to be salient. But if you’re interested in reaching a goal not only efficiently but ethically, then a different set of concerns will pop up.
# Moreover, understanding ethics as a way of orienting yourself toward a problem helps differentiate ethical behavior from mere legal compliance; just as the laws governing driving constrain my possible actions but don’t fully determine the contours of my road trip, nor do the laws or regulations governing data collection, storage, and use exhaust the possible decisions you and your team may face.
# My students lovingly refer to this as "Anna's red flags” approach—teaching folks to see and address red flags they’d otherwise miss along the way. Of course, orienting yourself toward your work with an eye to ethics is only a starting point. Simply intending to do ethical data science isn’t enough; once you’ve established an orientation, you need information and specialized training.
# In the case of The Princeton Review, it’s clear that the program designers had a suspicion that they could charge higher prices to customers in wealthier areas. Similarly, the city maps showing Amazon’s same-day delivery areas are immediately recognizable to residents of those cities as showing where people of color live. An awareness of the distribution of wealth and race in the U.S. would have set off alarm bells in either case—but this requires asking at the beginning of a research query “Are we about to build a proxy for race and class with this model?”
# To return to the road trip analogy, since both my wife and I are Midwestern transplants, we don’t have a deep background and knowledge of California to help guide our journey. Instead, we have to ask for help from folks with more extensive expertise in the space between the Bay Area and Southern California.
# Similarly, you may have some ideas about data ethics already. You and your team may have even discussed the topic, but you likely don’t have deep knowledge in applied ethics of data or technology, it’s not enough to rely only on your own (necessarily limited) perspective to guide you. Instead, you need to be proactive in reaching out to consult experts in the field, taking advantage of training opportunities when available, and diversifying the range of voices informing your work.
# Article image: Lickskillet Road, unincorporated Boulder County. (source: Image copyright: Tim McGovern; used with permission. ).
# Share
# Anna Lauren Hoffmann
# Anna Lauren Hoffmann is a trans woman and scholar working at the intersections of data, technology, culture, and ethics. She is currently a postdoctoral scholar with the School of Information at the University of California, Berkeley. She teaches both academic and practicing data scientists how to detect and predict the effects of their work, and to ensure that the ways we design, use, and speak about technology promotes the pursuit of important human values like respect and justice.

# %% [markdown]
# ## Using feedparser to extract the text (and other fields) from an RSS or Atom feed

# %%
# !pip3 install feedparser
import feedparser # pip install feedparser

FEED_URL='http://feeds.feedburner.com/oreilly/radar/atom'

fp = feedparser.parse(FEED_URL)

for e in fp.entries:
    print(e.title)
    print(e.links[0].href)
    print(e.content[0].value)
# Out:
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
#      |████████████████████████████████| 194kB 2.9MB/s
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# Installing collected packages: feedparser
# Successfully installed feedparser-5.2.1
# Four short links: 4 July 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/_waxd6utHmY/four-short-links-4-july-2019
# <p><em>Debugging AI, Serverless Foundations, YouTube Bans, and Pathological UI</em></p><ol>
# <li>
# <a href="https://github.com/microsoft/tensorwatch">TensorWatch</a> -- open source Microsoft, <i>a debugging and visualization tool designed for data science, deep learning, and reinforcement learning</i>.</li>
# <li>
# <a href="https://arxiv.org/abs/1902.05870">Formal Foundations of Serverless Computing</a> -- <i>the serverless computing abstraction exposes several low-level operational details that make it hard for programmers to write and reason about their code. This paper sheds light on this problem.</i>
# </li>
# <li>
# <a href="https://twitter.com/KodyKinzie/status/1146196570083192832">YouTube Bans Videos Showing Hacking and Phishing</a> (Kody) -- <i>We made a video about launching fireworks over Wi-Fi for the 4th of July only to find out @YouTube gave us a strike because we teach about hacking, so we can't upload it. YouTube now bans: "Instructional hacking and phishing: Showing users how to bypass secure computer systems."</i>
# </li>
# <li>
# <a href="https://userinyerface.com/">User Inyerface</a> -- <i>an exercise in frustration</i>.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-4-july-2019'>Four short links: 4 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/_waxd6utHmY" height="1" width="1" alt=""/>
# Tools for machine learning development
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/PMZgT-wOiYA/tools-for-machine-learning-development
# <p><img src='https://d3ucjech6zwjp8.cloudfront.net/600x450/abstract-texture-floor-cobblestone-wall-pattern-947466-pxhere_crop-e944da930f05b8e09fd1a07fcf8a64e1.jpg'/></p><p><em>The O'Reilly Data Show: Ben Lorica chats with Jeff Meyerson of Software Engineering Daily about data engineering, data architecture and infrastructure, and machine learning.</em></p><p>In this week's episode of the Data Show, we're featuring <a href="https://softwareengineeringdaily.com/2019/04/04/data-with-ben-lorica/">an interview Data Show host Ben Lorica participated in for the Software Engineering Daily Podcast</a>, where he was interviewed by <a href="https://twitter.com/the_prion">Jeff Meyerson</a>. Their conversation mainly centered around data engineering, data architecture and infrastructure, and machine learning (ML).</p><p>Continue reading <a href='https://www.oreilly.com/ideas/tools-for-machine-learning-development'>Tools for machine learning development.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4
p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/developing-dapps-with-ethereum/0636920302131/">Developing DApps with Ethereum</a></em>, September 9</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/building-a-deployment-pipeline-with-jenkins-2/0636920281177/">Building a Deployment Pipeline with Jenkins 2</a></em>, September 9-10</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/building-data-apis-with-graphql/0636920284710/">Building Data APIs with GraphQL</a></em>, September 11</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/creating-react-applications-with-graphql/0636920295723/">Creating React Applications with GraphQL </a></em>, September 12</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/jenkins-2-up-and-running/0636920281245/">Jenkins 2: Up and Running</a></em>, September 12</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/microservices-caching-strategies/0636920276326/">Microservices Caching Strategies</a></em>, September 12</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/chaos-engineering-planning-designing-and-running-automated-chaos-experiments/0636920278832/">Chaos Engineering: Planning, Designing, and Running Automated Chaos Experiments</a></em>, September 12</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/google-cloud-platform-security-fundamentals/0636920299790/">Google Cloud Platform Security Fundamentals</a></em>, September 12</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/understanding-aws-cloud-compute-options/0636920263807/">Understanding AWS Cloud Compute Option</a></em>, September 12-13</p>
# <p><em><a href="https://learning.oreilly.com/live-training/courses/google-cloud-certified-associate-cloud-engineer-crash-course/0636920300120/">Google Cloud Certified Associate Cloud Engineer Crash Course</a></em>, September 12-13</p>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/new-live-online-training-courses'>New live online training courses.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Q8JFXuBynxs" height="1" width="1" alt=""/>
# Four short links: 3 July 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/qV3ukU-4AGI/four-short-links-3-july-2019
# <p><em>Models, More Models, Robots.txt, and Event Sourcing</em></p><ol>
# <li>
# <a href="https://twitter.com/tomstafford/status/1143260282426417153">On Models</a> (Tom Stafford) -- a Twitter thread where he lays out his work in models and the value of them.</li>
# <li>
# <a href="http://jasss.soc.surrey.ac.uk/11/4/12.html">Why Model?</a> -- <i>The [article] distinguishes between explanation and prediction as modeling goals, and offers 16 reasons other than prediction to build a model. It also challenges the common assumption that scientific theories arise from and 'summarize' data, when often, theories precede and guide data collection; without theory, in other words, it is not clear what data to collect. Among other things, it also argues that the modeling enterprise enforces habits of mind essential to freedom.</i>
# </li>
# <li>
# <a href="https://github.com/google/robotstxt">Robots.txt</a> -- <i>Google's robots.txt parser and matcher as a C++ library (compliant to C++11).</i> Released as part of <a href="https://webmasters.googleblog.com/2019/07/rep-id.html">standardization work</a>.</li>
# <li>
# <a href="http://natpryce.com/articles/000819.html">Mistakes We Made Adopting Event Sourcing (And How We Recovered)</a> -- a useful post for those also considering their first system built around events as the mechanism for changing state.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-3-july-2019'>Four short links: 3 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/qV3ukU-4AGI" height="1" width="1" alt=""/>
# Four short links: 2 July 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Nq9HhgkapHs/four-short-links-2-july-2019
# <p><em>Lock Convoys, AI Hardware, Lambda Observability, and AI for Science</em></p><ol>
# <li>
# <a href="https://blog.acolyer.org/2019/07/01/the-convoy-phenomenon/">The Convoy Phenomenon</a> (Adrian Colyer) -- locks on resources that lead to performance degradation which never recovers, a situation first described in 1979.</li>
# <li>
# <a href="https://www.zdnet.com/article/ai-is-changing-the-entire-nature-of-compute/">AI is Changing the Entire Nature of Compute</a> (ZD) -- workloads have been doubling every 3.5 months, while our post-Moore's law chip speed increases have been 3.5% per year. <i>What that means, both authors believe, is that the design of chips, their architecture, as it's known, has to change drastically in order to get more performance out of transistors that are not of themselves producing performance benefits.</i> The article explores some of those directions.</li>
# <li>
# <a href="https://medium.com/@lukedemi/the-annoying-state-of-lambda-observability-465470403846">The Annoying State of Lambda Observability</a> -- <i>In the current state of the world, the available strategies boil down to either: (1) Send telemetry directly to external observability tools during Lambda execution. (2) Scrape or trigger off the telemetry sent to CloudWatch and X-Ray to populate external providers. Spoiler: neither option is ideal.</i>
# </li>
# <li>
# <a href="https://cra.org/ccc/wp-content/uploads/sites/2/2016/02/Accelerating-Science-Whitepaper-CCC-Final2.pdf">Accelerating Science: A Computing Research Agenda</a> -- I found this quite challenging at first because it seemed to be "cheating" somehow. But once I viewed it as the computer augmenting the human, not replacing them, then it was more acceptable. But I can imagine that better tools for each step of the scientific journey (e.g., <i>Expressing,	reasoning with,	updating	scientific	arguments	(along	with	supporting assumptions, facts,	observations),	including	languages	and	inference	techniques	for	managing	multiple,	often conflicting arguments,	assessing	the	plausibility	of	arguments,	their	uncertainty	and	provenance</i>) will create controversy no less than the software "proof" of the four-color theorem did.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-2-july-2019'>Four short links: 2 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Nq9HhgkapHs" height="1" width="1" alt=""/>
# Four short links: 1 July 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4jNEQq-ZE4o/four-short-links-1-july-2019
# <p><em>General-Purpose Probabilistic Programming, Microsoft's Linux, Decolonizing Data, Testing Statistical Softwares</em></p><ol>
# <li>
# <a href="https://github.com/probcomp/Gen">Gen</a> -- <i>general-purpose probabilistic programming system with programmable inference</i>. Julia package <a href="https://probcomp.github.io/Gen/">described</a> as <i>Gen's flexible modeling and inference programming capabilities unify symbolic, neural, probabilistic, and simulation-based approaches to modeling and inference, including causal modeling, symbolic programming, deep learning, hierarchical Bayesian modeling, graphics and physics engines, and planning and reinforcement learning.</i>.</li>
# <li>
# <a href="https://github.com/microsoft/WSL2-Linux-Kernel">WSL2 Linux Kernel</a> -- <i>source for the Linux kernel used in Windows Subsystem for Linux 2 (WSL2)</i>.</li>
# <li>
# <a href="https://crosscut.com/2019/05/abigail-echo-hawk-art-and-science-decolonizing-data">Decolonizing Data</a> -- <i>Decolonizing data means that the community itself is the one determining the information they want us to gather. Why are we gathering it? Who's interpreting it? And are we interpreting it in a way that truly serves our communities? Decolonizing data is about controlling our own story and making decisions based on what is best for our people. That hasn't been done in data before, and that's what's shifting and changing.</i>
# </li>
# <li>
# <a href="https://www.alexpghayes.com/blog/testing-statistical-software/">Testing Statistical Software</a> -- <i>In this post, I describe how I evaluate the trustworthiness of a modeling package, and in particular what I want from the test suite. If you use statistical software, this post will help you evaluate whether a package is worth using. If you write statistical software, this post will help you confirm the correctness of the code that you write.</i>
# </li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-1-july-2019'>Four short links: 1 July 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4jNEQq-ZE4o" height="1" width="1" alt=""/>
# RISELab’s AutoPandas hints at automation tech that will change the nature of software development
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/5zO30jAXZME/riselabs-autopandas-hints-at-automation-tech-that-will-change-the-nature-of-software-development
# <p><img src='https://d3ucjech6zwjp8.cloudfront.net/600x450/drum_of_a_washing_machine_crop-6f4d097fc5199bef6313bcbd616fd6ba.jpg'/></p><p><em>Neural-backed generators are a promising step toward practical program synthesis.</em></p><p>There's a lot of hype surrounding AI, but are companies actually beginning to use AI technologies? In <a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">a survey</a> we released earlier this year, we found that more than 60% of respondents worked in organizations that planned to invest some of their IT budgets into AI. <a href="https://www.oreilly.com/ideas/ai-adoption-is-being-fueled-by-an-improved-tool-ecosystem">We also found</a> that the level of investment depended on how much experience a company already had with AI technologies, with companies further along the maturity curve planning substantially higher investments. As far as current levels of adoption, the answer depended on the industry sector. We found that in several industries, 30% or more of respondents described their organizations as having a mature AI practice:</p>
#
# <figure class="center" id="id-31Vik"><img alt="Stage of adoption of AI technologies" src="https://d3ansictanv2wj.cloudfront.net/Figure1-2ac6f48acbec09780f5afd507a463571.png"><figcaption><span class="label">Figure 1. </span><a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">Stage of adoption of AI technologies</a> (by industry). Image by Ben Lorica.</figcaption></figure>
#
# <p>In which areas or domains are AI technologies being applied? As with any new technology, AI is used for a lot of R&amp;D-related activity. But we are also beginning to see AI and machine learning gain traction in areas like customer service and IT. In <a href="https://www.oreilly.com/ideas/how-ai-and-machine-learning-are-improving-customer-experience">a recent post</a>, we outlined the many areas pertaining to customer experience, where AI-related technologies are beginning to make an impact. This includes things like data quality, personalization, customer service, and many other factors that impact customer experience.</p>
#
#
#
# <figure class="center" id="id-5vyir"><img alt="Areas where AI is being applied" src="https://d3ansictanv2wj.cloudfront.net/Figure2-a799ba5208627f24a4938c0abfcc526a.png"><figcaption><span class="label">Figure 2. </span><a href="https://www.oreilly.com/data/free/ai-adoption-in-the-enterprise.csp">Areas where AI is being applied</a> (by stage of adoption). Image by Ben Lorica.</figcaption></figure>
#
#
#
# <p>One area I’m particularly interested in is the application of AI and automation technologies in data science, data engineering, and software development. <a href="https://www.oreilly.com/ideas/what-machine-learning-means-for-software-development">We’ve sketched some initial manifestations</a> of “human in the loop” technologies in software development, where initial applications of machine learning are beginning to change how people build and manage software systems. Automation has also emerged as one of the hottest topics in data science and machine learning (<a href="https://en.wikipedia.org/wiki/Automated_machine_learning">AutoML</a>), and teams of researchers and practitioners are actively building tools that can <a href="https://www.oreilly.com/ideas/deep-automation-in-machine-learning">automate every stage of a machine learning pipeline</a>.</p>
#
#
#
# <p>For a typical data scientist, data engineer, or developer, there is an explosion of tools and APIs they now need to work with and “master.” A data scientist might need to know Python, pandas, numpy, scikit-learn, one or more deep learning frameworks, Apache Spark, and more. <a href="https://www.dev-diaries.com/blog/im-just-good-at-googling-things/">According to a recent blog post by Khaliq Gant</a>, a web developer is typically expected to demonstrate competence in things like "navigating the terminal, HTML, CSS, JavaScript, cloud infrastructure, deployment strategies, databases, HTTP protocols, and that’s just the beginning." Data engineers additionally need to master several pieces of infrastructure.</p>
#
# <p>How do data scientists, data engineers, and developers cope with this explosion of tools and APIs? They typically use <em>search</em> (Google) or post in <em>forums</em> (Stack Overflow, Slack, mailing lists). In both instances, it takes some baseline knowledge to both frame a question and to be able to discern which answer is the "best one" to choose. In the case of forums, there might be a significant delay before one obtains an adequate response. Those with more resources and more time to spare can avail of free or paid learning resources such as books, videos, or training courses.</p>
#
#
#
# <p>There are emerging automation tools that can drastically increase the efficiency and productivity of software developers. At his recent <a href="https://ai.oreilly.com.cn/ai-cn/public/schedule/detail/76617?locale=en">keynote</a> at the <a href="https://ai.oreilly.com.cn/ai-cn?locale=en">Artificial Intelligence conference in Beijing</a>, professor Ion Stoica, director of <a href="https://rise.cs.berkeley.edu/">UC Berkeley’s RISELab</a>, unveiled a new research project that hints at a path forward for software developers. Their initial output is <a href="http://AutoPandas.io">AutoPandas</a>, a <a href="https://www.microsoft.com/en-us/research/wp-content/uploads/2017/10/program_synthesis_now.pdf">program synthesis</a> engine for <a href="https://pandas.pydata.org/">Pandas</a>, one of the most widely used data science libraries today. <a href="https://www.microsoft.com/en-us/research/wp-content/uploads/2017/10/program_synthesis_now.pdf">As described in a paper from Microsoft and the University of Washington</a>, program synthesis is a longstanding research area in computer science:</p>
#
#
#
# <blockquote><p>Program synthesis is the task of automatically finding a program in the underlying programming language that satisfies the user intent expressed in the form of some specification. Since the inception of AI in the 1950s, this problem has been considered the holy grail of computer science.</p></blockquote>
#
#
#
# <p>An AutoPandas user simply specifies an input and output data structure (i.e., dataframes), and AutoPandas automatically synthesizes an optimal program that produces the desired output from the given input. AutoPandas relies on "program generators" that capture the API constraints to reduce the search space (the space of possible programs is immense), neural network models to predict the arguments of the API calls, and the distributed computing framework <a href="https://github.com/ray-project/ray">Ray</a> to scale up the search.</p>
#
# <figure class="center" id="id-RBQi8"><img alt="An AutoPandas user specifies an input and output data structure, and neural-backed generators output an optimal program" src="https://d3ansictanv2wj.cloudfront.net/Figure3-1904491123bb816831a7e8a737627c0c.png"><figcaption><span class="label">Figure 3. </span>An AutoPandas user specifies an input and output data structure, and neural-backed generators output an optimal program. Image by Ben Lorica.</figcaption></figure>
#
#
# <p>While we are still very much in the early days, neural-backed generators are an extremely promising step toward practical program synthesis. Note that while researchers at RISELab have initially focused on pandas, the techniques and tools behind AutoPandas can be applied to other APIs (e.g., numpy, TensorFlow, etc.). So, any number of popular tools used by developers, data scientists, or data engineers can benefit from some level of automation via program synthesis.</p>
#
#
#
# ...
#
# <h2>Bad setups and their remedies</h2>
#
# <p>Each type of alert serves a purpose, but as with any powerful tool, there is a risk of misusing them. Below are some common anti-patterns and their remedies using a maturity hierarchy-based approach.</p>
#
# <h3>Only investigative alerts</h3>
#
# <p>In this scenario, investigative alerts account for most or all of the primary service alerting. This anti-pattern has led to much of the polarized language characterizing cause-based alerting as bad. As shown in Figure 2, these alerts aren't supported by a foundation of reactive and proactive alerts.</p>
#
# <figure class="center" id="id-q4iAV"><img alt="investigative alerts" src="https://d3ansictanv2wj.cloudfront.net/Figure2-d9a63c0fd3e5fed89275f98b6aa0c01c.png"><figcaption><span class="label">Figure 2. </span>Only investigative alerts. Source: Google.</figcaption></figure>
#
#
#
#
#
# <p><strong>Symptoms:</strong></p>
#
# <ul>
# 	<li>Your service does not have SLOs/SLIs, or you do not have alerting on SLOs/SLIs.</li>
# 	<li>Even if your service has SLOs/SLIs, the majority of incidents are discovered by alerts that are <em>not</em> SLO-based.</li>
# 	<li>The majority of the alerts considered “investigative” are given a paging priority, rather than a priority indicating the investigation can wait until the next business hour.</li>
# </ul>
#
#
#
# <p><strong>Remedy:</strong></p>
#
# <p>Establish SLOs and SLIs that reflect your business goals. Alert on these SLOs/SLIs. These reactive alerts will form the base of your pyramid.</p>
#
# <h3>Total set of alerts incurs too much toil</h3>
#
# <p>In this situation, there may be a reasonable mix of alerts, but their combined volume causes operators to regularly disregard or fail to prioritize them.</p>
#
#
#
# <p><strong>Symptoms:</strong></p>
#
# <ul>
# 	<li>You receive too many paging alerts: your setup either has too many alerts, or a small pool of alerts that fire too often.</li>
# 	<li>You receive too many non-paging alerts (for example, tickets), and frequently disregard them, declare “ticket bankruptcy” (close out a large chunk of tickets in order to start over from a clean slate), or otherwise allow them to fall into disrepair.</li>
# </ul>
#
#
#
# <p><strong>Remedy:</strong></p>
#
# <p>As shown in Figure 3, climb down the pyramid of alerting maturity by disabling alerts at higher levels of the hierarchy. Move toward the base as far as necessary to reach a manageable state. By mapping your alerts to the hierarchy, you will implicitly drop the less important alerts first.</p>
#
# <figure class="center" id="id-Mkibq"><img alt="Climb down the pyramid of alerting maturity" src="https://d3ansictanv2wj.cloudfront.net/Figure3-a4fcbe032e90a68aecf454562611f304.png"><figcaption><span class="label">Figure 3. </span>Climb down the pyramid of alerting maturity. Source: Google.</figcaption></figure>
#
# <p><strong><em>Figure 3: </em></strong><em>Climb down the pyramid of alerting maturity</em></p>
#
#
#
# <p>Inactionable alerts have a cost: if too many conditions trigger alerts, it becomes increasingly difficult to prioritize the most important alerts in a sea of noise. This results in worse uptime and more toil and burnout, harming both short- and long-term system reliability. You’ll want to climb up the pyramid again as you gain more control over the system, but only after you have reached and <em>sustained</em> a reasonable level of alerting—for example, for a month or longer.</p>
#
# <h3>SLO/SLI alerting is insufficient to discover common outages</h3>
#
# <p>Although you've set up SLO-based alerting, you're often notified of outages that threaten business goals by some other alerting—proactive alerts, investigative alerts, or even just user escalations.</p>
#
#
#
# <p><strong>Symptom:</strong></p>
#
# <p>More than one or two of your past 10 postmortems resulted from issues not captured in SLO alerts.</p>
#
#
#
# <p><strong>Remedy:</strong></p>
#
# <p>Resist the urge to craft more investigative and/or proactive alerts—your problem lies in the bottom layer of your alerting hierarchy, not the upper layers.</p>
#
#
#
# <p>Instead, figure out why you experienced an outage that's not covered by your SLIs. Either:</p>
#
# <ul>
# 	<li>You need to augment your SLIs to better cover the business aspects of your service, or</li>
# 	<li>Your definition of an outage is overly sensitive and needs to be reexamined</li>
# </ul>
#
# <h2>Cause-based alerts aren’t wrong!</h2>
#
# <p>...they're just misunderstood. As described in the first anti-pattern above, cause-based alerts are problematic if they're the only type of alerting you use. When used in conjunction with other types of alerts, cause-based notifications can provide a deeper understanding of the system and improve its robustness. But your aggregated alerting must not lead to toil, and when it does, we recommend revisiting your alerting strategy.</p>
#
#
#
# <p>All too frequently, we treat alerting as a haunted graveyard: we shy away from removing an alert (because what if it catches something important?!) just as much we shy away from enabling a new alert (because what if it causes toil?!).</p>
#
#
#
# <p>Throughout SRE history, alerting setups have been built based mostly on opinion and conjecture, rather than by actually analyzing which setups best serve the end goal of running reliable services with minimal toil. An alerting hierarchy allows us to approach alerting as a path we can walk, describing what is good or bad <em>in a given situation</em> instead of in absolutes. With this framework, we can iterate and improve our alerting based on data, rather than sound bites.</p>
#
#
# <aside data-type="sidebar" id="id-nkSzD">
# <p><em>Share your alerting experiences with us on Twitter at <a href="https://twitter.com/googlesre">@googlesre</a>.</em></p>
# </aside>
#
# <p><em>This post is part of a collaboration between O’Reilly and Google. <a href="http://www.oreilly.com/about/editorial_independence.html">See our statement
# of editorial independence</a>.</em></p>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/reduce-toil-through-better-alerting'>Reduce toil through better alerting.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/FjYOOyExYhE" height="1" width="1" alt=""/>
# Four short links: 3 June 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/6eXEe5FRzEY/four-short-links-3-june-2019
# <p><em>Differential Privacy, Future Op-Ed, Spectroscopy, and Research Programming Environment</em></p><ol>
# <li>
# <a href="https://www.sciencemag.org/news/2019/01/can-set-equations-keep-us-census-data-private">Differential Privacy in the Census</a> (Science) -- <i>Differential privacy, first described in 2006, isn’t a substitute for swapping and other ways to perturb the data. Rather, it allows someone—in this case, the Census Bureau—to measure the likelihood that enough information will “leak” from a public data set to open the door to reconstruction. “Any time you release a statistic, you’re leaking something,” explains Jerry Reiter, a professor of statistics at Duke University in Durham, North Carolina, who has worked on differential privacy as a consultant with the Census Bureau. “The only way to absolutely ensure confidentiality is to release no data. So the question is, how much risk is OK? Differential privacy allows you to put a boundary” on that risk.</i>
# </li>
# <li>
# <a href="https://www.nytimes.com/2019/05/27/opinion/ted-chiang-future-genetic-engineering.html">It’s 2059, and the Rich Kids Are Still Winning</a> (NYT) -- Ted Chiang's "Op-Ed From the Future." (via <a href="https://entertainment.slashdot.org/story/19/06/02/0328236/nyt-op-eds-from-the-future-launch-with-sci-fi-writer-ted-chiang">Slashdot</a>)</li>
# <li>
# <a href="https://www.groundai.com/project/classification-of-household-materials-via-spectroscopy/">Classification of Household Materials via Spectroscopy</a> -- <i>we collected a data set of spectral measurements from two commercially available spectrometers during which a robotic platform interacted with 50 distinct objects, and we show that a residual neural network can accurately analyze these measurements. Due to the low variance in consecutive spectral measurements, our model achieved a material classification accuracy of 97.7% when given only one spectral sample per object.</i>
# </li>
# <li>
# <a href="https://github.com/Glench/Flowsheets-v2">Flowsheets</a> -- <i>A research prototype programming environment for making programs while seeing the data the program outputs.</i> See <a href="https://www.youtube.com/watch?v=y1Ca5czOY7Q">the demo video</a>.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-3-june-2019'>Four short links: 3 June 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/6eXEe5FRzEY" height="1" width="1" alt=""/>
# Four short links: 31 May 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dEWuyxsMu7g/four-short-links-31-may-2019
# <p><em>Google Blocking Ad Blocking, Security Checklist, Maturity Model, and Software Engineering</em></p><ol>
# <li>
# <a href="https://9to5google.com/2019/05/29/chrome-ad-blocking-enterprise-manifest-v3/">Google to Restrict Modern Ad Blocking Chrome Extensions to Enterprise Users</a> (9 to 5 Google) -- <i>modern ad blockers, like uBlock Origin and Ghostery, use Chrome’s webRequest API to block ads before they’re even downloaded. With the Manifest V3 proposal, Google deprecates the webRequest API’s ability to block a particular request before it’s loaded. As you would expect, power users and extension developers alike criticized Google’s proposal for limiting the user’s ability to browse the web as they see fit. [...] "Google’s primary business is incompatible with unimpeded content blocking. Now that Google Chrome product has achieve high market share, the content blocking concerns as stated in its 10K filing are being tackled."</i> See also <a href="https://www.mozilla.org/en-US/firefox/switch/">Switch to Firefox</a>.</li>
# <li>
# <a href="https://www.sqreen.com/checklists/saas-cto-security-checklist">SaaS CTO Security Checklist</a> -- useful security tips, arranged by stage of your startup.</li>
# <li>
# <a href="https://medium.com/digitalhks/part-2-proposing-a-maturity-model-for-digital-services-9b1d429699e7">Proposing a Maturity Model for Digital Services</a> (David Eaves) -- an interesting approach: describes the aspects of maturity (<i>political environment, institutional capacity, delivery capability, skills and hiring, user centered design, cross-government platforms</i>) and then has a rubric for the different aspects of each of them.</li>
# <li>
# <a href="https://medium.com/s/story/notes-to-myself-on-software-engineering-c890f16f4e4d">Notes to Myself on Sofware Engineering</a> (François Chollet) -- <i>Technology is never neutral. If your work has any impact on the world, then this impact has a moral direction. The seemingly innocuous technical choices we make in software products modulate the terms of access to technology, its usage incentives, who will benefit, and who will suffer. Technical choices are also ethical choices. Thus, always be deliberate and explicit about the values you want your choices to support. Design for ethics. Bake your values into your creations. Never think, I’m just building the capability; that in itself is neutral. It is not because the way you build it determines how it will get used.</i> The whole list is great, and resonates strongly with my experience.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-31-may-2019'>Four short links: 31 May 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/dEWuyxsMu7g" height="1" width="1" alt=""/>
# Four short links: 30 May 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fimgK1F1NZY/four-short-links-30-may-2019
# <p><em>Open Insulin, Sonification of Data, Security UX, and Advanced Data Structures</em></p><ol>
# <li>
# <a href="http://openinsulin.org/new/">Open Insulin</a> -- open biohacking group working on (and making progress toward) the open and cheap manufacturing of insulin.</li>
# <li>
# <a href="https://programminghistorian.org/en/lessons/sonification">The Sound of Data</a> -- <i>a gentle intro to sonification for historians</i>.</li>
# <li>
# <a href="https://www.uie.com/jared-live/#fix-ux-of-security">UX of Security</a> -- an interesting talk on the relationship between UX and security. I particularly liked: "the most expensive dialog box in the world costs an Australian bank $750,000,000/year for password resets." <a href="https://www.dropbox.com/s/75o0yqe6hfeqpt8/Security%20UX%20-%20R3.pdf?dl=0">Slides available</a>. (via <a href="https://twitter.com/jmspool/status/1133795312961769473">Jared Pool</a>)</li>
# <li>
# <a href="https://courses.csail.mit.edu/6.851/fall17/">Advanced Data Structures</a> -- MIT course.</li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-30-may-2019'>Four short links: 30 May 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/fimgK1F1NZY" height="1" width="1" alt=""/>
# Four short links: 29 May 2019
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/gQL0BfppwkM/four-short-links-29-may-2019
# <p><em>Robustness Principle, End of Mobile, Beautiful Hack, and Autonomous Radios</em></p><ol>
# <li>
# <a href="https://tools.ietf.org/html/draft-iab-protocol-maintenance-03">The Harmful Consequences of the Robustness Principle</a> (IETF) -- <i>Time and experience shows that negative consequences to interoperability accumulate over time if implementations apply the robustness principle. This problem originates from an assumption implicit in the principle that it is not possible to effect change in a system the size of the internet. That is, the idea that once a protocol specification is published, changes that might require existing implementations to change are not feasible.</i>
# </li>
# <li>
# <a href="https://www.ben-evans.com/benedictevans/2019/5/28/the-end-of-mobile">The End of Mobile</a> (Stratechery) -- deep dive into numbers on mobile adoption around the world. The end is the kicker, though: <i>I’m not updating my smartphone model anymore. The next fundamental trends in tech, today, are probably machine learning, crypto, and regulation.</i>
# </li>
# <li>
# <a href="https://github.com/jtolds/gls">GLS: Goroutine Local Storage</a> -- using the call stack to implement local storage for goroutines, against the language's intentions. A splendidly hacky hack. <i>What are people saying? "Wow, that's horrifying." "This is the most terrible thing I have seen in a very long time." "Where is it getting a context from? Is this serializing all the requests? What the heck is the client being bound to? What are these tags? Why does he need callers? Oh god no. No no no."</i>
# </li>
# <li>
# <a href="https://spectrum.ieee.org/telecom/wireless/if-darpa-has-its-way-ai-will-rule-the-wireless-spectrum">If DARPA Has Its Way, AI Will Rule the Wireless Spectrum</a> (IEEE) -- <i>To tackle spectrum scarcity, I created the Spectrum Collaboration Challenge (SC2) at the U.S. Defense Advanced Research Projects Agency (DARPA), where I am a program manager. [...] Teams are designing new radios that use artificial intelligence (AI) to learn how to share spectrum with their competitors, with the ultimate goal of increasing overall data throughput. These teams are vying for nearly $4 million in prizes to be awarded at the SC2 championship this coming October in Los Angeles. Thanks to two years of competition, we have witnessed, for the first time, autonomous radios collectively sharing wireless spectrum to transmit far more data than would be possible by assigning exclusive frequencies to each radio.</i>
# </li>
# </ol>
# <p>Continue reading <a href='https://www.oreilly.com/ideas/four-short-links-29-may-2019'>Four short links: 29 May 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/gQL0BfppwkM" height="1" width="1" alt=""/>

# %% [markdown]
# ## Harvesting blog data by parsing feeds

# %%
import os
import sys
import json
import feedparser
from bs4 import BeautifulSoup
from nltk import clean_html

FEED_URL = 'http://feeds.feedburner.com/oreilly/radar/atom'

def cleanHtml(html):
    if html == "": return ""

    return BeautifulSoup(html, 'html5lib').get_text()

fp = feedparser.parse(FEED_URL)

print("Fetched {0} entries from '{1}'".format(len(fp.entries[0].title), fp.feed.title))

blog_posts = []
for e in fp.entries:
    blog_posts.append({'title': e.title, 'content'
                      : cleanHtml(e.content[0].value), 'link': e.links[0].href})

out_file = os.path.join('feed.json')
f = open(out_file, 'w+')
f.write(json.dumps(blog_posts, indent=1))
f.close()

print('Wrote output file to {0}'.format(f.name))
# Out:
# Fetched 29 entries from 'All - O'Reilly Media'
# Wrote output file to feed.json

# %% [markdown]
# ## Starting to write a web crawler

# %%
import httplib2
import re
from bs4 import BeautifulSoup

http = httplib2.Http()
status, response = http.request('http://www.nytimes.com')

soup = BeautifulSoup(response, 'html5lib')

links = []
 
for link in soup.findAll('a', attrs={'href': re.compile("^http(s?)://")}):
    links.append(link.get('href'))

for link in links:
    print(link)
# Out:
# https://www.nytimes.com/es/
# https://cn.nytimes.com
# https://www.nytimes.com/subscription/multiproduct/lp8HYKU.html?campaignId=6W74R
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi
# https://www.nytimes.com/section/todayspaper
# https://www.nytimes.com/section/world
# https://www.nytimes.com/section/us
# https://www.nytimes.com/section/politics
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/climate
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/obituaries
# https://www.nytimes.com/section/upshot
# https://www.nytimes.com/section/todayspaper
# https://www.nytimes.com/section/corrections
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/opinion/columnists
# https://www.nytimes.com/section/opinion/editorials
# https://www.nytimes.com/section/opinion/contributors
# https://www.nytimes.com/section/opinion/letters
# https://www.nytimes.com/section/opinion/sunday
# https://www.nytimes.com/video/opinion
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/arts/design
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section/arts/dance
# https://www.nytimes.com/section/movies
# https://www.nytimes.com/section/arts/music
# https://www.nytimes.com/spotlight/pop-culture
# https://www.nytimes.com/section/arts/television
# https://www.nytimes.com/section/theater
# https://www.nytimes.com/watching
# https://www.nytimes.com/video/arts
# https://www.nytimes.com/section/automobiles
# https://cooking.nytimes.com/
# https://www.nytimes.com/crosswords
# https://www.nytimes.com/section/education
# https://www.nytimes.com/section/food
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/jobs
# https://www.nytimes.com/section/magazine
# https://parenting.nytimes.com/
# https://www.nytimes.com/section/realestate
# https://www.nytimes.com/section/style
# https://www.nytimes.com/section/t-magazine
# https://www.nytimes.com/section/travel
# https://www.nytimes.com/section/style/love
# https://www.nytimes.com/section/reader-center
# https://thewirecutter.com
# http://nytconferences.com/
# https://www.nytimes.com/section/learning
# http://www.nytimes.com/marketing/tools-and-services
# https://www.nytimes.com/events
# https://www.nytimes.com/section/multimedia
# https://www.nytimes.com/section/lens
# https://www.nytimes.com/video
# https://www.nytimes.com/newsletters
# https://www.nytimes.com/store
# https://www.nytimes.com/times-journeys
# https://myaccount.nytimes.com/membercenter/myaccount.html
# https://www.nytimes.com/hdleftnav
# https://www.nytimes.com/digitalleftnav
# https://www.nytimes.com/subscription/games/lp897H9.html
# https://www.nytimes.com/subscriptions/Multiproduct/lp8R3WU.html
# https://www.nytimes.com/marketing/newsletters
# https://www.nytimes.com/corporateleftnav
# https://www.nytimes.com/educationleftnav
# https://www.nytimes.com/services/mobile/index.html
# http://eedition.nytimes.com/cgi-bin/signup.cgi?cc=37FYY
# https://www.nytimes.com/content/help/rights/copyright/copyright-notice.html
# https://myaccount.nytimes.com/membercenter/feedback.html
# http://www.nytco.com/careers
# http://nytmediakit.com/
# https://www.nytimes.com/content/help/rights/privacy/policy/privacy-policy.html#pp
# https://www.nytimes.com/privacy
# https://www.nytimes.com/ref/membercenter/help/agree.html
# https://www.nytimes.com/content/help/rights/sale/terms-of-sale.html
# http://spiderbites.nytimes.com
# https://mobile.nytimes.com/help
# https://www.nytimes.com/membercenter/sitehelp.html
# https://www.nytimes.com/subscription/multiproduct/lp8HYKU?campaignId=37WXW

# %% [markdown]
# ## Using NLTK to parse web page data

# %% [markdown]
# **Naive sentence detection based on periods**

# %%
text = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
print(text.split("."))
# Out:
# ['Mr', ' Green killed Colonel Mustard in the study with the candlestick', ' Mr', ' Green is not a very nice fellow', '']

# %% [markdown]
# **More sophisticated sentence detection**

# %%
import nltk # Installation instructions: http://www.nltk.org/install.html

# Downloading nltk packages used in this example
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentences = nltk.tokenize.sent_tokenize(text)
print(sentences)
# Out:
# ['Mr. Green killed Colonel Mustard in the study with the candlestick.', 'Mr. Green is not a very nice fellow.']

# %%
harder_example = """My name is John Smith and my email address is j.smith@company.com.
Mostly people call Mr. Smith. But I actually have a Ph.D.!
Can you believe it? Neither can most people..."""

sentences = nltk.tokenize.sent_tokenize(harder_example)
print(sentences)
# Out:
# ['My name is John Smith and my email address is j.smith@company.com.', 'Mostly people call Mr. Smith.', 'But I actually have a Ph.D.!', 'Can you believe it?', 'Neither can most people...']

# %% [markdown]
# **Word tokenization**

# %%
text = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
sentences = nltk.tokenize.sent_tokenize(text)

tokens = [nltk.word_tokenize(s) for s in sentences]
print(tokens)
# Out:
# [['Mr.', 'Green', 'killed', 'Colonel', 'Mustard', 'in', 'the', 'study', 'with', 'the', 'candlestick', '.'], ['Mr.', 'Green', 'is', 'not', 'a', 'very', 'nice', 'fellow', '.']]

# %% [markdown]
# **Part of speech tagging for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_treebank_pos_tagger')

pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]
print(pos_tagged_tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# [[('Mr.', 'NNP'), ('Green', 'NNP'), ('killed', 'VBD'), ('Colonel', 'NNP'), ('Mustard', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')], [('Mr.', 'NNP'), ('Green', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'NN'), ('.', '.')]]

# %% [markdown]
# **Alphabetical list of part-of-speech tags used in the Penn Treebank Project**
#
# See: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
#
# | # | POS Tag | Meaning |
# |:-:|:-------:|:--------|
# | 1	| CC | Coordinating conjunction|
# |2|	CD	|Cardinal number|
# |3|	DT	|Determiner|
# |4|	EX	|Existential there|
# |5|	FW	|Foreign word|
# |6|	IN	|Preposition or subordinating conjunction|
# |7|	JJ	|Adjective|
# |8|	JJR	|Adjective, comparative|
# |9|	JJS	|Adjective, superlative|
# |10|	LS	|List item marker|
# |11|	MD	|Modal|
# |12|	NN	|Noun, singular or mass|
# |13|	NNS	|Noun, plural|
# |14|	NNP	|Proper noun, singular|
# |15|	NNPS	|Proper noun, plural|
# |16|	PDT	|Predeterminer|
# |17|	POS	|Possessive ending|
# |18|	PRP	|Personal pronoun|
# |19|	PRP\$	|Possessive pronoun|
# |20|	RB	|Adverb|
# |21|	RBR	|Adverb, comparative|
# |22|	RBS	|Adverb, superlative|
# |23|	RP	|Particle|
# |24|	SYM	|Symbol|
# |25|	TO	|to|
# |26|	UH	|Interjection|
# |27|	VB	|Verb, base form|
# |28|	VBD	|Verb, past tense|
# |29|	VBG	|Verb, gerund or present participle|
# |30|	VBN	|Verb, past participle|
# |31|	VBP	|Verb, non-3rd person singular present|
# |32|	VBZ	|Verb, 3rd person singular present|
# |33|	WDT	|Wh-determiner|
# |34|	WP	|Wh-pronoun|
# |35|	WP\$|Possessive wh-pronoun|
# |36|	WRB	|Wh-adverb|

# %% [markdown]
# **Named entity extraction/chunking for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
jim = "Jim bought 300 shares of Acme Corp. in 2006."

tokens = nltk.word_tokenize(jim)
jim_tagged_tokens = nltk.pos_tag(tokens)

ne_chunks = nltk.chunk.ne_chunk(jim_tagged_tokens)

# %%
ne_chunks
# Out:
# [Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('PERSON', [('Green', 'NNP')]), ('killed', 'VBD'), Tree('ORGANIZATION', [('Colonel', 'NNP'), ('Mustard', 'NNP')]), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('ORGANIZATION', [('Green', 'NNP')]), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'NN'), ('.', '.')])]

# %%
ne_chunks = [nltk.chunk.ne_chunk(ptt) for ptt in pos_tagged_tokens]

ne_chunks[0].pprint()
ne_chunks[1].pprint()
# Out:
# (S
#   (PERSON Mr./NNP)
#   (PERSON Green/NNP)
#   killed/VBD
#   (ORGANIZATION Colonel/NNP Mustard/NNP)
#   in/IN
#   the/DT
#   study/NN
#   with/IN
#   the/DT
#   candlestick/NN
#   ./.)
# (S
#   (PERSON Mr./NNP)
#   (ORGANIZATION Green/NNP)
#   is/VBZ
#   not/RB
#   a/DT
#   very/RB
#   nice/JJ
#   fellow/NN
#   ./.)

# %%
ne_chunks[0]
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
#    1652         if parent is None:
# -> 1653             self._parent = Tk()
#    1654             self._parent.title('NLTK')
#    1655             self._parent.bind('<Control-p>', lambda e: self.print_to_file())
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
# Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('PERSON', [('Green', 'NNP')]), ('killed', 'VBD'), Tree('ORGANIZATION', [('Colonel', 'NNP'), ('Mustard', 'NNP')]), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')])

# %%
ne_chunks[1]
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
#    1652         if parent is None:
# -> 1653             self._parent = Tk()
#    1654             self._parent.title('NLTK')
#    1655             self._parent.bind('<Control-p>', lambda e: self.print_to_file())
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
# Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('ORGANIZATION', [('Green', 'NNP')]), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'NN'), ('.', '.')])

# %% [markdown]
# ## Using NLTK’s NLP tools to process human language in blog data

# %%
import json
import nltk

BLOG_DATA = "feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

# Download nltk packages used in this example
nltk.download('stopwords')

# Customize your list of stopwords as needed. Here, we add common
# punctuation and contraction artifacts.

stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    ']',
    '[',
    '...'
    ]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
for post in blog_data:
    sentences = nltk.tokenize.sent_tokenize(post['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Remove stopwords from fdist
    for sw in stop_words:
        del fdist[sw]
   
    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once
    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = fdist.most_common(10)

    print(post['title'])
    print('\tNum Sentences:'.ljust(25), len(sentences))
    print('\tNum Words:'.ljust(25), num_words)
    print('\tNum Unique Words:'.ljust(25), num_unique_words)
    print('\tNum Hapaxes:'.ljust(25), num_hapaxes)
    print('\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
          '\n\t\t'.join(['{0} ({1})'.format(w[0], w[1]) for w in top_10_words_sans_stop_words]))
    print()
# Out:
# Four short links: 21 August 2017
# 	Num Sentences:           10
# 	Num Words:               140
# 	Num Unique Words:        113
# 	Num Hapaxes:             93
# 	Top 10 Most Frequent Words (sans stop words):
# 		 signals (5)
# 		cloud (4)
# 		application (3)
# 		drone (3)
# 		operations (2)
# 		machine (2)
# 		learning (2)
# 		radio (2)
# 		flying (2)
# 		cameras (2)
#
# 6 practical guidelines for implementing conversational AI
# 	Num Sentences:           69
# 	Num Words:               908
# 	Num Unique Words:        528
# 	Num Hapaxes:             354
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (21)
# 		“ (21)
# 		” (21)
# 		conversational (15)
# 		bots (7)
# 		says (7)
# 		interaction (7)
# 		must (7)
# 		user (7)
# 		kai (7)
#
# Four short links: 18 August 2017
# 	Num Sentences:           16
# 	Num Words:               263
# 	Num Unique Words:        204
# 	Num Hapaxes:             173
# 	Top 10 Most Frequent Words (sans stop words):
# 		 hype (9)
# 		jobs (5)
# 		technologies (5)
# 		cycle (5)
# 		’ (5)
# 		bayesian (4)
# 		years (4)
# 		style (3)
# 		cycles (3)
# 		20 (3)
#
# How Ray makes continuous learning accessible and easy to scale
# 	Num Sentences:           5
# 	Num Words:               85
# 	Num Unique Words:        64
# 	Num Hapaxes:             47
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (5)
# 		data (3)
# 		show (2)
# 		robert (2)
# 		nishihara (2)
# 		philipp (2)
# 		moritz (2)
# 		framework (2)
# 		reinforcement (2)
# 		ai (2)
#
# Julie Stanford on vetting designs through rapid experimentation
# 	Num Sentences:           3
# 	Num Words:               48
# 	Num Unique Words:        35
# 	Num Hapaxes:             27
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (5)
# 		rapid (3)
# 		experimentation (3)
# 		’ (2)
# 		podcast (2)
# 		julie (2)
# 		stanford (2)
# 		get (2)
# 		reilly (1)
# 		quickly (1)
#
# Jack Daniel on building community and historical context in InfoSec
# 	Num Sentences:           2
# 	Num Words:               43
# 	Num Unique Words:        30
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		 community (4)
# 		security (3)
# 		podcast (2)
# 		bsides (2)
# 		infosec (2)
# 		jack (2)
# 		daniel (2)
# 		building (2)
# 		historical (2)
# 		context (2)
#
# Four short links: 17 August 2017
# 	Num Sentences:           11
# 	Num Words:               169
# 	Num Unique Words:        145
# 	Num Hapaxes:             129
# 	Top 10 Most Frequent Words (sans stop words):
# 		 via (4)
# 		interaction (4)
# 		us (3)
# 		mappy (3)
# 		system (3)
# 		rooms (3)
# 		eliminating (2)
# 		mapping (2)
# 		nes (2)
# 		world (2)
#
# Contouring learning rate to optimize neural nets
# 	Num Sentences:           115
# 	Num Words:               1371
# 	Num Unique Words:        674
# 	Num Hapaxes:             434
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (70)
# 		rate (45)
# 		’ (16)
# 		network (16)
# 		loss (15)
# 		decay (14)
# 		gradient (13)
# 		error (13)
# 		training (13)
# 		rates (11)
#
# Creating better disaster recovery plans
# 	Num Sentences:           73
# 	Num Words:               686
# 	Num Unique Words:        408
# 	Num Hapaxes:             283
# 	Top 10 Most Frequent Words (sans stop words):
# 		 n't (13)
# 		disaster (10)
# 		need (10)
# 		recovery (8)
# 		system (8)
# 		dependencies (8)
# 		systems (7)
# 		one (7)
# 		start (7)
# 		make (6)
#
# Announcing the Rebecca Bace Pioneer Award for Defensive Security
# 	Num Sentences:           34
# 	Num Words:               445
# 	Num Unique Words:        276
# 	Num Hapaxes:             206
# 	Top 10 Most Frequent Words (sans stop words):
# 		 becky (17)
# 		security (17)
# 		bace (10)
# 		’ (8)
# 		award (6)
# 		pioneer (6)
# 		detection (6)
# 		rebecca (5)
# 		community (5)
# 		reilly (4)
#
# How synthetic biology startups are building the future at RebelBio
# 	Num Sentences:           132
# 	Num Words:               1724
# 	Num Unique Words:        1012
# 	Num Hapaxes:             700
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (22)
# 		biology (18)
# 		new (18)
# 		“ (13)
# 		” (13)
# 		rebelbio (11)
# 		world (11)
# 		image (11)
# 		figure (10)
# 		team (10)
#
# The impact of design at Shopify
# 	Num Sentences:           87
# 	Num Words:               799
# 	Num Unique Words:        477
# 	Num Hapaxes:             341
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (26)
# 		design (16)
# 		designers (10)
# 		developers (10)
# 		work (9)
# 		process (8)
# 		use (8)
# 		learn (8)
# 		designer (7)
# 		shopify (6)
#
# Take the 2018 Data Science Salary Survey
# 	Num Sentences:           5
# 	Num Words:               43
# 	Num Unique Words:        35
# 	Num Hapaxes:             28
# 	Top 10 Most Frequent Words (sans stop words):
# 		 survey (3)
# 		data (2)
# 		responses (2)
# 		reported (2)
# 		aggregate (2)
# 		assure (2)
# 		anonymity (2)
# 		professional (1)
# 		invited (1)
# 		share (1)
#
# Four short links: 16 August 2017
# 	Num Sentences:           13
# 	Num Words:               155
# 	Num Unique Words:        119
# 	Num Hapaxes:             93
# 	Top 10 Most Frequent Words (sans stop words):
# 		 neural (4)
# 		networks (4)
# 		’ (4)
# 		virtual (3)
# 		network (3)
# 		natural (3)
# 		language (3)
# 		iot (2)
# 		using (2)
# 		logical (2)
#
# Four short links: 15 August 2017
# 	Num Sentences:           19
# 	Num Words:               206
# 	Num Unique Words:        144
# 	Num Hapaxes:             112
# 	Top 10 Most Frequent Words (sans stop words):
# 		 problems (6)
# 		solution (5)
# 		efficient (5)
# 		n't (5)
# 		p (4)
# 		np (4)
# 		problem (4)
# 		proven (4)
# 		`` (4)
# 		'' (4)
#
# How to use Presto Sketching to clarify your team’s purpose
# 	Num Sentences:           44
# 	Num Words:               545
# 	Num Unique Words:        283
# 	Num Hapaxes:             202
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (33)
# 		team (31)
# 		purpose (24)
# 		‘ (11)
# 		map (10)
# 		group (9)
# 		everyone (8)
# 		future (6)
# 		goals (6)
# 		see (5)
#
# Four short links: 14 August 2017
# 	Num Sentences:           9
# 	Num Words:               123
# 	Num Unique Words:        98
# 	Num Hapaxes:             81
# 	Top 10 Most Frequent Words (sans stop words):
# 		 failures (6)
# 		robotics (3)
# 		interviews (3)
# 		complex (3)
# 		systems (3)
# 		customer (2)
# 		development (2)
# 		engineering (2)
# 		method (2)
# 		“ (2)
#
# A multi-cloud strategy is the foundation for digital transformation
# 	Num Sentences:           32
# 	Num Words:               564
# 	Num Unique Words:        371
# 	Num Hapaxes:             290
# 	Top 10 Most Frequent Words (sans stop words):
# 		 digital (16)
# 		cloud (15)
# 		transformation (12)
# 		multi-cloud (12)
# 		data (10)
# 		companies (9)
# 		business (8)
# 		strategy (8)
# 		one (6)
# 		technology (6)
#
# How to choose a cloud provider
# 	Num Sentences:           60
# 	Num Words:               514
# 	Num Unique Words:        310
# 	Num Hapaxes:             225
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (19)
# 		cloud (18)
# 		use (13)
# 		providers (12)
# 		provider (11)
# 		case (7)
# 		make (6)
# 		level (6)
# 		managed (6)
# 		services (6)
#
# Four short links: 11 August 2017
# 	Num Sentences:           14
# 	Num Words:               200
# 	Num Unique Words:        160
# 	Num Hapaxes:             135
# 	Top 10 Most Frequent Words (sans stop words):
# 		 game (6)
# 		dna (5)
# 		simulation (4)
# 		> (4)
# 		wi-fi (3)
# 		security (3)
# 		computer (3)
# 		predictive (3)
# 		cracking (2)
# 		animation (2)
#
# Mike Roberts on serverless architectures
# 	Num Sentences:           3
# 	Num Words:               51
# 	Num Unique Words:        34
# 	Num Hapaxes:             23
# 	Top 10 Most Frequent Words (sans stop words):
# 		 serverless (4)
# 		’ (3)
# 		reilly (3)
# 		architecture (3)
# 		roberts (3)
# 		programming (2)
# 		podcast (2)
# 		next (2)
# 		cloud (2)
# 		mike (2)
#
# How to craft a voice user interface that won’t leave you frustrated
# 	Num Sentences:           1
# 	Num Words:               14
# 	Num Unique Words:        14
# 	Num Hapaxes:             14
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (1)
# 		principles (1)
# 		creating (1)
# 		truly (1)
# 		conversational (1)
# 		ui.continue (1)
# 		reading (1)
# 		craft (1)
# 		voice (1)
# 		user (1)
#
# Four short links: 10 August 2017
# 	Num Sentences:           8
# 	Num Words:               133
# 	Num Unique Words:        106
# 	Num Hapaxes:             84
# 	Top 10 Most Frequent Words (sans stop words):
# 		 salmon (5)
# 		sarcasm (3)
# 		% (3)
# 		gmo (2)
# 		new (2)
# 		deep (2)
# 		learning (2)
# 		courses (2)
# 		serverless (2)
# 		malware (2)
#
# Four short links: 9 August 2017
# 	Num Sentences:           10
# 	Num Words:               180
# 	Num Unique Words:        143
# 	Num Hapaxes:             119
# 	Top 10 Most Frequent Words (sans stop words):
# 		 event (7)
# 		’ (4)
# 		detection (3)
# 		autonomous (3)
# 		john (3)
# 		deere (3)
# 		tractor (3)
# 		still (3)
# 		trend (2)
# 		separation (2)
#
# Deep learning revolutionizes conversational AI
# 	Num Sentences:           120
# 	Num Words:               1290
# 	Num Unique Words:        581
# 	Num Hapaxes:             348
# 	Top 10 Most Frequent Words (sans stop words):
# 		 speech (54)
# 		recognition (41)
# 		machine (19)
# 		system (18)
# 		ai (17)
# 		learning (17)
# 		data (17)
# 		deep (16)
# 		language (11)
# 		techniques (10)
#
# Cancer detection, one slice at a time
# 	Num Sentences:           67
# 	Num Words:               764
# 	Num Unique Words:        479
# 	Num Hapaxes:             362
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ke (19)
# 		’ (19)
# 		data (15)
# 		slide (12)
# 		tissue (11)
# 		histowiz (11)
# 		cancer (10)
# 		slides (8)
# 		researchers (7)
# 		research (7)
#
# Integrating data with AI
# 	Num Sentences:           17
# 	Num Words:               310
# 	Num Unique Words:        208
# 	Num Hapaxes:             161
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (11)
# 		’ (10)
# 		knudsen (7)
# 		important (7)
# 		spam (5)
# 		“ (4)
# 		” (4)
# 		need (4)
# 		email (4)
# 		tamr (3)
#
# Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering
# 	Num Sentences:           45
# 	Num Words:               379
# 	Num Unique Words:        275
# 	Num Hapaxes:             219
# 	Top 10 Most Frequent Words (sans stop words):
# 		 jupyter (15)
# 		research (6)
# 		new (5)
# 		’ (5)
# 		reproducibility (4)
# 		use (4)
# 		tools (4)
# 		reproducible (4)
# 		education (3)
# 		barba (3)
#
# Four short links: 8 August 2017
# 	Num Sentences:           7
# 	Num Words:               69
# 	Num Unique Words:        58
# 	Num Hapaxes:             48
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ai (3)
# 		bloom (2)
# 		filter (2)
# 		future (2)
# 		adversarial (2)
# 		benchmarking (2)
# 		civilized (2)
# 		jeff (2)
# 		stand (2)
# 		anything (2)
#
# Why continuous learning is key to AI
# 	Num Sentences:           45
# 	Num Words:               605
# 	Num Unique Words:        355
# 	Num Hapaxes:             247
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (31)
# 		rl (12)
# 		continuous (10)
# 		’ (8)
# 		ai (8)
# 		algorithms (8)
# 		set (7)
# 		ray (7)
# 		machine (6)
# 		data (6)
#
# Four short links: 7 August 2017
# 	Num Sentences:           8
# 	Num Words:               157
# 	Num Unique Words:        125
# 	Num Hapaxes:             105
# 	Top 10 Most Frequent Words (sans stop words):
# 		 social (4)
# 		computational (4)
# 		zoom (4)
# 		ai (3)
# 		architecture (3)
# 		game (3)
# 		framework (3)
# 		several (3)
# 		technology (3)
# 		policy (2)
#
# How to move your team closer to clarity
# 	Num Sentences:           36
# 	Num Words:               364
# 	Num Unique Words:        265
# 	Num Hapaxes:             219
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (10)
# 		thinking (8)
# 		agile (8)
# 		lean (7)
# 		mindset (7)
# 		software (6)
# 		’ (6)
# 		development (3)
# 		learning (3)
# 		mindsets (3)
#
# Four short links: 4 August 2017
# 	Num Sentences:           6
# 	Num Words:               133
# 	Num Unique Words:        114
# 	Num Hapaxes:             98
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (5)
# 		history (2)
# 		intelligence (2)
# 		patreon (2)
# 		javascript (2)
# 		quackspeak (2)
# 		china (2)
# 		three (2)
# 		channel (2)
# 		people (2)
#
# JupyterHub on Google Cloud
# 	Num Sentences:           67
# 	Num Words:               1170
# 	Num Unique Words:        507
# 	Num Hapaxes:             321
# 	Top 10 Most Frequent Words (sans stop words):
# 		 # (74)
# 		jupyterhub (36)
# 		helm (18)
# 		name (17)
# 		> (15)
# 		install (14)
# 		cluster (14)
# 		gcloud (12)
# 		image (12)
# 		$ (11)
#
# Why AI and machine learning researchers are beginning to embrace PyTorch
# 	Num Sentences:           5
# 	Num Words:               93
# 	Num Unique Words:        71
# 	Num Hapaxes:             56
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (4)
# 		pytorch (4)
# 		chintala (3)
# 		deep (3)
# 		researchers (3)
# 		data (2)
# 		show (2)
# 		soumith (2)
# 		successor (2)
# 		torch (2)
#
# A DevOps approach to data management
# 	Num Sentences:           26
# 	Num Words:               358
# 	Num Unique Words:        232
# 	Num Hapaxes:             163
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (24)
# 		types (5)
# 		multi-model (4)
# 		variety (4)
# 		devops (4)
# 		needs (4)
# 		also (4)
# 		schemas (4)
# 		database (4)
# 		approach (3)
#
# Four short links: 3 August 2017
# 	Num Sentences:           12
# 	Num Words:               129
# 	Num Unique Words:        112
# 	Num Hapaxes:             99
# 	Top 10 Most Frequent Words (sans stop words):
# 		 price (4)
# 		poverty (3)
# 		study (3)
# 		unicorns (2)
# 		finding (2)
# 		’ (2)
# 		% (2)
# 		reading (2)
# 		early (2)
# 		customer (2)
#
# Declaring variables in Kotlin
# 	Num Sentences:           1
# 	Num Words:               12
# 	Num Unique Words:        11
# 	Num Hapaxes:             10
# 	Top 10 Most Frequent Words (sans stop words):
# 		 variables (2)
# 		learn (1)
# 		difference (1)
# 		mutable (1)
# 		immutable (1)
# 		cut (1)
# 		boilerplate (1)
# 		code.continue (1)
# 		reading (1)
# 		declaring (1)
#
# Building—and scaling—a reliable distributed architecture
# 	Num Sentences:           7
# 	Num Words:               95
# 	Num Unique Words:        71
# 	Num Hapaxes:             58
# 	Top 10 Most Frequent Words (sans stop words):
# 		 service (5)
# 		scale (5)
# 		joseph (3)
# 		robert (3)
# 		managing (3)
# 		dependencies (3)
# 		netflix (3)
# 		breuer (2)
# 		reta (2)
# 		implementing (2)
#
# Operationalizing security risk
# 	Num Sentences:           1
# 	Num Words:               10
# 	Num Unique Words:        9
# 	Num Hapaxes:             8
# 	Top 10 Most Frequent Words (sans stop words):
# 		 risk (2)
# 		bruce (1)
# 		potter (1)
# 		build (1)
# 		assessment (1)
# 		program.continue (1)
# 		reading (1)
# 		operationalizing (1)
# 		security (1)
#
# Reinforcement learning for complex goals, using TensorFlow
# 	Num Sentences:           112
# 	Num Words:               1372
# 	Num Unique Words:        595
# 	Num Hapaxes:             364
# 	Top 10 Most Frequent Words (sans stop words):
# 		 \ (45)
# 		agent (23)
# 		reward (23)
# 		battery (21)
# 		learning (18)
# 		environment (15)
# 		future (15)
# 		network (15)
# 		goal (13)
# 		state (13)
#
# Jay Jacobs on data analytics and security
# 	Num Sentences:           2
# 	Num Words:               58
# 	Num Unique Words:        33
# 	Num Hapaxes:             19
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (8)
# 		security (6)
# 		analytics (3)
# 		’ (2)
# 		reilly (2)
# 		podcast (2)
# 		convenient (2)
# 		first (2)
# 		steps (2)
# 		toward (2)
#
# Four short links: 2 August 2017
# 	Num Sentences:           11
# 	Num Words:               126
# 	Num Unique Words:        101
# 	Num Hapaxes:             82
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ; (4)
# 		app (3)
# 		make (3)
# 		threshold (3)
# 		research (3)
# 		headless (2)
# 		chrome (2)
# 		scientific (2)
# 		significance (2)
# 		sizes (2)
#
# The wisdom hierarchy: From signals to artificial intelligence and beyond
# 	Num Sentences:           73
# 	Num Words:               796
# 	Num Unique Words:        449
# 	Num Hapaxes:             319
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (37)
# 		wisdom (19)
# 		information (17)
# 		knowledge (17)
# 		’ (13)
# 		hierarchy (13)
# 		humans (11)
# 		ai (10)
# 		human (9)
# 		value (8)
#
# Four short links: 1 August 2017
# 	Num Sentences:           9
# 	Num Words:               142
# 	Num Unique Words:        120
# 	Num Hapaxes:             102
# 	Top 10 Most Frequent Words (sans stop words):
# 		 x86 (3)
# 		ai (3)
# 		bugs (3)
# 		; (3)
# 		rna (2)
# 		coding (2)
# 		1960s (2)
# 		based (2)
# 		make (2)
# 		decisions (2)
#
# How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks
# 	Num Sentences:           1
# 	Num Words:               21
# 	Num Unique Words:        18
# 	Num Hapaxes:             15
# 	Top 10 Most Frequent Words (sans stop words):
# 		 jupyter (2)
# 		notebooks (2)
# 		visualizations (2)
# 		learn (1)
# 		use (1)
# 		pixiedust (1)
# 		create (1)
# 		quick (1)
# 		easy (1)
# 		powerful (1)
#
# From prototype to product with hybrid neural networks
# 	Num Sentences:           33
# 	Num Words:               578
# 	Num Unique Words:        354
# 	Num Hapaxes:             262
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (16)
# 		deep (9)
# 		learning (9)
# 		neural (9)
# 		network (9)
# 		networks (8)
# 		declarative (7)
# 		frameworks (7)
# 		framework (7)
# 		“ (7)
#
# Four short links: 31 July 2017
# 	Num Sentences:           9
# 	Num Words:               175
# 	Num Unique Words:        140
# 	Num Hapaxes:             118
# 	Top 10 Most Frequent Words (sans stop words):
# 		 “ (5)
# 		” (5)
# 		sign (5)
# 		conditions (4)
# 		fiction (3)
# 		anonymous (3)
# 		statistics (2)
# 		machine (2)
# 		learning (2)
# 		digital (2)
#
# Four short links: 28 July 2017
# 	Num Sentences:           13
# 	Num Words:               129
# 	Num Unique Words:        107
# 	Num Hapaxes:             91
# 	Top 10 Most Frequent Words (sans stop words):
# 		 machine (4)
# 		security (3)
# 		a-ha (3)
# 		knitting (3)
# 		img2track (3)
# 		usable (2)
# 		philosophy (2)
# 		time (2)
# 		making (2)
# 		default (2)
#
# Eric Freeman and Elisabeth Robson on design patterns
# 	Num Sentences:           2
# 	Num Words:               54
# 	Num Unique Words:        41
# 	Num Hapaxes:             30
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (3)
# 		patterns (3)
# 		’ (2)
# 		reilly (2)
# 		programming (2)
# 		podcast (2)
# 		eric (2)
# 		freeman (2)
# 		elisabeth (2)
# 		robson (2)
#
# John Whalen on using brain science in design
# 	Num Sentences:           2
# 	Num Words:               71
# 	Num Unique Words:        56
# 	Num Hapaxes:             43
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (3)
# 		design (3)
# 		podcast (2)
# 		“ (2)
# 		six (2)
# 		minds (2)
# 		” (2)
# 		human (2)
# 		john (2)
# 		whalen (2)
#
# When you hear hooves, think horse, not zebra
# 	Num Sentences:           9
# 	Num Words:               123
# 	Num Unique Words:        109
# 	Num Hapaxes:             98
# 	Top 10 Most Frequent Words (sans stop words):
# 		 think (3)
# 		horse (3)
# 		patient (3)
# 		physician (2)
# 		zebras (2)
# 		diagnosis (2)
# 		one (2)
# 		hear (2)
# 		would (2)
# 		fevers (2)
#
# Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks
# 	Num Sentences:           93
# 	Num Words:               2106
# 	Num Unique Words:        834
# 	Num Hapaxes:             484
# 	Top 10 Most Frequent Words (sans stop words):
# 		 = (77)
# 		'' (67)
# 		# (37)
# 		image (35)
# 		data (29)
# 		set (21)
# 		32 (21)
# 		name= (20)
# 		network (19)
# 		neural (18)
#
# Four short links: 27 July 2017
# 	Num Sentences:           6
# 	Num Words:               87
# 	Num Unique Words:        77
# 	Num Hapaxes:             69
# 	Top 10 Most Frequent Words (sans stop words):
# 		 trust (3)
# 		embryos (3)
# 		next (2)
# 		evolution (2)
# 		indoor (2)
# 		robots (2)
# 		game (2)
# 		first (2)
# 		death (1)
# 		embryo (1)
#
# R’s tidytext turns messy text into valuable insight
# 	Num Sentences:           48
# 	Num Words:               705
# 	Num Unique Words:        373
# 	Num Hapaxes:             257
# 	Top 10 Most Frequent Words (sans stop words):
# 		 text (40)
# 		data (24)
# 		mining (19)
# 		r (12)
# 		words (11)
# 		“ (10)
# 		” (10)
# 		’ (10)
# 		sentiment (9)
# 		tidy (8)
#
# Four short links: 26 July 2017
# 	Num Sentences:           9
# 	Num Words:               145
# 	Num Unique Words:        125
# 	Num Hapaxes:             110
# 	Top 10 Most Frequent Words (sans stop words):
# 		 employees (4)
# 		securities (3)
# 		use (3)
# 		company (3)
# 		blockchain (2)
# 		robotics (2)
# 		deep (2)
# 		learning (2)
# 		report (2)
# 		capital (2)
#
# Making great hires in your design organization
# 	Num Sentences:           1
# 	Num Words:               13
# 	Num Unique Words:        12
# 	Num Hapaxes:             11
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (2)
# 		help (1)
# 		team (1)
# 		succeed (1)
# 		develop (1)
# 		stronger (1)
# 		practice.continue (1)
# 		reading (1)
# 		making (1)
# 		great (1)
#
# A lesson in prescriptive modeling
# 	Num Sentences:           1
# 	Num Words:               12
# 	Num Unique Words:        12
# 	Num Hapaxes:             12
# 	Top 10 Most Frequent Words (sans stop words):
# 		 simulate (1)
# 		new (1)
# 		business (1)
# 		models (1)
# 		practices (1)
# 		open (1)
# 		source (1)
# 		code.continue (1)
# 		reading (1)
# 		lesson (1)
#
# Four short links: 25 July 2017
# 	Num Sentences:           12
# 	Num Words:               131
# 	Num Unique Words:        112
# 	Num Hapaxes:             97
# 	Top 10 Most Frequent Words (sans stop words):
# 		 u2f (4)
# 		ai (3)
# 		soft (3)
# 		sentencing (2)
# 		encrypted (2)
# 		email (2)
# 		algorithm (2)
# 		ca (2)
# 		n't (2)
# 		whether (2)
#
# Data science startups focus on AI-enabled efficiency
# 	Num Sentences:           25
# 	Num Words:               308
# 	Num Unique Words:        244
# 	Num Hapaxes:             204
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (14)
# 		us (4)
# 		winner (4)
# 		winners (3)
# 		business (3)
# 		clouds (3)
# 		ai (3)
# 		gave (3)
# 		often (3)
# 		big (3)

# %% [markdown]
# ## A document summarization algorithm based principally upon sentence detection and frequency analysis within sentences

# %%
import json
import nltk
import numpy

BLOG_DATA = "feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# %%
stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    '>',
    '<',
    '...'
    ]

# %%
# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn
def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = 0

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence.
                word_idx.append(s.index(w))
            except ValueError: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all.
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words.

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence.

        max_cluster_score = 0
        
        for c in clusters:
            significant_words_in_cluster = len(c)
            # true clusters also contain insignificant words, so we get 
            # the total cluster length by checking the indices
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster**2 / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

        scores.append((sentence_idx, max_cluster_score))
        sentence_idx += 1

    return scores

# %%
def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)
    
    # Remove stopwords from fdist
    for sw in stop_words:
        del fdist[sw]

    top_n_words = [w[0] for w in fdist.most_common(N)]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summarization Approach 1:
    # Filter out nonsignificant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])

# %%
for post in blog_data: 
    post.update(summarize(post['content']))

    print(post['title'])
    print('=' * len(post['title']))
    print()
    print('Top N Summary')
    print('-------------')
    print(' '.join(post['top_n_summary']))
    print()
    print('Mean Scored Summary')
    print('-------------------')
    print(' '.join(post['mean_scored_summary']))
    print()
# Out:
# Four short links: 21 August 2017
# ================================
#
# Top N Summary
# -------------
# Cloud Operations, Machine Learning Radio, Flying Cameras, and Text Organization
#
# Paracloud: Bringing Application Insight into Cloud Operations -- In this work, we propose a uniform Paracloud interface (PaCI) to enable a bi-directional communication channel between application containers and the cloud management substrate. An application knows how it's doing, which it reports through this interface so the cloud management layer can figure how/when to migrate, scale, load balance. (via A Paper A Day)
#
# DARPA Wants Machine Learning for Radio Signals -- An RFMLS would be able to discern subtle differences in the RF signals among identical, mass-manufactured IoT devices and identify signals intended to spoof or hack into these devices. “We want to ... stand up an RF forensics capability to identify unique and peculiar signals amongst the proverbial cocktail party of signals out there,” Tilghman said. XPose: Reinventing User Interaction with Flying Cameras -- clever!
#
# Mean Scored Summary
# -------------------
# Cloud Operations, Machine Learning Radio, Flying Cameras, and Text Organization
#
# Paracloud: Bringing Application Insight into Cloud Operations -- In this work, we propose a uniform Paracloud interface (PaCI) to enable a bi-directional communication channel between application containers and the cloud management substrate. (via A Paper A Day)
#
# DARPA Wants Machine Learning for Radio Signals -- An RFMLS would be able to discern subtle differences in the RF signals among identical, mass-manufactured IoT devices and identify signals intended to spoof or hack into these devices. “We want to ... stand up an RF forensics capability to identify unique and peculiar signals amongst the proverbial cocktail party of signals out there,” Tilghman said.
#
# 6 practical guidelines for implementing conversational AI
# =========================================================
#
# Top N Summary
# -------------
# Conversational AI can come in the form of virtual personal (Alexa, Siri, Cortana, Google Home) or professional (such as X.ai or Skipflag) assistants. Organizations considering implementing conversational interfaces, whether for personal or professional uses, typically rely on partners for the technology stack, but there are plenty of considerations that span beyond the technical. While it’s too early in the game to call them “best practices,” here are some guidelines for organizations considering piloting and/or implementing conversational AI:
#
# 1. Sustained interactions require sustained contextual understanding
#
# There is a difference between giving a single command, such as “Play Beyoncé’s Lemonade,” or “Check my bank balance,” and engineering for a sustained interaction between a human and a chatbot. Screenshot by Susan Etlinger.
#
# Mean Scored Summary
# -------------------
# In 1966, MIT professor Joseph Weizenbaum introduced ELIZA—generally seen as the prototype for today’s conversational AI. Today, companies such as Slack, Starbucks, Mastercard, and Macy’s are piloting and using conversational interfaces for everything from customer service to controlling a connected home to, well, ordering flowers for mom. And if you doubt the value or longevity of this technology, consider that Gartner predicts that by 2019, virtual personal assistants “will have changed the way users interact with devices and become universally accepted as part of everyday life.”
#
# Not all conversational AI is created equal, nor should it be. Conversational AI can come in the form of virtual personal (Alexa, Siri, Cortana, Google Home) or professional (such as X.ai or Skipflag) assistants. They can be built on top of a rules engine or based on machine learning technology. Use cases range from the minute and specific (Taco Bell’s TacoBot) to the general and hypothetically infinite (Alexa, Siri, Cortana, Google Home). Organizations considering implementing conversational interfaces, whether for personal or professional uses, typically rely on partners for the technology stack, but there are plenty of considerations that span beyond the technical. While it’s too early in the game to call them “best practices,” here are some guidelines for organizations considering piloting and/or implementing conversational AI:
#
# 1. Figure 1 illustrates two successful interaction examples. “Many people still have a misperception of bots just as speaking or typing,” says Chris Mullins of Microsoft. Developers must design for multiple scenarios and experiences. To do the best job, project teams have to make choices at the beginning of the project. Sustained interactions require sustained contextual understanding
#
# There is a difference between giving a single command, such as “Play Beyoncé’s Lemonade,” or “Check my bank balance,” and engineering for a sustained interaction between a human and a chatbot. Screenshot by Susan Etlinger. At first glance, this looks like a fairly simple transaction, but from an engineering perspective, it requires quite a bit of language and contextual understanding:
#
#
# 	First, Kai must recognize and keep track of the user’s goal — she wants to pay someone. 6. A poorly executed bot can damage reputation, while a strong brand presence can support the success of the bot. But conversational AI—the ability for machines to interact with us in more humanistic ways—is here to stay.
#
# Four short links: 18 August 2017
# ================================
#
# Top N Summary
# -------------
# Eight Lessons from 20 Years of Hype Cycles -- Out of the more than 200 unique technologies that have ever appeared on a Gartner Hype Cycle for Emerging Technology, just a handful of technologies—Cloud Computing, 3D Printing, Natural Language Search, Electronic Ink—have been identified early and traveled even somewhat predictably through a Hype Cycle from start to finish. [...] [J]ust over 50 individual technologies appear for just a single year on the Hype Cycle—never to reappear again. [...]  20% of all technologies that were tracked for multiple years on the Hype Cycle became obsolete before reaching any kind of mainstream success. [...] I was often struck by how many times the Hype Cycle had an insight that was essentially correct, but the technology or the market just wasn’t ready yet. Each reincarnation makes progress and leaves lessons for its successors without really breaking through.
#
# Mean Scored Summary
# -------------------
# Eight Lessons from 20 Years of Hype Cycles -- Out of the more than 200 unique technologies that have ever appeared on a Gartner Hype Cycle for Emerging Technology, just a handful of technologies—Cloud Computing, 3D Printing, Natural Language Search, Electronic Ink—have been identified early and traveled even somewhat predictably through a Hype Cycle from start to finish. [...] [J]ust over 50 individual technologies appear for just a single year on the Hype Cycle—never to reappear again. [...]  20% of all technologies that were tracked for multiple years on the Hype Cycle became obsolete before reaching any kind of mainstream success. [...] I was often struck by how many times the Hype Cycle had an insight that was essentially correct, but the technology or the market just wasn’t ready yet.
#
# How Ray makes continuous learning accessible and easy to scale
# ==============================================================
#
# Top N Summary
# -------------
# The O’Reilly Data Show Podcast: Robert Nishihara and Philipp Moritz on a new framework for reinforcement learning and AI applications.In this episode of the Data Show, I spoke with Robert Nishihara and Philipp Moritz, graduate students at UC Berkeley and members of RISE Lab. I wanted to get an update on Ray, an open source distributed execution framework that makes it easy for machine learning engineers and data scientists to scale reinforcement learning and other related continuous learning algorithms. Many AI applications involve an agent (for example a robot or a self-driving car) interacting with an environment. In such a scenario, an agent will need to continuously learn the right course of action to take for a specific state of the environment. Continue reading How Ray makes continuous learning accessible and easy to scale.
#
# Mean Scored Summary
# -------------------
# The O’Reilly Data Show Podcast: Robert Nishihara and Philipp Moritz on a new framework for reinforcement learning and AI applications.In this episode of the Data Show, I spoke with Robert Nishihara and Philipp Moritz, graduate students at UC Berkeley and members of RISE Lab. I wanted to get an update on Ray, an open source distributed execution framework that makes it easy for machine learning engineers and data scientists to scale reinforcement learning and other related continuous learning algorithms.
#
# Julie Stanford on vetting designs through rapid experimentation
# ===============================================================
#
# Top N Summary
# -------------
# The O’Reilly Design Podcast: Quickly test ideas like a design thinker.In this week’s Design Podcast, I sit down with Julie Stanford, founder and principal of user experience agency Sliced Bread Design. We talk about how to get in the rapid experimentation mindset, the design thinking process, and how to get started with rapid experimentation at your company. Hint: start small.Continue reading Julie Stanford on vetting designs through rapid experimentation.
#
# Mean Scored Summary
# -------------------
# The O’Reilly Design Podcast: Quickly test ideas like a design thinker.In this week’s Design Podcast, I sit down with Julie Stanford, founder and principal of user experience agency Sliced Bread Design. Hint: start small.Continue reading Julie Stanford on vetting designs through rapid experimentation.
#
# Jack Daniel on building community and historical context in InfoSec
# ===================================================================
#
# Top N Summary
# -------------
# The O'Reilly Security Podcast: The role of community, the proliferation of BSides and other InfoSec community events, and celebrating our heroes and heroines.In this episode of the Security Podcast, I talk with Jack Daniel, co-founder of Security Bsides. We discuss how each of us (and the industry as a whole) benefits from community building, the importance of historical context, and the inimitable Becky Bace.Continue reading Jack Daniel on building community and historical context in InfoSec.
#
# Mean Scored Summary
# -------------------
# We discuss how each of us (and the industry as a whole) benefits from community building, the importance of historical context, and the inimitable Becky Bace.Continue reading Jack Daniel on building community and historical context in InfoSec.
#
# Four short links: 17 August 2017
# ================================
#
# Top N Summary
# -------------
# Implementing Compression, Eliminating Humans, Mapping NES, and Classifying Defects
#
# On the Implementation of Minimum Redundancy Prefix Codes -- a paper that shows all the curls and challenges of the real world, instead of the idealized handwaving that's pretty much everywhere else. (via Fabian Giesen)
#
# Eliminating the Human (MIT TR) -- David Byrne digs into the idea that modern tech is mostly about reducing need for human interaction. Often our rational thinking convinces us that much of our interaction can be reduced to a series of logical decisions—but we are not even aware of many of the layers and subtleties of those interactions. As behavioral economists will tell us, we don’t behave rationally, even though we think we do. (via BoingBoing)
#
# Automatic Mapping of NES Games with Mappy -- We describe a software system, Mappy, that produces a good approximation of a linked map of rooms given a Nintendo Entertainment System game program and a sequence of button inputs exploring its world.
#
# Mean Scored Summary
# -------------------
# Implementing Compression, Eliminating Humans, Mapping NES, and Classifying Defects
#
# On the Implementation of Minimum Redundancy Prefix Codes -- a paper that shows all the curls and challenges of the real world, instead of the idealized handwaving that's pretty much everywhere else. (via Fabian Giesen)
#
# Eliminating the Human (MIT TR) -- David Byrne digs into the idea that modern tech is mostly about reducing need for human interaction. Often our rational thinking convinces us that much of our interaction can be reduced to a series of logical decisions—but we are not even aware of many of the layers and subtleties of those interactions. (via BoingBoing)
#
# Automatic Mapping of NES Games with Mappy -- We describe a software system, Mappy, that produces a good approximation of a linked map of rooms given a Nintendo Entertainment System game program and a sequence of button inputs exploring its world.
#
# Contouring learning rate to optimize neural nets
# ================================================
#
# Top N Summary
# -------------
# Tips and tricks for treating learning rate as a hyperparameter, and using visualizations to see what’s really going on.Learning rate is the rate at which the accumulation of information in a neural network progresses over time. It is imperative to selectively increase or decrease learning rate as training progresses in order to reach the global optimum or the desired destination. Learning Rate
# 			Cross Entropy
# 			Classification Error
#
#
# 			1
#
#
#
#
# 			.5
#
#
#
#
# 			.2
#
#
#
#
# 			.1
#
#
#
#
# 			.01
#
#
#
#
#
#
# Figure 2. Loss per epoch for different learning rates. Figure 2 shows the loss per epoch curve for different learning rates.
#
# Mean Scored Summary
# -------------------
# Tips and tricks for treating learning rate as a hyperparameter, and using visualizations to see what’s really going on.Learning rate is the rate at which the accumulation of information in a neural network progresses over time. Contouring the learning rate over time is similar to contouring the speed of a car according to road conditions. On smooth, broad roads such as a highway, we can increase our speed (learning rate), but on narrow, hilly, or valley roads, we must slow down. Keep in mind that “...a high learning rate... [indicates] the system contains too much kinetic energy and the parameter vector bounces around chaotically, unable to settle down into the deeper, but narrower parts of the loss function” (see Karpathy’s Notes for cs231n). Such decay makes the learned network resistant to random fluctuations that could possibly reverse the learning. Learning rate decay
#
# Non-adaptive learning rates can be suboptimal. Learning rate decay can be brought about through reducing decay by some constant factor every few epochs, or by exponential decay, in which the decay takes a mathematical form of the exponential every few epochs. “Decay” is often considered a negative concept, and in the current case of learning rate decay it’s a negative, too: it refers to how much the learning rate is decreasing. In a car, for instance, we decrease the speed to suit the road and traffic conditions; this deacceleration can be understood as a “decay” in the velocity of the car. Think of a local minima as a speeding ticket, a toll or traffic light, or traffic congestion—something that basically increases the time taken to reach the destination. The RMSProp adaptive learning rate by Tieleman and Hinton, 2012, keeps a moving average of the squared gradient for each weight to normalize the current gradient. Figure 1 shows the comparison of different optimization techniques under similar hyperparameter settings:
#
#
# Figure 1. It is imperative to selectively increase or decrease learning rate as training progresses in order to reach the global optimum or the desired destination. A good way to generate this plot is by overlaying the loss per epoch curve for different sets of parameters. Cross entropy’s niceties include a log term, making it more granular, while taking into account the closeness of the predicted value with the target. Plotting the cross entropy function might be more interpretable due to the log term simply because the learning process is mostly an exponential process taking the form of an exponential shape. Experimenting with different learning rates
#
# Learning rate is a hyperparameter that controls the size of update steps. As seen in the plots of Figure 2, there is a lot of confusion or random noise with an increase in the learning rate. We can infer from the plots that a high learning rate is more likely to blow up the whole model, resulting in numerical instability such as overflows or underflows, which was also empirically noted while running these experiments. Learning Rate
# 			Cross Entropy
# 			Classification Error
#
#
# 			1
#
#
#
#
# 			.5
#
#
#
#
# 			.2
#
#
#
#
# 			.1
#
#
#
#
# 			.01
#
#
#
#
#
#
# Figure 2. Loss per epoch for different learning rates. Figure 2 shows the loss per epoch curve for different learning rates. Two different loss functions, the cross entropy and the classification error, are compared. When the learning rates are high, almost exponential jumps are seen (Learning rate 1 and .5). Each layer has a different fan-in or the number of inputs, that determines the overshoot effect caused by simultaneously updating the incoming weights of a unit aimed at correcting the same error (as is the case in the global learning rate). Hence, the appropriate learning rates can vary widely between weights. A fix for this issue involves setting a global learning rate and multiplying it by an appropriate local gain that is determined empirically for each weight. While using separate adaptive learning rates, either the entire batch should be used for learning, or larger mini-batches should be used in order to ensure the changes in the signs of the gradients are not mainly due to the sampling error of a mini-batch or random fluctuations. These per-weight adaptive learning rates can also be combined with momentum. As the network is pretrained, fine-tuning takes considerably less time to train, because the network has already acquired most of the information it needs and must only refine that knowledge during the fine-tuning phase. Conclusion
#
# In this article, we only briefly touched on a few things out of all the parameters in the parametric-multiverse of deep learning algorithms. We can always find a pre-trained model for the application we are developing, selectively add or delete parts of it, and ultimately fine-tune it for the application we need. And, if we contour our learning rate accurately, we reach our destination in good time.
#
# Creating better disaster recovery plans
# =======================================
#
# Top N Summary
# -------------
# Five questions for Tanya Reilly: How service interdependencies make recovery harder and why it’s a good idea to deliberately and preemptively manage dependencies.I recently asked Tanya Reilly, Site Reliability Engineer at Google, to share her thoughts on how to make better disaster recovery plans. If you have backups, but you haven't tested restoring them, you don't really have backups. Testing doesn't just mean knowing you can get the data back; it means knowing how to put it back into the database, how to handle incremental changes, how to reinstall the whole thing if you need to. Parts of the system that are only used in disasters need the most testing, or they'll fail you when you need them. What other parts of the program for Velocity NY are of interest to you?
#
# Mean Scored Summary
# -------------------
# Five questions for Tanya Reilly: How service interdependencies make recovery harder and why it’s a good idea to deliberately and preemptively manage dependencies.I recently asked Tanya Reilly, Site Reliability Engineer at Google, to share her thoughts on how to make better disaster recovery plans. at the O’Reilly Velocity Conference, taking place Oct. 1-4 in New York. 1. What are the most common mistakes people make when planning their backup systems strategy? If you have backups, but you haven't tested restoring them, you don't really have backups. Testing doesn't just mean knowing you can get the data back; it means knowing how to put it back into the database, how to handle incremental changes, how to reinstall the whole thing if you need to. It's the sort of thing that people will cut corners on if they're busy. It's worth taking the time to make it as simple and painless and automated as possible; never rely on human willpower for anything! to transfer and reinsert the data. When you build the second one, it's hard to be sure it's exactly the same. The only way to be sure you've covered everything is to fail over in earnest. But there can still be some forgotten components of the system that only run in one or two places. Parts of the system that are only used in disasters need the most testing, or they'll fail you when you need them. But someone needs to keep a big picture of what depends on what, because it can get very tangled very fast. You can even end up with things that indirectly depend on themselves—for example, a device that you need to configure to bring up the network, but you can't get to it while the network is down. Why is this important and what’s your advice for doing it effectively? The other advantage of starting early is that you can split up your services into vertical "strata," where the functionality in each stratum must be able to come completely online before the next one begins. What other parts of the program for Velocity NY are of interest to you?
#
# Announcing the Rebecca Bace Pioneer Award for Defensive Security
# ================================================================
#
# Top N Summary
# -------------
# Carrying on Becky Bace’s legacy of encouraging and celebrating defenders.In her keynote at O’Reilly Security Conference in New York 2016, Rebecca “Becky” Bace shared her vision for the future of cybersecurity. Within her talk, Becky encouraged defenders to study analogous safety industries in history and heed the lessons learned. She urged defenders to recognize the importance of understanding the context of the challenges we face today by considering historical parallels and our shared goals for the future. The winner of the first annual Rebecca Bace Pioneer Award will be announced at the O’Reilly Security Conference in New York. Please help us celebrate Becky by nominating worthy defenders for the first annual Rebecca Bace Pioneer Award here.
#
# Mean Scored Summary
# -------------------
# Carrying on Becky Bace’s legacy of encouraging and celebrating defenders.In her keynote at O’Reilly Security Conference in New York 2016, Rebecca “Becky” Bace shared her vision for the future of cybersecurity. Within her talk, Becky encouraged defenders to study analogous safety industries in history and heed the lessons learned. She urged defenders to recognize the importance of understanding the context of the challenges we face today by considering historical parallels and our shared goals for the future. The winner of the first annual Rebecca Bace Pioneer Award will be announced at the O’Reilly Security Conference in New York. Please help us celebrate Becky by nominating worthy defenders for the first annual Rebecca Bace Pioneer Award here. She was affectionately called the “den mother of computer security” or “infomom,” though as Jack Daniel tells us in the latest O’Reilly Security podcast, she preferred the moniker, “cranky broad.”
#
# In the words of others:
#
# When I think about Becky Bace, I remember her warm and friendly demeanor, her charming voice, and her welcoming hugs.
#
# How synthetic biology startups are building the future at RebelBio
# ==================================================================
#
# Top N Summary
# -------------
# The program helps the founders to make their longer-term moonshot visions (the “innovation” part) into feasible projects which generate revenue early on (the “engine” part). We even have a machine learning startup for drug discovery, and another working on microbial fuel cell modules to treat wastewater while generating electricity! We are building the tools that will allow innovators from all backgrounds to engineer the materials of the future. The biosynthetic machinery of antibiotics can be initiated by certain stimuli in the soil matrix though. Rachel Major, cofounder and CEO of NuLeaf Tech
#
#  So, bio-inspired design helps us uncover powerful engineering solutions—and even novel materials!
#
# Mean Scored Summary
# -------------------
# Biology is becoming the new digital. As the engineering of biology starts delivering solutions at industrial scale while becoming more data-driven and automated, investors are getting excited to fund breakthrough biotechnologies that unlock this potential for a whole range of industries. It has even been hailed as the “New Silicon Valley.” Boasting an active DIY biology scene, world-class institutions and productive innovation ecosystems, the continent is a fertile base to grow global startups from the early stage to the next level. This is the stage the RebelBio accelerator comes in to help startups solve global grand challenges—with life itself. The program helps the founders to make their longer-term moonshot visions (the “innovation” part) into feasible projects which generate revenue early on (the “engine” part). We even have a machine learning startup for drug discovery, and another working on microbial fuel cell modules to treat wastewater while generating electricity! Figure 1-3. Figure 1-4. We are building the tools that will allow innovators from all backgrounds to engineer the materials of the future. Dr. Thomas Meany, cofounder and CEO of Cell-Free Technologies
#
#
#
#
#  Figure 1-5. Galactica Biotech is using machine learning algorithms with multiple highly trained modules to identify potential new uses for existing medicines, from small molecules to complex plant alkaloids. The young innovator and principal investigator worked relentlessly all around the world, from the universities of Oxford, Leiden, and Kyoto to ETH Zurich, driven to find a solution to her father’s life-shattering cancer diagnosis. The biosynthetic machinery of antibiotics can be initiated by certain stimuli in the soil matrix though. By 2050, up to 66% of the world’s population will live in cities, according to the United Nations. Rachel Major, cofounder and CEO of NuLeaf Tech
#
#  So, bio-inspired design helps us uncover powerful engineering solutions—and even novel materials! Perfect Day (formerly Muufri) is a vegan alternative to milk which has been hitting the headlines as long-awaited animal-free dairy. And what better alternative to sweeten your caffeine fix, but with MilisBio’s sweetener proteins? They could find applications in cosmetics, and later on, medicine. The team has already optimized the powerful platform for high yield and is now scaling up the production of cosmetic ingredients with industrial partners. Canuevo is an Uruguayan-Canadian startup cofounded by Dr. Nils Rehman to launch a paradigm shift for cannabinoid medicine. As we see, very exciting things are happening at the intersection of biology and technology. Synthetic biology startups are at the forefront of tackling diverse areas of life sciences to build a better world by programming life.
#
# The impact of design at Shopify
# ===============================
#
# Top N Summary
# -------------
# Five questions for Cynthia Savard Saucier on how design impacts Shopify’s business outcomes, and tips for improving designer-developer communication.I recently asked Cynthia Savard Saucier, Director of UX at Shopify and author of Tragic Design, to discuss the design process, its impact on Shopify’s business outcomes, and how to improve communication between designers and developers. 1. Describe your design process and an example of the impact it’s had on business outcomes at Shopify. Second, we often start the design process with a design sprint, inspired by Google Ventures. Learn about the right level of abstraction required to offer an answer.
#
# Mean Scored Summary
# -------------------
# Five questions for Cynthia Savard Saucier on how design impacts Shopify’s business outcomes, and tips for improving designer-developer communication.I recently asked Cynthia Savard Saucier, Director of UX at Shopify and author of Tragic Design, to discuss the design process, its impact on Shopify’s business outcomes, and how to improve communication between designers and developers. Cynthia is presenting a keynote on The impact of design: How design influences outcomes at the O’Reilly Velocity Conference, taking place Oct. 1-4 in New York. 1. Describe your design process and an example of the impact it’s had on business outcomes at Shopify. The floor plan is pretty much a representation of our roadmap. Also, every project has a multidisciplinary trio of leads (product, engineering, and UX). They make decisions together, and ensure a good team alignment. Second, we often start the design process with a design sprint, inspired by Google Ventures. A lot of effort goes into tweaking our processes so they work for the project, people, and product. This seems quite obvious, but I know from experience that surprisingly few UX professionals ever get to meet their users. To use a biology reference: designers and developers are not in a neutral relationship (where both entities simply live together), but rather a mutualist association (where they benefit from each other). We might think that error management is not as important as other pieces of the interface. 4. If you’re a designer, invite developers to your design feedback sessions and vice versa. Learn about the right level of abstraction required to offer an answer.
#
# Take the 2018 Data Science Salary Survey
# ========================================
#
# Top N Summary
# -------------
# As a data professional, you are invited to share your valuable insights. Help us gain insight into the demographics, work environments, tools, and compensation of practitioners in our growing field. All responses are reported in aggregate to assure your anonymity. The survey will require approximately 5-10 minutes to complete.All responses to this survey are reported in aggregate to assure your anonymity. Continue reading Take the 2018 Data Science Salary Survey.
#
# Mean Scored Summary
# -------------------
# Help us gain insight into the demographics, work environments, tools, and compensation of practitioners in our growing field. Continue reading Take the 2018 Data Science Salary Survey.
#
# Four short links: 16 August 2017
# ================================
#
# Top N Summary
# -------------
# IoT Hacking, Virtual School Fails, Neural Network NLP, and Using Logical Fallacies
#
# Reverse-Engineering IoT Devices -- nice step-by-step of how the author figures out the protocol used by a Bluetooth lightbulb (oh to live in such times) and thus how to control it without the Approved Software. A Primer on Neural Network Models for Natural Language Processing -- This tutorial surveys neural network models from the perspective of natural language processing research, in an attempt to bring natural-language researchers up to speed with the neural techniques. The tutorial covers input encoding for natural language tasks, feed-forward networks, convolutional networks, recurrent networks and recursive networks, as well as the computation graph abstraction for automatic gradient computation. Effective Presentations Using Applied Logical Fallacies -- what I also got out of this Informal Logic course was that here were a huge list of classically tested brain shortcuts that are surprisingly effective. Why?
#
# Mean Scored Summary
# -------------------
# IoT Hacking, Virtual School Fails, Neural Network NLP, and Using Logical Fallacies
#
# Reverse-Engineering IoT Devices -- nice step-by-step of how the author figures out the protocol used by a Bluetooth lightbulb (oh to live in such times) and thus how to control it without the Approved Software. The tutorial covers input encoding for natural language tasks, feed-forward networks, convolutional networks, recurrent networks and recursive networks, as well as the computation graph abstraction for automatic gradient computation.
#
# Four short links: 15 August 2017
# ================================
#
# Top N Summary
# -------------
# P != NP, Open Source Lab Notebook, Science Data, and Anonymous Feedback
#
# A Solution of the P versus NP Problem -- from a respected computability theory researcher, so not the usual crank writing—but will need to withstand interrogation and verification from the rest of the academic community. There are a lot of problems, so researchers turn new problems into an archetypical problem with a solution that we've already proven is efficient or inefficient. To do so would mean we could quickly solve hard problems in maps, planning, allocation, even Donkey Kong and Bejeweled. This proof shows that both variations of one archetypical hard problem can't be reduced to an efficient solution: they're proven to be inefficient, which means (because we've shown all inefficient problems are equivalent) that all inefficient problems ("NP") can't be solved efficiently ("aren't P"). These data are the first complete set of neural activity recordings released before publication.
#
# Mean Scored Summary
# -------------------
# P != NP, Open Source Lab Notebook, Science Data, and Anonymous Feedback
#
# A Solution of the P versus NP Problem -- from a respected computability theory researcher, so not the usual crank writing—but will need to withstand interrogation and verification from the rest of the academic community. There are a lot of problems, so researchers turn new problems into an archetypical problem with a solution that we've already proven is efficient or inefficient. To do so would mean we could quickly solve hard problems in maps, planning, allocation, even Donkey Kong and Bejeweled. This proof shows that both variations of one archetypical hard problem can't be reduced to an efficient solution: they're proven to be inefficient, which means (because we've shown all inefficient problems are equivalent) that all inefficient problems ("NP") can't be solved efficiently ("aren't P"). These data are the first complete set of neural activity recordings released before publication.
#
# How to use Presto Sketching to clarify your team’s purpose
# ==========================================================
#
# Top N Summary
# -------------
# The Team Purpose map can visually guide and capture a team’s discussions about their identity, purpose and direction.This chapter is about using Presto Sketching techniques to envision the future state. This area is a mix of conceptual and literal representation, with a bit of visual metaphor thrown in. Let’s see how it applies to:
#
#   Helping your team rally around a common future with the Team Purpose map
#   Envisioning the future state of your customers with the Superhero Booth sketch
#   Exploring goals with the Build a Bridge sketch
#   Knocking down the barriers with the Goal Barriers sketch
#   Envision a future product with the experience canvas
#   Bringing future experiences to life with storyboarding
#
#
# Rally around a common future with the Team Purpose map
# Setting out to create a new product or service is one of the most exciting things you can ever do. The Team Purpose map: This is a fun visual activity to do with your team, especially if it’s a new team and you need to form a shared understanding together of who you are, your purpose, and your destination. This is what the team is going to do.
#
# Mean Scored Summary
# -------------------
# The Team Purpose map can visually guide and capture a team’s discussions about their identity, purpose and direction.This chapter is about using Presto Sketching techniques to envision the future state. This area is a mix of conceptual and literal representation, with a bit of visual metaphor thrown in. Let’s see how it applies to:
#
#   Helping your team rally around a common future with the Team Purpose map
#   Envisioning the future state of your customers with the Superhero Booth sketch
#   Exploring goals with the Build a Bridge sketch
#   Knocking down the barriers with the Goal Barriers sketch
#   Envision a future product with the experience canvas
#   Bringing future experiences to life with storyboarding
#
#
# Rally around a common future with the Team Purpose map
# Setting out to create a new product or service is one of the most exciting things you can ever do. If you’re part of a larger business with one or more products or services, your team purpose might need to be expressed in a different way (e.g. The Team Purpose map: This is a fun visual activity to do with your team, especially if it’s a new team and you need to form a shared understanding together of who you are, your purpose, and your destination. As with all of these visual patterns, do feel free to adapt it to your team’s needs. It’s a good idea to have the boss or a senior stakeholder establish the intent of the strategic discussion, and give some background that would be helpful for everyone. The aim here is to get a shared understanding. This is what the team is going to do. Go ahead and get the group to write those up on the Team Purpose map too. If ever there was a time to call out any skills-gaps to achieve those goals, now is that time!
#
# Four short links: 14 August 2017
# ================================
#
# Top N Summary
# -------------
# Robotics Interviews, Customer Development, Engineering Method, and Complex System Failures
#
# Robotics Interviews -- Mike Salem (Robotics Nanodegree Service Lead), interviews professional roboticists. 10 Things I've Learned About Customer Development -- my favorite: If someone says, “I wouldn’t personally use it, but I bet other people would,” no one will use it. Multiple Perspectives on Technical Problems and Solutions (John Allspaw) -- [The Engineering Method is] “the strategy for causing the best change in a poorly understood or uncertain situation within the available resources.”
#
#
# How Complex Systems Fail -- Complex systems contain changing mixtures of failures latent within them. Eradication of all latent failures is limited primarily by economic cost but also because it is difficult before the fact to see how such failures might contribute to an accident. Continue reading Four short links: 14 August 2017.
#
# Mean Scored Summary
# -------------------
# Multiple Perspectives on Technical Problems and Solutions (John Allspaw) -- [The Engineering Method is] “the strategy for causing the best change in a poorly understood or uncertain situation within the available resources.”
#
#
# How Complex Systems Fail -- Complex systems contain changing mixtures of failures latent within them.
#
# A multi-cloud strategy is the foundation for digital transformation
# ===================================================================
#
# Top N Summary
# -------------
# Using a single cloud provider is a thing of the past.When news broke that Amazon was acquiring Whole Foods, brick and mortar retailers panicked. Many industries are feeling pressure to undergo digital transformation for fear of being “Amazoned” (acquired by an online competitor). IDC’s Worldwide Semiannual Digital Transformation Spending Guide reports that many industries have been affected by the frenzy, too, with manufacturing leading the pack, followed by retail, health care, insurance, and banking. Using a multi-cloud strategy to achieve digital transformation
#
# A growing number of companies have embraced a multi-cloud approach as part of their digital transformation strategy, mainly to meet various business and technology requirements because no single cloud model can fit the diverse requirements and workloads across different business units. By adopting a multi-cloud strategy, companies are able to choose best-in-class technologies and services from different cloud providers to create the best possible solution for a business.
#
# Mean Scored Summary
# -------------------
# Using a single cloud provider is a thing of the past.When news broke that Amazon was acquiring Whole Foods, brick and mortar retailers panicked. Many industries are feeling pressure to undergo digital transformation for fear of being “Amazoned” (acquired by an online competitor). The International Data Corporation (IDC) forecasts worldwide spending on digital transformation technologies will grow to more than $1.2 trillion in 2017 (an increase of 17.8% over 2016. IDC’s Worldwide Semiannual Digital Transformation Spending Guide reports that many industries have been affected by the frenzy, too, with manufacturing leading the pack, followed by retail, health care, insurance, and banking. Using a multi-cloud strategy to achieve digital transformation
#
# A growing number of companies have embraced a multi-cloud approach as part of their digital transformation strategy, mainly to meet various business and technology requirements because no single cloud model can fit the diverse requirements and workloads across different business units. Some workloads run better on one cloud platform while other workloads achieve higher performance and lower cost on another platform. By adopting a multi-cloud strategy, companies are able to choose best-in-class technologies and services from different cloud providers to create the best possible solution for a business.
#
# How to choose a cloud provider
# ==============================
#
# Top N Summary
# -------------
# Practical questions to help you make a decision.If you look up the phrase “boiling the ocean,” it’s defined as writing a post on choosing a cloud provider—there are so many different facets and use cases, and each variable complicates your choice. At these small data scales, there are fewer distinguishing factors. Take the time to investigate niche providers as well. They may be able to provide a level of service that the big providers don’t (although, be warned that some smaller providers don’t provide tech support). Use case: Does the technology work for your use case?
#
# Mean Scored Summary
# -------------------
# Practical questions to help you make a decision.If you look up the phrase “boiling the ocean,” it’s defined as writing a post on choosing a cloud provider—there are so many different facets and use cases, and each variable complicates your choice. In this article, I share some of the early questions and decisions I use when working with a team to choose a cloud provider. In the lens of a use case, these differences can make a requirement of your use case impossible to implement with a technology. At these small data scales, there are fewer distinguishing factors. How difficult will it be for you to move between cloud providers and technologies—aka “lock in”? Take the time to investigate niche providers as well. They may be able to provide a level of service that the big providers don’t (although, be warned that some smaller providers don’t provide tech support). Use case: Does the technology work for your use case?
#
# Four short links: 11 August 2017
# ================================
#
# Top N Summary
# -------------
# Cracking Wi-Fi, Hacking with DNA, Animation Playthings, and Physics Simulation
#
# Wi-Fi Cracking -- This is a brief walk-through tutorial that illustrates how to crack Wi-Fi networks that are secured using weak passwords. The attack outlined below is entirely passive (listening only, nothing is broadcast from your computer) and it is impossible to detect, provided you don't actually use the password that you crack. Computer Security and Privacy in DNA Sequencing -- Here we highlight two key examples of our research below: (1) the failure of DNA sequencers to follow best practices in computer security and (2) the possibility to encode malware in DNA sequences. Wick -- a free browser-based toolkit for creating small interactive things for the Internet. ... Wick is a hybrid of an animation tool and a coding IDE, heavily inspired by similar tools such as Flash, HyperCard, and Scratch.
#
# Mean Scored Summary
# -------------------
# Cracking Wi-Fi, Hacking with DNA, Animation Playthings, and Physics Simulation
#
# Wi-Fi Cracking -- This is a brief walk-through tutorial that illustrates how to crack Wi-Fi networks that are secured using weak passwords. Computer Security and Privacy in DNA Sequencing -- Here we highlight two key examples of our research below: (1) the failure of DNA sequencers to follow best practices in computer security and (2) the possibility to encode malware in DNA sequences. Wick -- a free browser-based toolkit for creating small interactive things for the Internet. ... Wick is a hybrid of an animation tool and a coding IDE, heavily inspired by similar tools such as Flash, HyperCard, and Scratch.
#
# Mike Roberts on serverless architectures
# ========================================
#
# Top N Summary
# -------------
# The O’Reilly Programming Podcast: The next technological evolution of cloud systems.In this episode of the O’Reilly Programming Podcast, I talk serverless architecture with Mike Roberts, engineering leader and co-founder of Symphonia, a serverless and cloud architecture consultancy. Roberts will give two presentations—Serverless Architectures: What, Why, Why Not, and Where Next? and Designing Serverless AWS Applications—at the O’Reilly Software Architecture Conference, October 16-19, 2017, in London.Continue reading Mike Roberts on serverless architectures.
#
# Mean Scored Summary
# -------------------
# and Designing Serverless AWS Applications—at the O’Reilly Software Architecture Conference, October 16-19, 2017, in London.Continue reading Mike Roberts on serverless architectures.
#
# How to craft a voice user interface that won’t leave you frustrated
# ===================================================================
#
# Top N Summary
# -------------
# Design principles for creating a truly conversational UI.Continue reading How to craft a voice user interface that won’t leave you frustrated.
#
# Mean Scored Summary
# -------------------
#
#
# Four short links: 10 August 2017
# ================================
#
# Top N Summary
# -------------
# Sarcasm Detector, GMO Salmon, New Deep Learning Courses, and Serverless Malware Detection
#
# An Algorithm Trained on Emoji Knows When You're Being Sarcastic on Twitter (MIT TR) -- They also tested it against humans, using volunteers recruited through the crowdsourcing site Mechanical Turk. It was 82% accurate at identifying sarcasm correctly, compared with an average score of 76% for the human volunteers. GMO Salmon On Sale (Guardian) -- Originally developed by a group of Canadian scientists at Newfoundland’s Memorial University, the salmon can grow twice as fast as conventionally farmed Atlantic salmon, reaching adult size in some 18 months as compared to 30 months. The product also requires 75% less feed to grow to the size of wild salmon, reducing its carbon footprint by up to 25 times, the company has claimed. New Coursera Deep Learning Courses -- topics: neural networks, tuning and optimization, structuring ML projects, convolutional neural networks, sequence models.
#
# Mean Scored Summary
# -------------------
# Sarcasm Detector, GMO Salmon, New Deep Learning Courses, and Serverless Malware Detection
#
# An Algorithm Trained on Emoji Knows When You're Being Sarcastic on Twitter (MIT TR) -- They also tested it against humans, using volunteers recruited through the crowdsourcing site Mechanical Turk. The product also requires 75% less feed to grow to the size of wild salmon, reducing its carbon footprint by up to 25 times, the company has claimed. New Coursera Deep Learning Courses -- topics: neural networks, tuning and optimization, structuring ML projects, convolutional neural networks, sequence models.
#
# Four short links: 9 August 2017
# ===============================
#
# Top N Summary
# -------------
# Event Trend Detection, Separation of Duties, Online Communities, and Autonomous Tractors
#
# ...
# # The actual name of the classes are given in a separate file. Here we load the csv file which allows mapping from classes/labels to
# # file name
# import csv
# def read_csv_and_parse():
#     traffic_labels_dict ={}
#     with open('signnames.csv') as f:
#         reader = csv.reader(f)
#         count = -1;
#         for row in reader:
#             count = count + 1
#             if(count == 0):
#                 continue
#             label_index = int(row[0])
#             traffic_labels_dict[label_index] = row[1]
#     return traffic_labels_dict
# traffic_labels_dict = read_csv_and_parse()
# print(traffic_labels_dict)
#
# We can see there are 43 labels for the 43 image classes. %matplotlib inline
#
# #This functions selects one image per class to plot
# def get_images_to_plot(images, labels):
#     selected_image = []
#     idx = []
#     for i in range(n_classes):
#         selected = np.where(labels == i)[0][0]
#         selected_image.append(images[selected])
#         idx.append(selected)
#     return selected_image,idx
#
# # function to plot the images in a grid
# def plot_images(selected_image,y_val,row=5,col=10,idx = None):
#     count =0;
#     f, axarr = plt.subplots(row, col,figsize=(50, 50))
#
#     for i in range(row):
#          for j in range(col):
#                 if(count < len(selected_image)):
#                     axarr[i,j].imshow(selected_image[count])
#                     if(idx != None):
#                         axarr[i,j].set_title(traffic_labels_dict[y_val[idx[count]]], fontsize=20)
#                 axarr[i,j].axis('off')
#                 count = count + 1
#
# selected_image,idx = get_images_to_plot(X_train,y_train)
# plot_images(selected_image,row=10,col=4,idx=idx,y_val=y_train)
#
# Here are the visualized traffic signs, with their labels:
#
#
#
# Preparing the data set
#
# X_train and Y_train make the training data set. Below is the helper function to convert image ordering to MXNet's 3X32X32 format from 32X32X3:
# #change the image dimensioning from 32 X 32 X 3 to 3 X 32 X 32 for train
# X_train_reshape = np.transpose(X_train, (0, 3, 1, 2))
# plt.imshow(X_train_reshape[0].transpose((1,2,0)))
# print(X_train_reshape.shape)
#
#
# #change the image dimensioning from 32 X 32 X 3 to 3 X 32 X 32 for validation
# X_valid_reshape = np.transpose(X_valid, (0, 3, 1, 2))
# plt.imshow(X_valid_reshape[1].transpose((1,2,0)))
# print(X_valid_reshape.shape)
#
#
#
# Building the deepnet
#
# Now, enough of preparing our data set. The neural code is concise and simple, thanks to MXNet's symbolic API:
# data = mx.symbol.Variable('data')
# conv1 = mx.sym.Convolution(data=data, pad=(1,1), kernel=(3,3), num_filter=24, name="conv1")
# relu1 = mx.sym.Activation(data=conv1, act_type="relu", name= "relu1")
# pool1 = mx.sym.Pooling(data=relu1, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool1")
# # second conv layer
# conv2 = mx.sym.Convolution(data=pool1, kernel=(3,3), num_filter=48, name="conv2", pad=(1,1))
# relu2 = mx.sym.Activation(data=conv2, act_type="relu", name="relu2")
# pool2 = mx.sym.Pooling(data=relu2, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool2")
#
# conv3 = mx.sym.Convolution(data=pool2, kernel=(5,5), num_filter=64, name="conv3")
# relu3 = mx.sym.Activation(data=conv3, act_type="relu", name="relu3")
# pool3 = mx.sym.Pooling(data=relu3, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool3")
#
# #conv4 = mx.sym.Convolution(data=conv3, kernel=(5,5), num_filter=64, name="conv4")
# #relu4 = mx.sym.Activation(data=conv4, act_type="relu", name="relu4")
# #pool4 = mx.sym.Pooling(data=relu4, pool_type="max", kernel=(2,2), stride=(2,2),name="max_pool4")
#
# # first fullc layer
# flatten = mx.sym.Flatten(data=pool3)
# fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500, name="fc1")
# relu3 = mx.sym.Activation(data=fc1, act_type="relu" , name="relu3")
# # second fullc
# fc2 = mx.sym.FullyConnected(data=relu3, num_hidden=43,name="final_fc")
# # softmax loss
# mynet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')
#
# Let's break down the code a bit. Since the output from the neuron is real valued, but our classification requires a single label as output, we use another activation function. This helps the learning algorithm to converge faster. Make sure there is folder named models exist
# model_prefix = 'models/chkpt'
# checkpoint = mx.callback.do_checkpoint(model_prefix)
#
# #loading the module API. We also set the binding in the model loaded to training as false, since we are using this network for testing, not training. You can use the same technique to load any other pre-trained machine learning model:
# #load the model from the checkpoint , we are loading the 10 epoch
# sym, arg_params, aux_params = mx.model.load_checkpoint(model_prefix, 10)
#
# # assign the loaded parameters to the module
# mod = mx.mod.Module(symbol=sym, context=mx.cpu())
# mod.bind(for_training=False, data_shapes=[('data', (1,3,32,32))])
# mod.set_params(arg_params, aux_params)
#
#
#
# Prediction
#
# To use the loaded model for prediction, we convert a traffic sign image (Stop.jpg) into 32  32  3 (32 * 32 dimension image with 3 channels) and try to predict their label. While the network we built was simpler than the most sophisticated image-recognition neural network architectures available, even this simpler version was surprisingly performant!
#
# Four short links: 27 July 2017
# ==============================
#
# Top N Summary
# -------------
# Next Death, Evolution of Trust, Indoor Robots, and Embryo Editing
#
# Predicting Who Dies Next in Game of Thrones -- waiting for the org chart version of this. The Evolution of Trust -- fun illustration of what game theory has to say about trust. First Human Embryos Edited in USA (MIT TR) -- Mitalipov is believed to have broken new ground both in the number of embryos experimented upon and by demonstrating that it is possible to safely and efficiently correct defective genes that cause inherited diseases. Although none of the embryos were allowed to develop for more than a few days—and there was never any intention of implanting them into a womb—the experiments are a milestone on what may prove to be an inevitable journey toward the birth of the first genetically modified humans. Continue reading Four short links: 27 July 2017.
#
# Mean Scored Summary
# -------------------
# First Human Embryos Edited in USA (MIT TR) -- Mitalipov is believed to have broken new ground both in the number of embryos experimented upon and by demonstrating that it is possible to safely and efficiently correct defective genes that cause inherited diseases.
#
# R’s tidytext turns messy text into valuable insight
# ===================================================
#
# Top N Summary
# -------------
# Authors Julia Silge and David Robinson discuss the power of tidy data principles, sentiment lexicons, and what they're up to at Stack Overflow.“Many of us who work in analytical fields are not trained in even simple interpretation of natural language,” write Julia Silge, Ph.D., and David Robinson, Ph.D., in their newly released book Text Mining with R: A tidy approach. I recently caught up with Silge and Robinson to discuss how they’re using text mining on job postings at Stack Overflow, some of the challenges and best practices they’ve experienced when mining text, and how their tidytext package for R aims to make text analysis both easy and informative. Tidy tools like dplyr and ggplot2 are widely used, and integrating natural language processing into these tools allows R users to work with greater fluency. Applying the Loughran-McDonald lexicon allows us to explore the sentiment content of documents dealing with finance with more confidence. Data scientists and analysts like us are usually trained on numerical data in a rectangular shape like a table (i.e., data frame), so it takes some practice to fluently wrangle raw text data.
#
# Mean Scored Summary
# -------------------
# Authors Julia Silge and David Robinson discuss the power of tidy data principles, sentiment lexicons, and what they're up to at Stack Overflow.“Many of us who work in analytical fields are not trained in even simple interpretation of natural language,” write Julia Silge, Ph.D., and David Robinson, Ph.D., in their newly released book Text Mining with R: A tidy approach. I recently caught up with Silge and Robinson to discuss how they’re using text mining on job postings at Stack Overflow, some of the challenges and best practices they’ve experienced when mining text, and how their tidytext package for R aims to make text analysis both easy and informative. Why did you create the tidytext text mining package in R? We created the tidytext package because we believe in the power of tidy data principles, and we wanted to apply this consistent, opinionated approach for handling data to text mining tasks. Tidy tools like dplyr and ggplot2 are widely used, and integrating natural language processing into these tools allows R users to work with greater fluency. A word like “share” has a positive meaning in most contexts, but is neutral in financial contexts, where it usually refers to shares of stock. Applying the Loughran-McDonald lexicon allows us to explore the sentiment content of documents dealing with finance with more confidence. One example we deal with is text in job postings; we use text mining and modeling to match job listings with people who may be interested in them. Data scientists and analysts like us are usually trained on numerical data in a rectangular shape like a table (i.e., data frame), so it takes some practice to fluently wrangle raw text data. When your data is tidy, you can use a common set of tools for exploring and visualizing them. Using consistent tools designed for handling tidy data gives us a dependable framework for understanding how to represent text data in R, visualize the characteristics of text, model topics, and move smoothly to more complex machine learning applications. What is the difference between text mining and natural language processing? We describe our work as “text mining” because our goal is extracting and visualizing insights, but there is a great deal of overlap.
#
# Four short links: 26 July 2017
# ==============================
#
# Top N Summary
# -------------
# Blockchain and Securities Law, Low-Energy Sensing, Robotics Deep Learning, and Chipped Employees
#
# Report of Investigation ... DAO (SEC) -- This Report reiterates these fundamental principles of the U.S. federal securities laws and describes their applicability to a new paradigm—virtual organizations or capital raising entities that use distributed ledger or blockchain technology to facilitate capital raising and/or investment and the related offer and sale of securities. How to Make a Wireless Sensor Live for a Year on One Tiny Coin Cell Battery -- We see that making the right choices in software can make a stunning 400x difference in power consumption – two orders of magnitude – even with an already extremely power-efficient hardware. Deep Learning in Robotics: A Review of Recent Research -- what it says on the cover. A Wisconsin Company Will Let Employees Use Microchip Implants to Buy Snacks and Open Doors -- Participating employees will have the chips, which use near field communication (NFC) technology, implanted between their thumb and forefinger. It’s an extension of the long-running implantable RFID chip business, based on a partnership with Swedish company Biohax International.
#
# Mean Scored Summary
# -------------------
# Blockchain and Securities Law, Low-Energy Sensing, Robotics Deep Learning, and Chipped Employees
#
# Report of Investigation ... DAO (SEC) -- This Report reiterates these fundamental principles of the U.S. federal securities laws and describes their applicability to a new paradigm—virtual organizations or capital raising entities that use distributed ledger or blockchain technology to facilitate capital raising and/or investment and the related offer and sale of securities. How to Make a Wireless Sensor Live for a Year on One Tiny Coin Cell Battery -- We see that making the right choices in software can make a stunning 400x difference in power consumption – two orders of magnitude – even with an already extremely power-efficient hardware.
#
# Making great hires in your design organization
# ==============================================
#
# Top N Summary
# -------------
# How to help your team succeed and develop a stronger design practice.Continue reading Making great hires in your design organization.
#
# Mean Scored Summary
# -------------------
#
#
# A lesson in prescriptive modeling
# =================================
#
# Top N Summary
# -------------
# Simulate new business models and practices with open source code.Continue reading A lesson in prescriptive modeling.
#
# Mean Scored Summary
# -------------------
#
#
# Four short links: 25 July 2017
# ==============================
#
# Top N Summary
# -------------
# AI Sentencing, AI Vocabulary, Soft U2F, and Encrypted Email
#
# Opening the Lid on Criminal Sentencing -- Duke researchers building a (socially) better algorithm. CORELS makes it possible for judges and defendants to scrutinize why the algorithm classifies a particular person as high or low risk. [...] None of the research team’s models rely on race or socioeconomic status. By emulating a HID device, Soft U2F is able to communicate with your U2F-enabled browser, and by extension, any websites implementing U2F. (The magic numbers intercepted for one site can't be reused on another)
#
# Magma -- The magma server daemon is an encrypted email system with support for SMTP, POP, IMAP, HTTP and MOLTEN.
#
# Mean Scored Summary
# -------------------
# AI Sentencing, AI Vocabulary, Soft U2F, and Encrypted Email
#
# Opening the Lid on Criminal Sentencing -- Duke researchers building a (socially) better algorithm. CORELS makes it possible for judges and defendants to scrutinize why the algorithm classifies a particular person as high or low risk. (The magic numbers intercepted for one site can't be reused on another)
#
# Magma -- The magma server daemon is an encrypted email system with support for SMTP, POP, IMAP, HTTP and MOLTEN.
#
# Data science startups focus on AI-enabled efficiency
# ====================================================
#
# Top N Summary
# -------------
# Recapping winners of the Strata San Jose Startup Showcase.Every five years, we invent a new technology that, when sprinkled atop existing business problems, acts as a panacea for managers. Web and SaaS gave us interfaces anyone could use. Mobility made them ubiquitous, taking us away from the workday—we check our phones dozens of times a day, and, often, they're the last thing we look at before sleep and the first thing we grab upon waking. And AI is a set of algorithms that make sense of that big data, teasing threads of gold from the digital hay. From a field of applicants, our panel winnowed the list down to 10 finalists, and then a combination of on-site judges and audience voting helped us pick the winners:
#
#
# 	The first-place winner, Nexla, makes data wrangling easier with a product that allows teams to share, automatically process, transform, and monitor data.
#
# Mean Scored Summary
# -------------------
# Recapping winners of the Strata San Jose Startup Showcase.Every five years, we invent a new technology that, when sprinkled atop existing business problems, acts as a panacea for managers. Web and SaaS gave us interfaces anyone could use. Mobility made them ubiquitous, taking us away from the workday—we check our phones dozens of times a day, and, often, they're the last thing we look at before sleep and the first thing we grab upon waking. Clouds gave us elastic, on-demand computing. Big data gave clouds something to do. And AI is a set of algorithms that make sense of that big data, teasing threads of gold from the digital hay. From a field of applicants, our panel winnowed the list down to 10 finalists, and then a combination of on-site judges and audience voting helped us pick the winners:
#
#
# 	The first-place winner, Nexla, makes data wrangling easier with a product that allows teams to share, automatically process, transform, and monitor data.

# %% [markdown]
# ## Visualizing document summarization results with HTML output

# %%
import os
from IPython.display import IFrame
from IPython.core.display import display

HTML_TEMPLATE = """<html>
    <head>
        <title>{0}</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>{1}</body>
</html>"""

for post in blog_data:
   
    # Uses previously defined summarize function.
    post.update(summarize(post['content']))

    # You could also store a version of the full post with key sentences marked up
    # for analysis with simple string replacement...

    for summary_type in ['top_n_summary', 'mean_scored_summary']:
        post[summary_type + '_marked_up'] = '<p>{0}</p>'.format(post['content'])
        
        for s in post[summary_type]:
            post[summary_type + '_marked_up'] = \
            post[summary_type + '_marked_up'].replace(s, '<strong>{0}</strong>'.format(s))

        filename = post['title'].replace("?", "") + '.summary.' + summary_type + '.html'
        
        f = open(os.path.join(filename), 'wb')
        html = HTML_TEMPLATE.format(post['title'] + ' Summary', post[summary_type + '_marked_up'])    
        f.write(html.encode('utf-8'))
        f.close()

        print("Data written to", f.name)

# Display any of these files with an inline frame. This displays the
# last file processed by using the last value of f.name...
print()
print("Displaying {0}:".format(f.name))
display(IFrame('files/{0}'.format(f.name), '100%', '600px'))
# Out:
# Data written to Four short links: 21 August 2017.summary.top_n_summary.html
# Data written to Four short links: 21 August 2017.summary.mean_scored_summary.html
# Data written to 6 practical guidelines for implementing conversational AI.summary.top_n_summary.html
# Data written to 6 practical guidelines for implementing conversational AI.summary.mean_scored_summary.html
# Data written to Four short links: 18 August 2017.summary.top_n_summary.html
# Data written to Four short links: 18 August 2017.summary.mean_scored_summary.html
# Data written to How Ray makes continuous learning accessible and easy to scale.summary.top_n_summary.html
# Data written to How Ray makes continuous learning accessible and easy to scale.summary.mean_scored_summary.html
# Data written to Julie Stanford on vetting designs through rapid experimentation.summary.top_n_summary.html
# Data written to Julie Stanford on vetting designs through rapid experimentation.summary.mean_scored_summary.html
# Data written to Jack Daniel on building community and historical context in InfoSec.summary.top_n_summary.html
# Data written to Jack Daniel on building community and historical context in InfoSec.summary.mean_scored_summary.html
# Data written to Four short links: 17 August 2017.summary.top_n_summary.html
# Data written to Four short links: 17 August 2017.summary.mean_scored_summary.html
# Data written to Contouring learning rate to optimize neural nets.summary.top_n_summary.html
# Data written to Contouring learning rate to optimize neural nets.summary.mean_scored_summary.html
# Data written to Creating better disaster recovery plans.summary.top_n_summary.html
# Data written to Creating better disaster recovery plans.summary.mean_scored_summary.html
# Data written to Announcing the Rebecca Bace Pioneer Award for Defensive Security.summary.top_n_summary.html
# Data written to Announcing the Rebecca Bace Pioneer Award for Defensive Security.summary.mean_scored_summary.html
# Data written to How synthetic biology startups are building the future at RebelBio.summary.top_n_summary.html
# Data written to How synthetic biology startups are building the future at RebelBio.summary.mean_scored_summary.html
# Data written to The impact of design at Shopify.summary.top_n_summary.html
# Data written to The impact of design at Shopify.summary.mean_scored_summary.html
# Data written to Take the 2018 Data Science Salary Survey.summary.top_n_summary.html
# Data written to Take the 2018 Data Science Salary Survey.summary.mean_scored_summary.html
# Data written to Four short links: 16 August 2017.summary.top_n_summary.html
# Data written to Four short links: 16 August 2017.summary.mean_scored_summary.html
# Data written to Four short links: 15 August 2017.summary.top_n_summary.html
# Data written to Four short links: 15 August 2017.summary.mean_scored_summary.html
# Data written to How to use Presto Sketching to clarify your team’s purpose.summary.top_n_summary.html
# Data written to How to use Presto Sketching to clarify your team’s purpose.summary.mean_scored_summary.html
# Data written to Four short links: 14 August 2017.summary.top_n_summary.html
# Data written to Four short links: 14 August 2017.summary.mean_scored_summary.html
# Data written to A multi-cloud strategy is the foundation for digital transformation.summary.top_n_summary.html
# Data written to A multi-cloud strategy is the foundation for digital transformation.summary.mean_scored_summary.html
# Data written to How to choose a cloud provider.summary.top_n_summary.html
# Data written to How to choose a cloud provider.summary.mean_scored_summary.html
# Data written to Four short links: 11 August 2017.summary.top_n_summary.html
# Data written to Four short links: 11 August 2017.summary.mean_scored_summary.html
# Data written to Mike Roberts on serverless architectures.summary.top_n_summary.html
# Data written to Mike Roberts on serverless architectures.summary.mean_scored_summary.html
# Data written to How to craft a voice user interface that won’t leave you frustrated.summary.top_n_summary.html
# Data written to How to craft a voice user interface that won’t leave you frustrated.summary.mean_scored_summary.html
# Data written to Four short links: 10 August 2017.summary.top_n_summary.html
# Data written to Four short links: 10 August 2017.summary.mean_scored_summary.html
# Data written to Four short links: 9 August 2017.summary.top_n_summary.html
# Data written to Four short links: 9 August 2017.summary.mean_scored_summary.html
# Data written to Deep learning revolutionizes conversational AI.summary.top_n_summary.html
# Data written to Deep learning revolutionizes conversational AI.summary.mean_scored_summary.html
# Data written to Cancer detection, one slice at a time.summary.top_n_summary.html
# Data written to Cancer detection, one slice at a time.summary.mean_scored_summary.html
# Data written to Integrating data with AI.summary.top_n_summary.html
# Data written to Integrating data with AI.summary.mean_scored_summary.html
# Data written to Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering.summary.top_n_summary.html
# Data written to Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering.summary.mean_scored_summary.html
# Data written to Four short links: 8 August 2017.summary.top_n_summary.html
# Data written to Four short links: 8 August 2017.summary.mean_scored_summary.html
# Data written to Why continuous learning is key to AI.summary.top_n_summary.html
# Data written to Why continuous learning is key to AI.summary.mean_scored_summary.html
# Data written to Four short links: 7 August 2017.summary.top_n_summary.html
# Data written to Four short links: 7 August 2017.summary.mean_scored_summary.html
# Data written to How to move your team closer to clarity.summary.top_n_summary.html
# Data written to How to move your team closer to clarity.summary.mean_scored_summary.html
# Data written to Four short links: 4 August 2017.summary.top_n_summary.html
# Data written to Four short links: 4 August 2017.summary.mean_scored_summary.html
# Data written to JupyterHub on Google Cloud.summary.top_n_summary.html
# Data written to JupyterHub on Google Cloud.summary.mean_scored_summary.html
# Data written to Why AI and machine learning researchers are beginning to embrace PyTorch.summary.top_n_summary.html
# Data written to Why AI and machine learning researchers are beginning to embrace PyTorch.summary.mean_scored_summary.html
# Data written to A DevOps approach to data management.summary.top_n_summary.html
# Data written to A DevOps approach to data management.summary.mean_scored_summary.html
# Data written to Four short links: 3 August 2017.summary.top_n_summary.html
# Data written to Four short links: 3 August 2017.summary.mean_scored_summary.html
# Data written to Declaring variables in Kotlin.summary.top_n_summary.html
# Data written to Declaring variables in Kotlin.summary.mean_scored_summary.html
# Data written to Building—and scaling—a reliable distributed architecture.summary.top_n_summary.html
# Data written to Building—and scaling—a reliable distributed architecture.summary.mean_scored_summary.html
# Data written to Operationalizing security risk.summary.top_n_summary.html
# Data written to Operationalizing security risk.summary.mean_scored_summary.html
# Data written to Reinforcement learning for complex goals, using TensorFlow.summary.top_n_summary.html
# Data written to Reinforcement learning for complex goals, using TensorFlow.summary.mean_scored_summary.html
# Data written to Jay Jacobs on data analytics and security.summary.top_n_summary.html
# Data written to Jay Jacobs on data analytics and security.summary.mean_scored_summary.html
# Data written to Four short links: 2 August 2017.summary.top_n_summary.html
# Data written to Four short links: 2 August 2017.summary.mean_scored_summary.html
# Data written to The wisdom hierarchy: From signals to artificial intelligence and beyond.summary.top_n_summary.html
# Data written to The wisdom hierarchy: From signals to artificial intelligence and beyond.summary.mean_scored_summary.html
# Data written to Four short links: 1 August 2017.summary.top_n_summary.html
# Data written to Four short links: 1 August 2017.summary.mean_scored_summary.html
# Data written to How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks.summary.top_n_summary.html
# Data written to How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks.summary.mean_scored_summary.html
# Data written to From prototype to product with hybrid neural networks.summary.top_n_summary.html
# Data written to From prototype to product with hybrid neural networks.summary.mean_scored_summary.html
# Data written to Four short links: 31 July 2017.summary.top_n_summary.html
# Data written to Four short links: 31 July 2017.summary.mean_scored_summary.html
# Data written to Four short links: 28 July 2017.summary.top_n_summary.html
# Data written to Four short links: 28 July 2017.summary.mean_scored_summary.html
# Data written to Eric Freeman and Elisabeth Robson on design patterns.summary.top_n_summary.html
# Data written to Eric Freeman and Elisabeth Robson on design patterns.summary.mean_scored_summary.html
# Data written to John Whalen on using brain science in design.summary.top_n_summary.html
# Data written to John Whalen on using brain science in design.summary.mean_scored_summary.html
# Data written to When you hear hooves, think horse, not zebra.summary.top_n_summary.html
# Data written to When you hear hooves, think horse, not zebra.summary.mean_scored_summary.html
# Data written to Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks.summary.top_n_summary.html
# Data written to Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks.summary.mean_scored_summary.html
# Data written to Four short links: 27 July 2017.summary.top_n_summary.html
# Data written to Four short links: 27 July 2017.summary.mean_scored_summary.html
# Data written to R’s tidytext turns messy text into valuable insight.summary.top_n_summary.html
# Data written to R’s tidytext turns messy text into valuable insight.summary.mean_scored_summary.html
# Data written to Four short links: 26 July 2017.summary.top_n_summary.html
# Data written to Four short links: 26 July 2017.summary.mean_scored_summary.html
# Data written to Making great hires in your design organization.summary.top_n_summary.html
# Data written to Making great hires in your design organization.summary.mean_scored_summary.html
# Data written to A lesson in prescriptive modeling.summary.top_n_summary.html
# Data written to A lesson in prescriptive modeling.summary.mean_scored_summary.html
# Data written to Four short links: 25 July 2017.summary.top_n_summary.html
# Data written to Four short links: 25 July 2017.summary.mean_scored_summary.html
# Data written to Data science startups focus on AI-enabled efficiency.summary.top_n_summary.html
# Data written to Data science startups focus on AI-enabled efficiency.summary.mean_scored_summary.html
#
# Displaying Data science startups focus on AI-enabled efficiency.summary.mean_scored_summary.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Data science startups focus on AI-enabled efficiency.summary.mean_scored_summary.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Extracting entities from a text with NLTK

# %%
import nltk
import json

BLOG_DATA = "feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    sentences = nltk.tokenize.sent_tokenize(post['content'])
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    # Flatten the list since we're not using sentence structure
    # and sentences are guaranteed to be separated by a special
    # POS tuple such as ('.', '.')

    pos_tagged_tokens = [token for sent in pos_tagged_tokens for token in sent]

    all_entity_chunks = []
    previous_pos = None
    current_entity_chunk = []
    for (token, pos) in pos_tagged_tokens:

        if pos == previous_pos and pos.startswith('NN'):
            current_entity_chunk.append(token)
        elif pos.startswith('NN'):
            
            if current_entity_chunk != []:
                
                # Note that current_entity_chunk could be a duplicate when appended,
                # so frequency analysis again becomes a consideration

                all_entity_chunks.append((' '.join(current_entity_chunk), pos))
            current_entity_chunk = [token]

        previous_pos = pos

    # Store the chunks as an index for the document
    # and account for frequency while we're at it...

    post['entities'] = {}
    for c in all_entity_chunks:
        post['entities'][c] = post['entities'].get(c, 0) + 1

    # For example, we could display just the title-cased entities

    print(post['title'])
    print('-' * len(post['title']))
    proper_nouns = []
    for (entity, pos) in post['entities']:
        if entity.istitle():
            print('\t{0} ({1})'.format(entity, post['entities'][(entity, pos)]))
    print()
# Out:
# Four short links: 21 August 2017
# --------------------------------
# 	Cloud Operations (1)
# 	Machine Learning Radio (1)
# 	Cameras (1)
# 	Text Organization Paracloud (1)
# 	Bringing Application Insight (1)
# 	Cloud Operations (1)
# 	Paracloud (1)
# 	A Paper A Day (1)
# 	Radio Signals (1)
# 	” Tilghman (1)
# 	Reinventing User Interaction (1)
# 	Flying Cameras (1)
# 	Drone (1)
# 	Tree Sheets (1)
# 	Nice (1)
# 	Continue (1)
#
# 6 practical guidelines for implementing conversational AI
# ---------------------------------------------------------
# 	Apple (1)
# 	Siri (4)
# 	Jeff Bezos (1)
# 	Star Trek (1)
# 	Alexa (1)
# 	Joseph Weizenbaum (1)
# 	Decades (1)
# 	Andrew Leonard (1)
# 	Bots (1)
# 	Mozambique. ” (1)
# 	Today (1)
# 	Slack (2)
# 	Starbucks (1)
# 	Mastercard (1)
# 	Macy ’ (1)
# 	Gartner (1)
# 	Alexa (3)
# 	Cortana (2)
# 	Google Home (1)
# 	Skipflag (1)
# 	Use (1)
# 	Taco Bell ’ (1)
# 	Google Home (1)
# 	Organizations (1)
# 	Start (1)
# 	Amir Shevat (1)
# 	Beyond (1)
# 	Shevat (1)
# 	Others (1)
# 	Figure (1)
# 	Figure (1)
# 	Screenshots (1)
# 	Susan Etlinger (1)
# 	Chris Mullins (1)
# 	Microsoft (1)
# 	Speech (1)
# 	Google Home (1)
# 	Typing (1)
# 	Keyboard (1)
# 	Mullins (2)
# 	Where (1)
# 	Developers (1)
# 	Play Beyoncé ’ (1)
# 	Lemonade (1)
# 	“ Check (1)
# 	Figure (2)
# 	Kasisto (1)
# 	Susan Etlinger (1)
# 	Kai (5)
# 	Kai (2)
# 	First (1)
# 	Third (1)
# 	“ Neubig (1)
# 	Neubig (1)
# 	Fourth (1)
# 	Speech Technology (1)
# 	Research (1)
# 	Analytics (1)
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    entity_interactions = []
    for sentence in pos_tagged_tokens:

        all_entity_chunks = []
        previous_pos = None
        current_entity_chunk = []

        for (token, pos) in sentence:

            if pos == previous_pos and pos.startswith('NN'):
                current_entity_chunk.append(token)
            elif pos.startswith('NN'):
                if current_entity_chunk != []:
                    all_entity_chunks.append((' '.join(current_entity_chunk),
                            pos))
                current_entity_chunk = [token]

            previous_pos = pos

        if len(all_entity_chunks) > 1:
            entity_interactions.append(all_entity_chunks)
        else:
            entity_interactions.append([])

    assert len(entity_interactions) == len(sentences)

    return dict(entity_interactions=entity_interactions,
                sentences=sentences)

blog_data = json.loads(open(BLOG_DATA).read())

# Display selected interactions on a per-sentence basis

for post in blog_data:

    post.update(extract_interactions(post['content']))

    print(post['title'])
    print('-' * len(post['title']))
    for interactions in post['entity_interactions']:
        print('; '.join([i[0] for i in interactions]))
    print()
# Out:
# Four short links: 21 August 2017
# --------------------------------
# Cloud Operations; Machine Learning Radio; Cameras; Text Organization Paracloud; Bringing Application Insight; Cloud Operations; work; Paracloud; interface; PaCI; communication channel; application; containers
# application; interface; cloud management layer; how/when; scale
# A Paper A Day; DARPA Wants Machine Learning; Radio Signals; RFMLS; differences; RF; signals; IoT; devices; signals
# RF; forensics; capability; signals; cocktail party; signals
# XPose; Reinventing User Interaction; Flying Cameras
# Drone; bunch; shots; path; operators; drone; location; operator; framing; focus
# drone; photo; thing
#
#
# Continue; links
#
# 6 practical guidelines for implementing conversational AI
# ---------------------------------------------------------
# organizations; interactions; humans; machines.It; years; Apple; Siri; Jeff Bezos; Star Trek
# idea; interfaces; intelligence
# MIT; professor; Joseph Weizenbaum; prototype; today; ’
# Decades; WIRED; story; Andrew Leonard; Bots; price; CD; flowers; mom [; developments; Mozambique. ”; reference; reveals
# Today; companies; Slack; Starbucks; Mastercard; Macy ’; s; interfaces; everything; customer service; home; flowers
# value; longevity; technology; Gartner; assistants; way; users; devices; part
# AI; form; Alexa; Siri; Cortana; Google Home; X.ai; Skipflag
# top; rules; engine; machine
# Use; cases; minute; Taco Bell ’; TacoBot; Alexa; Siri; Cortana
# Organizations; interfaces; uses; partners; technology stack; plenty
# game; practices; ”; guidelines; organizations; and/or
# Start; use case; focus; product; brand; ”; Amir Shevat; director; developer; relations; Slack; “; bot; service; Beyond; Shevat; others; place; thorny problem
# doesn; mean; bots; thing; domain; answer; design; experience; users
#
# interaction model; conversations; interactions; example; car; heater
# Others; bank balance; privacy; precision
# ways; users
# Figure; interaction
#
#
# people; misperception; bots; speaking; typing; ”; Chris Mullins
# fact; ways; modalities; bots; information; Speech; Alexa; Siri; Google Home; Typing; bots; apps; Keyboard; support; cues; range; input; options Cards; information; scenarios; ”; Mullins; “; mix
#
#
#
# modeling; problem; one
# contexts require; planning; choices; customer; retailer; question; Where; power drill; store; developer; context; question; customer; ’
#
# phone; computer
# Developers; scenarios
# process; interaction; models
# “; humans; modeling; ”
# job; project; teams; choices; beginning
#
# interactions; understanding; difference; command; Play Beyoncé ’; s; Lemonade; ”; “ Check; bank balance; engineering; interaction
# conversations; exchanges; ”; human; bot
# example; Figure; Kasisto; complexity; payment interaction
#
# user; Kai
# Kai; people; user; ’
#
# Kai; answers; ”
# glance; transaction; engineering perspective; bit; language; understanding; First; Kai; track; user; ’; s goal; —
# Kai; user; friends; clarification; one
# Third; Kai; word; “ Neubig; refers; interaction; request
# Fourth; Kai; checking; ”; request; interactions
# request; thread
# conversation; purpose; answer; domain expertise; chatbot development —; user; ’; s intent
#
# EQ; IQ Intelligence; intention; aren
# emotion; word choice; tone; experiences
# result; research; labs; startups; software; states; images; speech; text
# SRI International ’; Speech Technology; Research; STAR; laboratory; SenSay; Analytics; platform; speaker; emotions
# user; agent; frame
#
#
# Branding; aspect; bot; ’; s; brand; ’; s
# bot; reputation; brand presence; success
# “; branding opportunity; interface; ”; Lars Trieloff
# “; brand
# Make; thing; way; customer; stages; interfaces; way
# time; web; sites
# AI—the; ability; machines
# today; advances; data; science; language technology; machine learning; disciplines; conditions; shift; communications; humans
#
# types; conversations; machine
# uses; innovation
# thing; futurist; strategist; Monika Bielskyte; “; future
# future; ”; world; ” Continue; guidelines
#
# Four short links: 18 August 2017
# --------------------------------
# Style Transfer; Hype Cycles; Automation; Jobs; Become; Neural Style Transfer; overview; state; art; image
# Lessons; Years; Hype Cycles; technologies; Gartner Hype Cycle; Emerging Technology; handful; Computing; Printing; Natural Language Search; Electronic Ink—have; Hype Cycle
# [; [ J ]; ust; technologies; year
# [; %; technologies; years; Hype Cycle; kind
# [; ]; times; Hype Cycle; insight; technology; market
# [; ]; number; core; technologies; guises; years; Hype Cycles
# reincarnation; progress; lessons
# [; number; technologies; years
# Robopocalypse; James Surowiecki; study; impact; robots; manufacturing; agriculture; utilities; countries; instance; robots; hours; workers—but; t; hours; humans
# words; automation; kind; work; humans; moment; world
# McAfee; fact; statements; emphasis; way technology; changes; economy; jobs; jobs
#
# shift; kinds; jobs; ” Become; Eight Easy Steps; Annotated Reading List; resources; order; foundations
# [; goal; researchers; starting point; core; tenets; analysis; level
# guide; articles; reader; methods; work; use
# Continue; links
#
# How Ray makes continuous learning accessible and easy to scale
# --------------------------------------------------------------
# O ’ Reilly Data Show Podcast; Robert Nishihara; Philipp Moritz; framework; reinforcement learning; AI; episode; Data Show; Robert Nishihara; Philipp Moritz; graduate; students; UC Berkeley; members
# update; Ray; source; execution framework; machine learning; engineers; data scientists; reinforcement learning
# AI; applications; agent; example; robot; car
# scenario; agent; course; action; state
#
#
# Julie Stanford on vetting designs through rapid experimentation
# ---------------------------------------------------------------
# O ’ Reilly Design Podcast; test; ideas; design thinker.In; week; ’; s; Design Podcast; Julie Stanford; founder; principal; experience agency
# experimentation mindset; design; process; experimentation
# Hint; start small.Continue; Julie Stanford; designs
#
# Jack Daniel on building community and historical context in InfoSec
# -------------------------------------------------------------------
# O'Reilly Security Podcast; role; community; proliferation; BSides; InfoSec; community; events; heroes; episode; Security Podcast; Jack Daniel; co-founder
# industry; whole; benefits; community building; importance; context; Becky Bace.Continue; Jack Daniel; building community; context
#
# Four short links: 17 August 2017
# --------------------------------
# Compression; Eliminating; Humans; Mapping NES; Classifying Defects; Implementation; Minimum Redundancy Prefix Codes; paper; curls; challenges; world
# Fabian Giesen; Human; MIT TR; David Byrne; idea; tech; need
# interaction; thing
# thinking; convinces; interaction; series; decisions—but; layers; subtleties
#
# Bayesians; interaction
# BoingBoing; Automatic Mapping; NES Games; Mappy; software system; Mappy; approximation; map; rooms; Nintendo Entertainment System; game program; sequence; button; inputs
# addition; maps; Mappy; grids; tiles; time; positions; objects; clusters; rooms; fact; room; set; links
# step; corpora; high-quality; maps; PCG; machine learning
#
# Ryan Betts; Continue; links
#
# Contouring learning rate to optimize neural nets
# ------------------------------------------------
# Tips; tricks; rate; hyperparameter; visualizations; ’; rate; rate; accumulation; information; network
# learning rate; network; optimum; location; network
# Gradient Descent; SGD; learning rate; shape; error gradient; learning rate
# modifications; SGD; update rule; rate; magnitude; orientation
#
# learning rate; time; speed; car; road
# smooth; roads; highway; speed; rate; valley
# t; highways; destination; training time
# t; roads; ravines; optimization loss surface; control; car; jitter; bounce; improvement; destination
# mind; “; learning rate; system; energy; parameter vector; bounces; deeper; parts; loss function; ”; Karpathy ’; s; Notes
# source; guesstimate; learning rate; network; subset
# ideal strategy; learning rate; divide; half
# end; training; decay
# decay; network resistant; fluctuations
# start; LR; test; set; data
# rate; decay
# rate; decay; decay; factor; epochs; decay; decay; form
# Decay ”; concept; case; rate; decay
# result; kind; decay; something
# car; instance; speed; road; traffic; conditions; deacceleration; decay ”; velocity
# benefits; rate
# learning rate; learning rate; training; iterations; probability
# Think; minima; speeding ticket; toll; traffic light; traffic congestion—something; time
# traffic; lights; tolls
# bouncing; gradient; route
# t; speeding ticket; jump
# analogy; applies
# Momentum; method parameter; velocity; directions; velocity
# definition; momentum; momentum; ”; correction; velocity; jump; direction
# Momentum; base; rate; respect; gradient; change; speed; location
# Momentum; network
# update; rules; rate; hyperparameter include; AdaGrad; update; Duchi; al.; scaling; gradient; sum; squares
# RMSProp; learning rate; Tieleman; Hinton; average; gradient; weight
# RMSProp; resistance; fluctuations
# Adam; update; Kingma; Ba; correction
# rprop; sign; gradient; step size
#
# rules; order; methods; Newton ’
# order; methods; rate; hyperparameter; demands; learning
# Figure; comparison; optimization; techniques; hyperparameter; settings
# comparison; optimization
# Source; Alec Radford
# image; momentum; target
# NAG ”; Nesterov Accelerated Gradient; step; direction; velocity; correction; velocity vector
# decay; decay
# rate; training; progresses; order; optimum
#
#
# loss versus epochs plot; instance; loss
# epoch; data; points
# epochs; comparison; iterations; number; iterations depends; setting
# way; plot; loss; curve; sets
# process; set; parameters; training
# plots; loss; y axis; number; epochs; x
# loss; Figure; look; differences; optimization; patterns; number; convergence
# kinds; loss; functions
# classification; tasks; cross entropy error; metrics; mean; error; assumptions
# networks; models; cross entropy; cost function; sigmoid; softmax nonlinearity; likelihood; input
# square error; hand
#
# Cross; entropy; ’; s; niceties; term; account; closeness; value
# Cross; entropy; derivatives; errors; gradients
# cost function; assumptions; output; units; modelling
# instance; softmax; cross entropy
# cross entropy function; term; learning process; process; form
# rates; rate; hyperparameter; size
# rate; increases; number; oscillations
# plots; Figure; lot; confusion; noise; increase
# plots; Figure; network; MNIST
# plots; learning rate; model; instability; overflows; underflows
# fact; NAN ’; s
#
# Loss; epoch
#
# Figure; loss; curve
# loss; functions; cross entropy
# plots; learning; rates; improvements
# learning; rates; jumps; rate
# learning; rates; loss; disadvantage; jump; minima; values
# phenomenon; oscillations; plots; parameters; gradient move
# validation curve; training curve
# gaps; validation; training; curves; network; training set
# Chances; dropout; regularization
# learning rate; connection; networks
# layer; fan-in; number; inputs; effect; weights; unit; error; case
# magnitudes; gradients; layers; weights; case
# Hence; learning; rates
# fix; issue; learning rate; gain
# order; performance; network; gains
# learning; rates; batch; learning; mini-batches; order; changes; signs; gradients; error; mini-batch
# adaptive; rates
# information; Neural Networks
# rate; transfer learning; Transfer; learning; model; use
# reuse; models; data set; training; purposes
# Fine-tuning; type; transfer learning; slice; network; layers; network; number
# types; transfer learning
# Figure; demonstrates; modifies; network; kind; data; accordion; network; kind; data
#
#
# Slide; Anirudh Koul; Learning Into Mobile
#
# network; time; network; information; knowledge
# learning rate; learning rate; slice; layer
# example; source; Caffe; framework; base_lr; solver prototxt; lr_mult
# change; model; change; layer
# rule; thumb; learning rate; layer; times; layers
# Conclusion; article; things; parameters; parametric-multiverse
# decay; rate; parameter
# learning; experiments; use
# ways; ’; learning
# Imagine; learning; knobs; switches; pilot
# outputs; work
# model; application; parts
# rate; destination
# Continue; rate
#
# Creating better disaster recovery plans
# ---------------------------------------
# questions; Tanya Reilly; How; service; interdependencies; recovery harder; idea; dependencies.I; Tanya Reilly; Site Reliability Engineer; Google; share; thoughts; disaster recovery
#
# O ’ Reilly Velocity Conference; place; Oct.
#
# mistakes people; backup; systems
# line; backup strategy
#
# Testing; data; database; changes
# recovery path; system; time
#
# sort; thing; people
# time; willpower
# time; people; disaster
# Recovery; exercises; way; documentation; process; date; resources; disk
#
#
# challenges; disaster recovery; DR
# lot; DR; afterthought; system; business
#
# point; system
# time something; human; things
#
# sites; config management; something
# backups; access; decryption key
#
# way; everything
#
# system; disaster recovery; modes; part
# service; start; replicas
#
# components; system
#
# way; components; information; person; brain; DR; X; vacation; person; point
# Parts; system
#
#
# service; interdependencies; recovery harder
#
#
# Microservices; flexibility; reinvention; wheels; backend
# someone; needs
#
#
# outage; deadlock; systems
#
# things; example; device; network
# people; dependencies; advance; sort; fallback plan; road; cases; path; systems
#
#
# people; dependencies; order
#
#
#
#
#
# policies; use; example; stack; set
# culture; dependencies; part
# bear; mind; lists; dependencies; stale; dependency discovery
#
# advantage; services; strata; functionality; stratum
# example; network
# storage; systems; nothing; network; application; backends; network
# Different; strata; sense
# advance; services
#
# cycles—things; stratum; other—but
#
# parts; program; Velocity NY
#
# lot; interdependent; systems; Carin Meier; thoughts; system complexity; Sarah Wells; microservices; Baron Schwartz
# Jon Moore; story; release
#
# Continue; Creating; disaster recovery
#
# Announcing the Rebecca Bace Pioneer Award for Defensive Security
# ----------------------------------------------------------------
# Becky Bace ’; legacy; defenders.In; keynote; O ’ Reilly Security Conference; New York; Rebecca “ Becky ” Bace; vision; future
# talk; Becky; defenders; safety; industries; history
# defenders; importance; context; challenges; today; parallels; goals
# decades; discipline; Becky
# months; message
# Defender Award; Becky; contributions
# award; defender; paths
# way; Becky; role; security community; efforts; support; celebrate; others
# winner; Rebecca Bace Pioneer Award; O ’ Reilly Security Conference
# Becky; defenders
# O ’ Reilly Defender Awards; security; heroes
# deserving; honors
# contributions; efforts; support; security community; members; pioneer
# Becky; years; experience; technology; years
# achievements; paragraph; ’; summary
# leader; intrusion detection; techniques; influencer; founder; government; forays; cybersecurity; spending; years; US National Security Agency; Computer Misuse; Anomaly Detection; CMAD
# strategist; Center; Forensics; Information Technology; Security; CFITS; University; South Alabama; program
# achievements; contributions; Becky; role; mentor; encourager; friend
# “; mother; computer security ”; infomom; ”; Jack Daniel; O ’ Reilly Security; podcast; moniker; “; ”; words; others; Becky Bace; warm; demeanor; voice
# infomom; mother bear
# accomplishments; pioneer
# book; Intrusion Detection; Computer Misuse; Anomaly Detection Program
# Los Alamos National Laboratory; number; sector
# role; mentor
# nothing; story; told
#
# Becky Bace; impression
# Caroline Wong; Vice President; Security Strategy; Cobalt Becky; den mother; IDS; Intrusion Detection Systems; work fostering; intrusion detection
# expertise; contributions; Becky; hugs
#
# things; Becky; number; people; years; number; people; careers; start; boost
#
# way; people
# Jack Daniel; Co-founder; Security; BSides Continue; Rebecca Bace Pioneer Award
#
# How synthetic biology startups are building the future at RebelBio
# ------------------------------------------------------------------
# accelerator; scientists; visions
#
# engineering; biology; starts; solutions; scale; investors; breakthrough; biotechnologies; potential; range
# Europe; hub; innovation; bets; veteran; VC
# “ New Silicon Valley. ” Boasting; DIY; biology scene; institutions; innovation; ecosystems; continent; base; startups; stage
# Accelerators; elements; innovation; institutions; “ Valley; Death; gap; discoveries
# stage; RebelBio; accelerator
# Innovation Engine; exciting; biology today; computer industry; '70s
#
# Steve Jobs; innovations; century; intersection; biology; technology; ethos; RebelBio; rules; status quo; intersection
# total; teams; world; program; RebelBio; investment
# addition; access; labs; office; spaces; network; hundreds; mentors; RebelBio-founder Bill Liao; Xing; Davnet
# program; founders; visions; “ innovation; ”; part; projects; revenue; “; engine; ”
# scientists; entrepreneurs; areas; life; sciences
# biomaterials; ways; foods; cancer lab; tests; days; hours; discovering
# machine; startup; drug discovery; fuel cell; modules; wastewater
# Bill Liao; founder; RebelBio; partner; SOSV So; kind; startups
#
# lab; cohort; IV; University College Cork; Image; RebelBio; Portable; Personal One RebelBio; startup; Sex Positive; Nico Bouchard; Mary Ward; cofounders; Counter Culture Labs; biohackers
# device; infections; Sex Positive; self-testing; health; privacy; ’ s; home; need
#
# device; combines; dynamics; immunology; genetics; electronics; Tesla; engineer
# KaitekLabs; Emilia Diaz; Chile; bacteria
# ready-to-use; biosensor kit; toxin; shellfish—a; food source; people; regions
#
# startup; batch
#
# KaitekLabs ’; founder; Emilia; “; MOSES ”; Microbial Optic Shellfish Evaluation Sensor; toxin-detection kit; Image; KaitekLabs; OaCP; Oncology; Cytogenetic Products; university spin-out; Bologna; Italy; reagents
# tests; cancer; days; waiting; OaCP; reagent; hybridization; acid
#
# applications; reagent; bottlenecks; sequencing; editing
#
# Sex; Positive ’; test; infections; Image; Sex Positive; DNA; New Silicon; biology; information technology; DNA
# instance; Helixworks; Technologies; storage; data
# startup; product; machine; OpenMOSS; data; DNA—in
# data; medium; dense; DNA; Helixworks; solution; need; data; storage; threat
# sets; data; medium; offers; safety
# startup; “; Most Innovative ”; award; pitch competition
# Tools; program life; theme; cohorts; example; Briefcase Biotec; DNA synthesizer; Kilobaser; Nespresso Machine; DNA; synthesis ”; reagent-cartridge
# machine; oligos; primers
# Moirai Biodesign; approach; case; cancer; therapeutics
# molecule; domains; sensor part; presence; biomarkers; trigger part
# activation; biodevice; cancer; cells; promise; side-effects; cancer therapy
#
# Left; Conor Crosbie; Eshna Gogia; Sachin Chalapati; Nimesh Chandra; buddy; Helixworks; team; Image; Sachin Chalapati; Kilobaser ’; platform; Image; Briefcase Biotec; Personal Maker Kits; Biology Tools; conjunction; kit; BentoLabs; AminoLabs—or
# Hence; Cell-Free; processor; cell; anyone; biomolecules; machinery; “; Raspberry Pi ”; model
# years; synthesis; products; insulin; vaccines; availability
# startup; consumer biotech; applications; anyone; custom; colors; smells
# founders; technology
# sensors; detectors
# tools; innovators; backgrounds; materials
# Dr. Thomas Meany; cofounder; CEO; Cell-Free; Technologies
# Rapid; kit; biology; imagination; creation; Image; cycle; Bio-Pixel; visualization; open-source maker platform; BioDesign Challenge; synthesis; app; Image; Helene Steiner; Biodesign Challenge; Royal College; Art; Machine Learning; MicrobeMiner; ”; Unlock New Medicines Continuing; health theme; trials; approval; medicines; rise; resistance; challenge
# Galactica Biotech; machine; algorithms; modules; uses; medicines; molecules; plant
# process; backward; targets; drugs; effects; toxicology
#
# service; companies; potential; drug discovery pipeline; future
# algorithm; anticancer lead molecule; lab
# team; Russia; Spain; Mexico
# expertise; PhD; research; chemistry; intelligence; systems
# CyCa OncoSolutions; Dr. Nusrat Jahan; things; chemist
#
# delivery; instance; cancer
# innovator; investigator; world; universities; Oxford; Leiden; Kyoto; ETH Zurich; solution; father ’
# Valanx Biotech; hand; designer; proteins; instance
# click-chemistry; molecules; protein; technology; “ SnapIt. ”; software; bitcoins; whilst; biology
# Research; Inc.; platform; mimics; soil; antibiotics; Streptomyces
#
#
#
#
# team; MicrobeMiner; kits; collection; crowd-source
# %; products; operons; microbe; ’; s; DNA
# machinery; antibiotics; stimuli
# Hence; microbes; GeneMiner; technology; gene; clusters; absence
# step; StimKeys; play; platform; variety; chemical; inducers; aim; chemical
# ve; molecules; “; dirt microbe; ”; factory; novel
#
# Prospective Research; team; MicrobeMiner; platform; antibiotics; soil
# Pictures; cultures; applications; MicrobeMiner; GeneMiner
# Image; Research; Economy; Design; High-tech Ecosystems; Biomaterials Urbanization
# %; world; ’; s population; cities; United
# solutions; power; feed; future
# economy; activity; health
# Biomimicry; nature; ’; blueprints
# Hence; building smarter; cities
# example; NuLeaf Tech; technologies; ecosystems; plant fuel; cells; part; hardware module; water
# ideas; rise; NuLeaf Tech
# team; prototype; collaboration; farmers; vision; ecosystems; wetlands—even; arrangement; use
# technology; water; energy; solutions; industry
# Rachel Major; cofounder; CEO; NuLeaf Tech So; design; engineering solutions—and
# Examples; materials; ability; bioplastics; items; plastic waste
#
# hand; Pili; color; pigments; print; design; bacteria; scale; Chinova Bioworks
#
# Left; NuLeaf Tech; fuel cell prototype; Images; NuLeaf Tech; Foods
# re; Brewed
# time; animal; lovers
# number; products; development
# Examples; peanuts; Aranex Biotech; plants; designer; foods; future; PlantEdit; meat; program; IndieBio SF
#
# Day; Muufri; milk; headlines
# time; Spira; health market; tasty; drink; Spirulina
#
# Cultured Coffee; fermentation; New York
# caffeine fix; MilisBio ’; sweetener
# vegan plant; proteins; times; sugar; MilisBio; team; demand; sweeteners; world
#
# Afineur Cultured Coffee; Image; Afineur; Spira; drink; Image; Spira; Perfect Day; milk; Image; Perfect Day; Plant Biofactory; area; innovation; microorganisms; plants; compounds
# example; Hemoalgea; team; bioengineers
# startup; microalgal factory; Hirudin; anticoagulant
# algae; glycosylation; patterns; biomanufacturing
# SwaLife Biotech; alkaloids; plants; results; DNA
# applications; cosmetics
# Plants; CEO Anna Ramata-Stunda
# treasures; compounds; plants; plant tissue stem
# access nature; ’; reservoir; compounds; scale; harm
# team; platform; yield; production; ingredients
# Canuevo; startup; Dr. Nils Rehman; shift
# technology; creams; pills; supplements
# Hyasynth Bio; Canada; THC; cannabinoids; yeast
# things; intersection; biology
# biology; startups; forefront; areas; life; sciences; world
# Hopes; consumer biotech; products; foods; beverages; biomaterials; living; medicines; therapeutics—in; share; benefits; innovation; people
# Biorevolution Find; website; video; date; Twitter
# year ’; cohort
# RebelBio; IndieBio EU; world; ’; s; startup accelerator; part; SOSV; accelerator
# fund; assets; management; world; ’; investor
# SOSV; accelerator; IndieBio SF
#
# cohort; startups; world; team; RebelBio; SOSV; teams
# RebelBio; team; John Carrigan; scientist; Elsa Sotiriadis; program director; Steven O ’ Connell; program manager; Bill Liao; founder; SOSV; partner; Continue; How; biology; startups; future
#
# The impact of design at Shopify
# -------------------------------
# questions; Cynthia Savard Saucier; Shopify ’; s business; outcomes; tips; communication.I; Cynthia Savard Saucier; Director; UX; Shopify; author; Tragic Design; design process; impact; Shopify ’; s business; outcomes; communication; designers
# Cynthia; keynote; impact; design; How; design; O ’ Reilly Velocity Conference; place; Oct.
#
# Describe; design process; example; impact; business; outcomes
# design process; project
# designer; sketches; prototypes; t
# commonalities; teams
# design doesn; ’; t work; isolation
#
#
# floor plan; representation
# project; trio; leads; product; engineering
#
# design process; design sprint
# sprint; members; variety; disciplines; expertise
# diversity; thought
# t; Google Ventures ’; methodology; t
# activities; use; war room; sketching process
#
# lot; effort; processes; project; people
# Third; research; users
# experience; UX; professionals
# t; testing
#
# merchant; groups
# customer support; pain; points; complaints
# everyone; regardless; discipline; day
# work; business; orders; deal; inventory; POS
# example; merchant; process
# time; effort; things
#
# order status; page; merchants
# result—they; t; time
#
# engineers; design
# ’; start
# Developers; designers; work; solving; problems
#
# biology reference; designers; developers; relationship; entities
# Yonatan Zunger; Engineering; art; building; devices; art
# Devices; means
# problems; purpose; things; problems; world; problems; people; people; ways; system; step
# Developers; power; user experience; ways; designer; security; performance; reliability; accessibility
# example; designers; importance; error message; use
# Chances; developers; error; exception; design
# error management; pieces
# talk; error message; difference; event
# history; products; sadden; exclude
# existence; experience designer; team; developers
#
# effect; design; business
# metrics; goal; commerce better
#
# variety; qualitative; success; metrics; area
# UX; researchers; metrics; data; team; care; side
# A/B; testing; experiments
# user testing; feedback; surveys; chats; customer support phone
#
#
# rule; interaction
#
# gap; disciplines
# subject; book; Radical Candor
# way; communication; trust
# designer; developers; design feedback; sessions
# restrictions; complexity
# rationale; interactions; bonus; language
# Involve; decision process; overlaps
#
#
#
#
# feedback; tools; techniques
# designer shouldn; ’; t feel
# hand; developers; mile; things; way
# level; abstraction
#
# way; design feedback; problem
# designers; value feedback; arguments; t
# Be; ’; s
# ’; t use; phrases; “
# impression; designers; service; team
#
#
# conference; talks; categories—at; core expertise; leadership; skills
# Velocity NY; comfort zone; Carin ’; Meier ’; Unconventional; programming paradigms; future; manager; Kellan Elliott-McCrea ’; s talk; architect; bridge; building; decision; teams; craft; John Le Drew ’; talk; Pay
# safety; Continue; impact; design
#
# Take the 2018 Data Science Salary Survey
# ----------------------------------------
# data professional; share
# Help; demographics; work; environments; tools; compensation; practitioners
# responses; aggregate
# survey; minutes; responses; survey; aggregate
#
#
# Four short links: 16 August 2017
# --------------------------------
# IoT Hacking; Virtual School Fails; Neural Network NLP; Using Logical Fallacies Reverse-Engineering IoT; Devices; step-by-step; author; protocol; Bluetooth; lightbulb; times
#
#
#
# Primer; Neural Network Models; Natural Language Processing; surveys; network; models; perspective; language processing research; attempt; natural-language; researchers
# covers; language; tasks; networks; networks; recurrent; networks; networks; computation graph abstraction
# Presentations; Applied Logical Fallacies; Informal Logic; course; list; brain
# ve; thinking; skills; re
#
# thinking; effort; time; re; hundreds; arguments; bits
#
#
# Continue; links
#
# Four short links: 15 August 2017
# --------------------------------
# P; =; NP; Open Source Lab Notebook; Science Data; Anonymous Feedback A Solution; P; versus; NP Problem; computability theory researcher; crank writing—but; interrogation; verification; rest
# Explainer; computing
# problems; solutions; P; solution
# lot; problems; researchers; problems; problem; solution
# question; solution
# problems; maps; planning; allocation; Donkey Kong
# proof; variations; hard problem; solution; inefficient; problems; problems; NP
# eLabFTW; source
# Moment; Neuroscience; Moment; Science; Allen Institute; Brain Science; release
# data; set; activity; recordings
#
#
# guys; fruits; labour; people
# research; organizations; universities; publications; funding; kudos
#
# design; feedback
# lot; teens
#
# Continue; links
#
# How to use Presto Sketching to clarify your team’s purpose
# ----------------------------------------------------------
# Team Purpose; map; team ’; discussions; identity; purpose; direction.This chapter; Presto; techniques
#
#
# area; mix; representation; bit
# ’; team rally; future; Team Purpose; map; state; customers; Superhero Booth; goals; Build; Bridge; sketch; barriers; Goal Barriers; Envision; product; experience canvas; Bringing; experiences; life; Rally; future; Team Purpose; map; product; service
# worth; spell
# part; startup business; business; product; thing
# part; business; products; services; team purpose; way
# product support team; ’; s purpose; development team
# staff; changes; team; ’; while; team; ’; purpose
#
# Team Purpose; map; activity; team; team; understanding; purpose
# case; Team Purpose; map; template; team ’; discussions; identity; purpose
# loads; kinds; facilitation; templates; outputs; group; version; version; template; lots
# patterns; team ’ s
# pattern; Set; team ’ s identity; purpose; direction; understanding; sense; ownership; Expose; assumptions; anxieties; team; project; Align; stakeholders; teams; organisations; purpose; direction; confidence; discussion; discussion; duty; someone; people; wall
# Preparation; sort
# Make; sure; everyone
# ‘; homework ’; sections
# everyone; hopes; fears; team; skills; assets
# Gather; group; team purpose map; whiteboard
# idea; boss; stakeholder; intent; discussion; background
# Start; everyone; something fun; space
# everyone; isn; sort; meeting; hands
# Ask; everyone; note; purpose; team; product; ‘ PURPOSE ’
#
#
# everyone; team; ’; s; goals; GOALS ’
#
# time; group; ‘ SUCCESS FACTORS ’
# context; anything; attitude ’
# facilitator; pausing; story; Team Purpose
# team; purpose; purpose
#
# yourselves; ‘
# Go; group
# group; ACTIONS ’; area
# rearranging; sequence
# part; group; ‘; SKILLS
# group; skills; set; group
# time; skills-gaps; goals
# idea; discussion session; everyone; story; Team Purpose; map
# people; story; arms
# Continue; How; Presto Sketching; team ’
#
# Four short links: 14 August 2017
# --------------------------------
# Robotics Interviews; Customer Development; Engineering Method; Complex System Failures Robotics Interviews; Mike Salem; Robotics Nanodegree Service Lead
# Things; Customer Development; someone; t; people
#
# Perspectives; Technical Problems; Solutions; John Allspaw; Engineering Method; strategy; change; understood; situation; resources.; ” How Complex Systems Fail; systems; mixtures
# complexity; systems
# failure; factors
# Eradication; failures; cost; fact; failures
# failures; technology; work organization; efforts
# Continue; links
#
# A multi-cloud strategy is the foundation for digital transformation
# -------------------------------------------------------------------
# cloud provider; thing; past.When news; Amazon; Whole Foods; brick; mortar
# industries; pressure; transformation; fear; “ Amazoned ”
# International Data Corporation; IDC; spending; transformation; technologies; increase
# IDC ’; Worldwide Semiannual Digital Transformation Spending Guide; industries; frenzy; manufacturing; pack; health care; insurance
# one; ”; Defining; transformation; Surprisingly; anxiety; transformation; money
# George Westerman; research scientist; MIT Sloan Initiative; Digital Economy; transformation; technology; performance; reach; ” Technology; pace; businesses
# Digital; transformation; practice; How; businesses; power; technology
# answer; Digital IQ; survey; IT; business; leaders; industries; technology
# experience; organizations; customers; experiences; employees; experiences
# understanding; experience; technology; companies; marketplace
# strategy; transformation; number; companies; approach; part; transformation strategy; business; technology; requirements; cloud model; diverse; requirements; workloads; business
# cloud; Amazon Web; Services; Microsoft Azure; Google Cloud Platform—has; range; services; areas; cloud; data; warehousing; data; NoSQL
# workloads; cloud platform; workloads; performance; cost
# strategy; companies; technologies; services; cloud; providers; solution
# reason; approach; companies; IT; projects
# environment; sandbox; IT
# teams; decommission; scenarios; burden; cost; time
# strategy; business unit; cloud service; business; needs; Ease; administration; Concurrency; workloads; Query; performance; User; roles; access; levels; Security; governance; Government; regulations; data; privacy; Specialized; functionality; workload; application; machine learning; AI; Access; data; tools; technologies; businesses; transformation journey; environments; transition; migrate; model; customer engagement
# trend; cloud engagement; strategy; return; investment
# benefits; strategy; flexibility; flexibility; cloud
# Risk mitigation; redundancy; workloads; data; cloud; platforms; companies; downtime
# scalability; agility; Elasticity; agility; business; units; demands; access
# Avoid; vendor lock-in; option; changes; marketplace; cloud architecture
# Adopt; use; practices; practices; cloud vendor; enterprise; departments
# companies; position; world; IT; CIOs; roles; facilitators; areas
# trend; point; transformation; phenomenon
# companies; impacts; media; mobile; cloud computing; “; ”; technologies; rise; machine learning; data; collection; drones; reality; data; tenet
# amount; data; strategy; deliberate choice; companies; way
# Companies; curve; position
# post; collaboration; Talend
#
# Continue; strategy; foundation
#
# How to choose a cloud provider
# ------------------------------
# questions; decision.If; phrase; “; ocean; ’; post; cloud; facets; use; cases; complicates
# key; field; situation
# article; share; questions; decisions; team
# Simple; pass/fails; organization; move
# engagement; pass/fail; decisions
# pass/fail; choices; team; decision
#
#
#
# prohibition; cloud; organization; climate
#
#
# data problems; isn; issue
# data problems; capability; issue—there; tradeoffs; technology
# posts; tradeoffs
# example; Amazon Kinesis; Apache Kafka; Google Cloud Pub/Sub
#
# lens; use case; differences; requirement; use case
# order; call
# idea; future; use
# providers; level; ’; t; glaring difference
#
# data scales; cloud; providers
#
# example; database
#
#
#
# cloud; providers
# cost; infrastructure
# question; technology
# example; messaging system; costs; message transfer; storage; message; fee
# prevalent; engineers; knowledge; cloud provider
# days; stone; someone; knowledge; Amazon Web
#
#
# providers; technologies—aka “ lock
# example; providers; source technology; API; service
# service; API
# options; providers; don; ’; t; look; cloud
# time; niche
# level; service; providers; t; providers; t
# niche; providers; operations; source; technologies; t
# questions; factors
# questions; teams; provider; Cost
#
# Popularity contest; How; provider; customers; way
# Availability; people; How; staff; provider; ’; s; technologies; operations
#
# SLAs; level; SLA; provider give; services; services
# Does; management; outage; t
# Use; case; technology work
#
# Lock-in; Are; level
#
# Company; politics; company
#
# questions; position; comparison
# preparation; groundwork; keys
# Continue; How
#
# Four short links: 11 August 2017
# --------------------------------
# Wi-Fi; DNA; Animation Playthings; Physics; Simulation Wi-Fi Cracking; tutorial; Wi-Fi; networks
# information; network; security; break
# attack; nothing; computer
# Computer Security; Privacy; DNA Sequencing; examples; research; failure; DNA; sequencers; practices; computer security; possibility; malware; DNA
# Buffer; overflow; >; DNA; >; sequencer code; >
# Wick; toolkit; things
# Wick; hybrid; animation tool; coding; IDE; tools; Flash; HyperCard
#
# Simulation; Game Physics; simulation; part; planning; game; AI; potential; game; mechanics
# notion; design space model; game design; motor control literature; developing; prototypes; challenges
# work; highlights opportunities; control; characters; action
# results; simulation; game; mechanics
# Preprint; paper
# Continue; links
#
# Mike Roberts on serverless architectures
# ----------------------------------------
# O ’ Reilly Programming Podcast; evolution; cloud systems.In; episode; O ’ Reilly Programming Podcast; architecture; Mike Roberts; engineering leader; co-founder; Symphonia; serverless
# Roberts; presentations—Serverless; Architectures
# Designing Serverless AWS Applications—at; O ’ Reilly Software Architecture Conference; October; London.Continue; Mike Roberts; serverless
#
# How to craft a voice user interface that won’t leave you frustrated
# -------------------------------------------------------------------
# Design; principles; UI.Continue; How; voice user interface; ’
#
# Four short links: 10 August 2017
# --------------------------------
# Sarcasm Detector; GMO Salmon; New Deep Learning Courses; Serverless Malware Detection; Algorithm; Emoji Knows; Sarcastic; Twitter; MIT TR; humans; volunteers; crowdsourcing site
# humans; sarcasm; emotions
# % accurate; sarcasm; score; %
# GMO Salmon; Sale; Guardian; group; scientists; Newfoundland ’; Memorial University; salmon; Atlantic; salmon; adult size; months
# product; %; feed; size; salmon; carbon footprint; times
# New Coursera Deep Learning Courses; topics; networks; optimization; ML; projects; networks; sequence
# BinaryAlert; Serverless; real-time; malware detection
# Airbnb Engineering; blog; Continue; links
#
# Four short links: 9 August 2017
# -------------------------------
# Trend Detection; Separation; Duties; Online Communities; Tractors; Event Trend Detection; High-Rate Event Streams; Event; Processing; CEP; technology; applications; fraud detection; health care
# CEP; systems; streams; events; event; queries; event; sequences; check; kites; heart rate; trends
# event; sequences
# Paper; Day; Separation; Duties
# Case; Studies; Building Online Communities
# John Deere; Autonomy Lessons; order; tractor
# blend; GPS; location; sensors; image; sensors; telematics; John Deere; vehicles; fields; today; company; everything
# company; ’; s; machine; features; S700; combine; vehicle; grain; equipment; condition; crop; farmer; tractor; camera
# John Deere ’; s; tractors; sign; autonomy; road
# Continue; links
#
# Deep learning revolutionizes conversational AI
# ----------------------------------------------
# AI; transform speech; dream; speech recognition; system; humans; environments; variety; accents
# decades; people; problem
#
# years; breakthroughs; AI; learning; everything; quest
# learning; techniques
# Today; forward; development manifesting; range; products; Amazon Echo
# post; review; advances; recognition; elements; progress; futureand
# background; years; tasks; AI
# People; machines; actions
# goal; essence
# Conversational AI; categories; interface
# interface; machine; voice; text; machine; human; manner; kind
# Figure; machine; assistant; SIRI; Alexa; kind
#
#
#
# interaction; AI; bridge; humans; conversations; insights
# example; AI; conference; calls; summary; call
#
#
#
# Machine perception; cognition; order; challenges; technologies; AI; concepts; AI; machine perception
# Machine perception; ability; machine; data; manner; way; humans; senses; world; words; machine
# lot; AI; algorithms; computer; cameras; detection; recognition; fall; category; machine perception—they concern; sense
# Speech; recognition; profiling; machine perception; technologies; sense
# Machine cognition; top; metadata
# Machine cognition; decision-making; systems; action taking
# machine cognition; ’; t; impact; outcome; AI ’; perception; machine perception; metadata information; decision
# AI; machine perception; speech analysis; technologies; recognition; profiling; machine cognition; language; technologies; part; Natural Language Processing
# evolution; speech recognition; research; development; speech recognition; time; periods; Active; research; speech recognition; place; decades; fact; attempts; recognition
# advent; learning; data; cloud computing; solutions; mass; adoptions
# algorithms; data; algorithms; lack; high-performance computing; researchers
# –; effect; learning; group; researchers; Microsoft; Li Deng; Dong Yu; Alex Acero; Geoffrey Hinton; student; George Dahl; speech recognition system
# impact; %; reduction
# system; point; developments; improvements
# data; cloud computing; adoption; companies; Apple; SIRI; Amazon; Alexa; Google; improvements; performance; products
# – Today; end; networks
# attention; models; memory; networks; techniques; era; wave
# Today; type; algorithm; solution; type; model; fact; research; speech
# advances; models; speech; years; speech recognition; breakthroughs
#
# order; impact; learning; part; recognition
# speech recognition; research; years; machines; speech; problems
#
# Speech; recognition; tasks; kind; speech; speech
# speech; part; signal; work; speech; noise; parts
# building; blocks; speech recognition system; Speech; recognition; sections; level; aim; level; speech; signal; pre-processing; cleaning
# level; machine; task; words; data; data; pre-processing
# level; aim; level; features
# way; criteria; sub-sounds
# language level; sounds; meaning; sounds; words; words
# techniques; language; levels; types; NLP
# Improvements; Deep; learning; impact; field
# impact; today; solution; field; recognition
# evaluation; recognition; systems; industry standard; Switchboard
# SWBD; corpus; speech; conversations
#
# evaluation; speech recognition system; word error rate
# refers; words
# Figure; improvement; WER
#
#
#
# WER; state; %; learning; result; WER; %
# development; game changer; speech recognition; %
# range; applications; Apple SIRI; Amazon Alexa; Microsoft Cortana
# variety; appliances; speech recognition; Amazon Echo
# sauce; So
# technique; WER; %
# ’; t
# Deep; learning; speech recognition; system; variety; techniques
# level; instance; techniques; speech; signal
# techniques; feature extraction; methods
#
#
#
# language; levels; variety; learning; techniques; state classification; types; architectures; language; models; language level
#
#
#
# system; task; techniques
# edge research; breakthroughs
# areas; focus; research; future; algorithms; data
# Algorithms; success; Amazon Echo; Google Home; companies; speakers; home; devices
# devices; problem; user; microphone; phone
# speech; problem; lot
# Today; learning; processing; techniques; quality
# topics; research today; topologies
# results; language; models
# examples; Grid-LSTM; models; memory; networks; language
# Data; issues; speech recognition system; lack
# example; data
# lot; data
# question; synthesizers; data
# data; systems
# order; speech recognition system; data sets
# transcription; work; problems; amounts
# result; research; training; building proper confidence measure
# Scalability; learning; recognition; amount; CPU
# users; adoption; recognition; systems; cloud solution; challenging
# research; computation cost
# Today; recognition; systems; issues; latency
# Latency; issue; devices; response
# system; time; connectivity; problem
# result; research; edge speech recognition; quality
# problems; speech recognition; years; quantum leap; recognition performance
#
#
# answer; probably—but; problems
# problem; issue
# speech recognition system; microphone; environment; speech; data
# problem; language expansion; languages; world; recognition
#
# addition; data; languages; speech recognition system
# Conclusion Deep; learning; mark; speech recognition
# breakthroughs; edge
# question; triumph; challenges; speech recognition
#
# advances; recognition; piece; puzzle; language
# Continue; Deep; learning
#
# Cancer detection, one slice at a time
# -------------------------------------
# New; technology; researchers; digitization
# Ke Cheng ’; story; begins; way
# nights; hours; student; task; name
# Ke; company
# world; ’; online; pathology database; detection
# ’; step back—how; Ke; grad student; fountain
# task; tissue; slides; histopathology; analysis; tissue; changes
# process; tissue sample; block
# microtome; tissue; slices; microscopy; microns
# slice; microscope slide
# stain; H; E; mixture; dye; hematoxylin; eosin; pink
# alone; disease; researchers; organization; disorganization
# hundreds; “; stains; tissue; elements; e.g.; muscle; fibers; glycoproteins; mucins; fungi; bacilli; ions; iron
# Immunohistochemistry; IHC; tissue
# detection; cancer
# H; E; staining; stains; IHC
#
# time; Ke ’; s graduate work; weeks
# step; Ke ’; company; pathology; data; powerhouse
# Ke; HistoWiz; years; instruments; histopathology
# slide histology wasn; ’; vision
# Ke; source; research model; databases; everyone; access
# firsthand; trove; histopathology; data; slide; boxes; cabinets
# literature; images; sections; slide; course; results; fraction
# Ke; HistoWz; customer base; turnaround; industry standard
# days; door; research; buildings; people
# nights; samples
# years; HistoWiz; number; research; institutions; Harvard; MD Anderson; HHMI; pharma; Pfizer; Regeneron
# difference; HistoWiz; histology; competitors; Ke
# order; customer; high-res; image; slide; magnification; laptop; smartphone; tablet
# customer; image; slide; HistoWiz ’
# histology; service; HistoWiz; pipeline
# customer; discount; data; slide; HistoWiz
#
# H; E; slide; murine lung cancer; HistoWiz ’
#
# HistoWiz ’; PathologyMap; slides; rate; percent
# data; mouse tissue; PathologyMap; models; rats
#
# Ke ’; mission; cancer cooperatively.; boxes; representative images—this database; researchers; data; mining; slides
# data; pathologists
# door; anyone; histology field; access; discoveries
#
# era; pathology.; FDA; pathology; diagnosis; data
# Ke ’; database; data
# Ke; potential; researchers; HistoWiz; database
# slides; contributors; vision; researchers; slide; tools
# tissue; banks; resources
#
# Ke ’; s team; process; machine; algorithm; diagnosis; prognosis
# goal; histology; patient; type; therapy
# approach; methods; sequencing
#
# team; Stanford; genetics; informatics; algorithm; cell lung cancer prognosis; H; E; slides; Snyder
# HistoWiz; number; pathologists; staff; “; ”; tumor; types; tumor
#
# annotation tool; development; data
# Different; users; levels; tags; in-house; pathologists; slide owner
# data; machine
# Ke; doesn; ’; t; machine learning; place; pathologists; diagnosis; time; value; prognosis
# cancer detection; anyone; morning; Ke; inspiration; end goal; beauty
# company; Twitter “; images; day; ”; themes
# d; Ke; HistoWiz
#
# Clover; pattern; St. Patrick ’; Day; Right; heart; Valentine ’
#
# Continue; Cancer; detection; slice
#
# Integrating data with AI
# ------------------------
# Tamr ’; Eliot Knudsen; algorithms; work; experts.As; companies; idea; management; stores; data; troves; data; parts; company
# data sets; essence; re; schemas
# podcast episode; Eliot Knudsen; data; science lead; Tamr; company; AI; data
# Data; integration; painstaking; process; fields; entities; tools; experts; patterns; data
# participation; humans
# Knudsen; points; Andrew Ng ’; assessment; person; task; seconds; thought; AI; ” AI-driven; products; judgments; limitations; humans
# Knudsen; Gmail; feature; example; service; spam filter; degree; accuracy; model; Gmail ’
# years; Gmail; feature; flag
# Knudsen; fact; feature; flag; filter
# “; surface; idea; email; versus; versus
# “; someone; email; attention; s; something; least; me—takes
#
# intelligence; term; email; degree; accuracy.; ” So; Knudsen; Google ’; response; challenge; flag; recommendation; spam filter; notification
# way; process; data; integration; expertise; business; managers—who; insight; ways
# AI-driven; tools; managers; leverage; time; humans; integration; Knudsen; approach. ”; post; collaboration; O ’ Reilly
#
# Continue; Integrating; data
#
# Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering
# ----------------------------------------------------------------------------------------------
# Jupyter; education; Jupyter-in-the-loop; reproducibility; Barba; professor; engineering
# JupyterCon; August
# Barba; shares; thoughts; state
#
#
# research group; focus; fluid; dynamics; physics; range; activities; education
#
# topic—like; method; equations; fluid dynamics—the exploration
# student; results; simulations; discussion
# materials; students; notebooks
# form; course; others; tutorial; others; learning process
#
# Jupyter; way; team
#
# web; version control; GitHub; example; conversations
# process; ideas
#
#
#
# everyone; arrival
#
# Adoption; data
# Users; joy; data files
# realm; ecosystem—with; tools
# people; tools; future; employers; source
#
#
# talk; Design
# years; debates; reproducibility
# concerns; sharing; code; data
#
# Jupyter; solution
# means; practice; Knuth ’; idea; programming; code
# contradiction; tools; pioneers; research; antithesis
#
# ...
# --------------------------------------------
# O ’ Reilly Design Podcast; Designing; “; minds; importance; future; AI.In; week; ’; s; Design Podcast; John Whalen; experience officer; Pearls; development company; mobile; web apps; enterprise; solutions; security; data; IoT; cloud
# “; minds; experience; designers; brain science; people; voice assistant.Continue; John Whalen; brain science
#
# When you hear hooves, think horse, not zebra
# --------------------------------------------
#
# Focus; security foundation; month; discussion; physician
# zebras; context; data; mining; strategies; diagnosis
# things; physicians; phrase “; horse; principle; odds; patient
# example; family member; female patient; presents; history; headache; fatigue
# exam; fevers; symptom; note
# zebra; brain tumor—and; practitioner; order; thousands; dollars; tests; patient
# blood count; horse—and
# rule; horse; zebras.Continue; hooves; horse
#
# Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks
# ----------------------------------------------------------------------------------------------------
# instructions; net; Jupyter Notebook.Although; learning; frameworks; TensorFlow; Keras; Torch; Caffe; Apache MXNet; popularity; scalability
# blog post; computer vision problem; traffic; signs
# network; color photo; traffic sign image; input; tries; type
# notebook; order; notebook; understanding; network; convolution; activation; units; descent; NumPy
#
# end; notebook; data set; network; Generate; data; data set; custom; network architecture
# environment; AWS Cloud; installation management; Amazon Machine Image; AMI
#
# Note; conda environment; conda; pip
# step; lot; problems
# First; Anaconda
# Python; libraries
# OpenCV-python; library
#
# OpenCV; Anaconda; environment
#
#
#
#
#
# Jupyter Notebook; 'conda
# MXNet; source
# commands; anaconda environment; activation; environment; conda install pip; conda; conda install jupyter notebook pip install; data set; order; network
# notebook; data set; NumPy
#
#
# data set; Traffic Sign Recognition Benchmark; J. Stallkamp; M. Schlipsing; J. Salmen
#
# Proceedings; IEEE International Joint Conference
#
# data set; training; samples; testing; samples; traffic signs—stop; signs; speed; limits; warning
# version; data; training.p
# image; dataset; size; channel; RGB; color
#
# 'signnames.csv; file; mapping; sign name; class
# code; data; import pickle; TODO; Fill; training; data; training_file; validation_file; mode='rb; f; train = pickle.load; f; mode='rb; f; = pickle.load; f; X_train; y_train = train; 'features; ]; 'labels; ]; X_valid; =; [; 'features; ]; [; 'labels; ]; data; NumPy
# array; data; training; validation; test
# training set; features; images; size; R; G; B
# result; NumPy; array dimension; X
# training set; validation
# images; internet
# X_train; dimension; *
# y_train; dimesion; number
# file; image class; ID; names; name; classes
# csv file; mapping; classes/labels; file name import csv def read_csv_and_parse; traffic_labels_dict =; 'signnames.csv; f; reader = csv.reader; f; count; = -1; row; reader; count; =; count; count; continue label_index; =; int; ]; traffic_labels_dict; [; label_index; ] =; row; return traffic_labels_dict traffic_labels_dict; =; read_csv_and_parse; print; traffic_labels_dict; labels; image
# example; image class; km/h; limit; limit; limit; limit; limit; limit; limit; 'End; speed limit; limit; limit; vehicles; tons; 'Right-of-way; intersection; 'Priority road; 'Yield; 'Stop; vehicles; 'Vehicles; tons; entry; caution; curve; left; curve; right; curve; road; road; 'Road; right; 'Road work; signals; 'Pedestrians; 'Bicycles; 'Beware; ice/snow; animals; 'End; speed; limits; 'Turn; 'Turn; right; left; mandatory; passing; passing; vehicles; tons; Visualization; code; images; labels; image; classes; Exploratory; data; visualization; understanding; data; import matplotlib.pyplot; plt; matplotlib.figure import; Figure; Visualizations
# %; functions; image; class; def get_images_to_plot; images; labels; selected_image; [ ]; idx; = [ ]; i; range; n_classes; =; ==; i; ]; selected_image.append; images; ]; idx.append; return selected_image; function; images; def; plot_images; selected_image; y_val; row=5; col=10; =; None; count =0; plt.subplots; row; col; figsize=; i; range; row; j; range; col; count; <; len; selected_image; [ i; j; ] .imshow; selected_image [ count; ]; idx; =; None; [ i; j; ] .set_title; [; y_val; [; idx; [; count; ] ] ]; fontsize=20; [ i; j; ] .axis; 'off; count; =; count; selected_image; = get_images_to_plot; X_train; y_train; plot_images; selected_image; row=10; col=4; idx=idx; y_val=y_train; traffic; signs; labels; data set X_train; Y_train; training; data
#
# validation; training; data; train; validation; sets; scikit-learn; model
# Python; code; train-set; validation; test set; sklearn.model_selection import train_test_split; X_train_set; X_validation_set; Y_train_set; Y_validation_set =; train_test_split; X_train; Y_train; test_size=0.02; random_state=42; image dimension order; MXNet
# number; channels; dimension; height; width
# uses; image dimension
# TensorFlow; discussion
# Below; function; image; MXNet; format; image; X; train X_train_reshape; =; plt.imshow; X_train_reshape; ] .transpose; print; X_train_reshape.shape; image; X; validation; X_valid_reshape =; plt.imshow; X_valid_reshape; ] .transpose; print; X_valid_reshape.shape; deepnet; data
#
# lines; artifacts; development; learning model; iteration
# networks; something; art; point; history; problem; issue; image recognition; architecture
# version; AlexNet; architecture
# code; thanks; MXNet; API; data =; 'data; conv1; mx.sym.Convolution; data=data; pad=; conv1; mx.sym.Activation; data=conv1; act_type=; relu; relu1; mx.sym.Pooling; data=relu1; pool_type=; max; stride=; max_pool1; conv layer conv2; =; mx.sym.Convolution; data=pool1; kernel=; conv2; pad=; mx.sym.Activation; data=conv2; act_type=; relu; relu2; mx.sym.Pooling; data=relu2; pool_type=; max; stride=; max_pool2; mx.sym.Convolution; data=pool2; kernel=; conv3; mx.sym.Activation; data=conv3; act_type=; relu; relu3; mx.sym.Pooling; data=relu3; pool_type=; max; stride=; max_pool3; mx.sym.Convolution; data=conv3; kernel=; conv4; mx.sym.Activation; data=conv4; act_type=; relu; relu4; = mx.sym.Pooling; data=relu4; pool_type=; max; stride=; max_pool4; fullc layer; =; mx.sym.Flatten; data=pool3; fc1 =; fc1; mx.sym.Activation; data=fc1; act_type=; relu; relu3; fullc fc2; =; data=relu3; final_fc; loss mynet; =; mx.sym.SoftmaxOutput; data=fc2; Let; code
# data layer; layer; dataset; training; data =; 'data; conv1 layer; convolution operator; image; data; layer; conv1; mx.sym.Convolution; data=data; pad=; conv1; relu2 layer; activation; input; layer; relu2; mx.sym.Activation; data=conv2; act_type=; relu; relu2; pool layer; pooling operation; pixels; image size; layer; output
# pool2 = mx.sym.Pooling; data=relu2; pool_type=; max; stride=; max_pool2; network; Lego; block—we; layers; capacity; model; —
# dense layer; layer; neuron; layer; neuron
# fc1 =; fc1; layer; layer; neurons; neuron; class
# output; neuron; classification; label; output
# step; output; neuron; neurons; neurons
# fc2 =; data=relu3; final_fc; loss mxnet; =; mx.sym.SoftmaxOutput; data=fc2; data; A; network; lot; time
# data; minibatches; memory; MXNet; GPU; efficiency
# value; image; colors
#
#
# code; value; image color; X_train_set_as_float = X_train_reshape.astype; 'float32; X_train_set_norm =; X_train_set_as_float; [; X_validation_set_as_float = X_valid_reshape.astype; 'float32; X_validation_set_norm =; X_validation_set_as_float; [; train_iter =mx.io.NDArrayIter; X_train_set_as_float; y_train_extra; batch_size; shuffle=True; val_iter; mx.io.NDArrayIter; X_validation_set_as_float; shuffle=True; print; train set; X_train_set_norm.shape; print; validation set; X_validation_set_norm.shape; print; set; y_train.shape; print; validation set; y_valid.shape; network; network
# pass-through; training set; epoch; network
# model; JSON; file; measure; train; validation accuracy
# code; optimiser adam; =; mx.optimizer.create; 'adam; point
# Make; sure; models; =; checkpoint = mx.callback.do_checkpoint; model_prefix; module
# mxnet; feedforward; model; mx.mod.Module; = mx.gpu; use; GPU; training
# symbol; mynet; data_names=; [ 'data; ]; model
# minutes; train_iter; eval_data=val_iter; batch_end_callback = mx.callback.Speedometer; =; eval_metric='acc; evaluation
# optimizer; =; adam; epoch_end_callback=checkpoint; model; filesystem; model; training; epoch
#
# binding; model
# batch size; input; data_shapes=; [; 'data
# technique; machine; model; model; checkpoint; epoch sym; arg_params; aux_params; mx.model.load_checkpoint; model_prefix; parameters; module mod; =; mx.mod.Module; symbol=sym; context=mx.cpu; mod.bind; [; 'data; ]; mod.set_params; aux_params; Prediction; model; prediction; traffic sign image; Stop.jpg; dimension image; channels
#
# Prediction; random traffic sign; internet; collections; Batch =; namedtuple; [ 'data; ]; image; converts; def get_image; download; image img; =cv2.imread; img; =; cv2.cvtColor; cv2.COLOR_BGR2RGB; img; None; return None; show; plt.imshow; img; plt.axis; 'off; convert; format; batch; RGB; width; height; img; cv2.resize; img; np.swapaxes; img; img =; np.swapaxes; img; swaps; plt.imshow; plt.axis; 'off; img; =; img; [; np.newaxis; Add; axis; image; return img def predict; img = get_image; predict; probabilities; mod.forward; Batch; mx.nd.array; img; ]; prob =; mod.get_outputs; ]; .asnumpy; prob = np.squeeze; prob; prob; np.argsort; prob; [; ]; i; prob; ]; print; %; %; [ i; ]; predict; model; predictions; image
# predictions; class=Stop class=Speed limit; class=Speed limit; class=Speed limit; class=Bicycles; Conclusion; notebook; MXNet
# network; simpler; image-recognition; network; architectures
# techniques; image; data; network; network
# network model; images
# model; service
# techniques; data; purpose; classification; sentiment; intent; chats; help desk; intent
# notebook; sentiment classifier
# Continue; Classifying; traffic; signs; Apache MXNet; introduction; computer vision
#
# Four short links: 27 July 2017
# ------------------------------
# Death; Evolution; Trust; Indoor Robots; Embryo Editing Predicting Who; Next; Game; Thrones
# Evolution; Trust; illustration; game theory
# Indoor Robots; overview; companies
# First Human Embryos Edited; USA; MIT TR; Mitalipov; ground; number; embryos; genes
# none; embryos; days—and; intention; experiments; milestone; journey; birth
# Continue; links
#
# R’s tidytext turns messy text into valuable insight
# ---------------------------------------------------
# Authors; Julia Silge; David Robinson; power; tidy; data principles; sentiment; lexicons; Stack Overflow. “ Many; fields; interpretation; language; ”; Julia Silge; Ph.D.; David Robinson; Ph.D.; newly; book; Text Mining; R
# applications; text mining; analysis; content; text; frequency; measurements; document ’; terms; analysis; relationships; connections; words
# Silge; Robinson; text mining; job; postings; Stack Overflow; challenges; practices; ve; text; package; R; aims
# ’; start
#
# insights; instances; words; sentiment
# Text; data; data; analysts; data scientists; fields; health care
# data; decisions; tools; skills; text
# lot; word; frequencies; word usage; sentiment analysis; emotion; opinion content; words; topic model; structure; set
#
# R; user ’
# package; power; tidy; data principles; consistent; approach; data; mining
# Tidy; tools; dplyr; ggplot2; language processing; tools; R; users
# feature; addition; Loughran; McDonald; lexicon; words; reporting; words; “; collaborate ”; collaborators; words; “; ”
# someone; mining; purpose
# ways; lexicon
# Sentiment; lexicons; lists; words; scores; emotions; anticipation ”
# emotion content; text; scores; words; approach
# package; purpose; English; lexicons; text; lexicon
# word; “; share; ”; meaning; contexts; contexts; shares
# Loughran-McDonald; lexicon; sentiment content; documents; finance
# book; analysis; data sets; Jane Austen; novels; NASA; metadata; Twitter
# ways; text; data; work
# text; data
# example; job; postings; mining; modeling; job; listings
# example; messages; companies; developers; mining; developer
# organizations; amounts; text; data
# Text; data; things; abbreviations; “; filler ”; words; words
# challenges practitioners; wrangling; data; data types
# Data; scientists; analysts; data; shape; table; data; frame; practice; text
# expressions; package; lot; challenges; HTML; tags; email; headers; subsets
# tasks; practice; package; tool
# practices; scientists; analysts; text mining
# perspective; question; advice; tidy; data principles; strategy; text mining
# tidy text; token; word; row; document; chapter
# data; set
# data; format; task; lets
# book; mining; R. Which R; tools
# R; tool
# toolbox; text mining; R; focuses; package tidytext; packages; tidyr
# tools; collection; packages; R; availability; cohesion; tools; reasons; R
# tools; tidy; data; framework; text; data; R; characteristics; text; model; topics; machine learning
# difference; text mining
# experience; definitions
# people; text mining; insight; text; analysis; word; frequencies
# people; language processing; re; interaction; language; computers; goal
# work; text mining ”; goal; insights; deal
# Continue; R ’; turns; text
#
# Four short links: 26 July 2017
# ------------------------------
# Blockchain; Securities Law; Low-Energy Sensing; Robotics Deep Learning; Chipped Employees Report; Investigation; DAO; SEC; Report; principles; U.S.; securities laws; applicability; organizations; capital; entities; ledger; blockchain technology; capital; investment; offer; sale
# Wireless Sensor Live; Year; Tiny Coin Cell Battery; choices; software; difference; power consumption; orders; magnitude; –
# Learning; Robotics; Review; Recent Research
# Wisconsin Company Will Let Employees Use Microchip; Snacks; Open Doors; employees; chips; field communication; NFC; technology; thumb
# extension; RFID; chip business; partnership; company
# kiosk company; chip; employees; party
#
#
# Continue; links
#
# Making great hires in your design organization
# ----------------------------------------------
# team; design practice.Continue; Making; hires
#
# A lesson in prescriptive modeling
# ---------------------------------
# Simulate; business; models; practices; source code.Continue; A; lesson
#
# Four short links: 25 July 2017
# ------------------------------
# AI Sentencing; AI Vocabulary; Soft U2F; Encrypted Email; Lid; Criminal Sentencing; Duke; researchers
# CORELS; judges; defendants; algorithm; person
# [; None; research team; ’; s; models; race
# Agents; Imagine; Plan; appropriation; terms; cognition; psychology
#
# future; distinction; software; wetware; Ai; intelligence
# U2F; Authenticators; USB; devices; HID
# HID; device; Soft U2F; browser; extension; websites
# Improves; site security
# magic; numbers; site; Magma; magma server daemon; email system; support; SMTP; POP; IMAP; HTTP
# support; DMTP; DMAP
# Continue; links
#
# Data science startups focus on AI-enabled efficiency
# ----------------------------------------------------
# winners; Strata San Jose Startup Showcase.Every; years; technology; business; problems; panacea
# ‘; Web; SaaS; mobility; clouds; data
#
# Web; SaaS; interfaces
# Mobility; workday—we; phones dozens; times; day; thing; thing
#
# Big; data; clouds
# AI; set; algorithms; sense; data; threads; gold
# example; winners
# field; applicants; panel; list; finalists; combination; judges; audience voting; winners; first-place winner; Nexla; data; easier; product; teams; share; process; transform; monitor
# %; time; data sources; companies
# Second-place; winner; Gluent; rivers; data; organization
# truism; AI; data beats; data; disposal; models; ability; perils
# Third-place; winner; torrent; data; gamers; publisher; brand; player
# E-sports; industry
# gamers; audiences; range
#
# vote winner; Outlier; business information
#
# growth; churn; rash; alerts
# patterns; data; advantages; organization
# companies; link; computing; data
# oughties; user interface—and; process; technology; billions; years; groundwork
# disclosure; Alistair Croll; board member; Repable; voting; selection process; company
# Continue; Data; science; startups

# %% [markdown]
# ## Visualizing interactions between entities with HTML output

# %%
import os
import json
import nltk
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>{0}</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>{1}</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    post.update(extract_interactions(post['content']))

    # Display output as markup with entities presented in bold text

    post['markup'] = []

    for sentence_idx in range(len(post['sentences'])):

        s = post['sentences'][sentence_idx]
        for (term, _) in post['entity_interactions'][sentence_idx]:
            s = s.replace(term, '<strong>{0}</strong>'.format(term))

        post['markup'] += [s] 
            
    filename = post['title'].replace("?", "") + '.entity_interactions.html'
    f = open(os.path.join(filename), 'wb')
    html = HTML_TEMPLATE.format(post['title'] + ' Interactions', ' '.join(post['markup']))
    f.write(html.encode('utf-8'))
    f.close()

    print('Data written to', f.name)
    
    # Display any of these files with an inline frame. This displays the
    # last file processed by using the last value of f.name...
    
    print('Displaying {0}:'.format(f.name))
    display(IFrame('files/{0}'.format(f.name), '100%', '600px'))
# Out:
# Data written to Four short links: 21 August 2017.entity_interactions.html
# Displaying Four short links: 21 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 21 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to 6 practical guidelines for implementing conversational AI.entity_interactions.html
# Displaying 6 practical guidelines for implementing conversational AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/6 practical guidelines for implementing conversational AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 18 August 2017.entity_interactions.html
# Displaying Four short links: 18 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 18 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How Ray makes continuous learning accessible and easy to scale.entity_interactions.html
# Displaying How Ray makes continuous learning accessible and easy to scale.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How Ray makes continuous learning accessible and easy to scale.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Julie Stanford on vetting designs through rapid experimentation.entity_interactions.html
# Displaying Julie Stanford on vetting designs through rapid experimentation.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Julie Stanford on vetting designs through rapid experimentation.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Jack Daniel on building community and historical context in InfoSec.entity_interactions.html
# Displaying Jack Daniel on building community and historical context in InfoSec.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Jack Daniel on building community and historical context in InfoSec.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 17 August 2017.entity_interactions.html
# Displaying Four short links: 17 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 17 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Contouring learning rate to optimize neural nets.entity_interactions.html
# Displaying Contouring learning rate to optimize neural nets.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Contouring learning rate to optimize neural nets.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Creating better disaster recovery plans.entity_interactions.html
# Displaying Creating better disaster recovery plans.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Creating better disaster recovery plans.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Announcing the Rebecca Bace Pioneer Award for Defensive Security.entity_interactions.html
# Displaying Announcing the Rebecca Bace Pioneer Award for Defensive Security.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Announcing the Rebecca Bace Pioneer Award for Defensive Security.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How synthetic biology startups are building the future at RebelBio.entity_interactions.html
# Displaying How synthetic biology startups are building the future at RebelBio.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How synthetic biology startups are building the future at RebelBio.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to The impact of design at Shopify.entity_interactions.html
# Displaying The impact of design at Shopify.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/The impact of design at Shopify.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Take the 2018 Data Science Salary Survey.entity_interactions.html
# Displaying Take the 2018 Data Science Salary Survey.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Take the 2018 Data Science Salary Survey.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 16 August 2017.entity_interactions.html
# Displaying Four short links: 16 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 16 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 15 August 2017.entity_interactions.html
# Displaying Four short links: 15 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 15 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How to use Presto Sketching to clarify your team’s purpose.entity_interactions.html
# Displaying How to use Presto Sketching to clarify your team’s purpose.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How to use Presto Sketching to clarify your team’s purpose.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 14 August 2017.entity_interactions.html
# Displaying Four short links: 14 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 14 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to A multi-cloud strategy is the foundation for digital transformation.entity_interactions.html
# Displaying A multi-cloud strategy is the foundation for digital transformation.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/A multi-cloud strategy is the foundation for digital transformation.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How to choose a cloud provider.entity_interactions.html
# Displaying How to choose a cloud provider.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How to choose a cloud provider.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 11 August 2017.entity_interactions.html
# Displaying Four short links: 11 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 11 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Mike Roberts on serverless architectures.entity_interactions.html
# Displaying Mike Roberts on serverless architectures.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Mike Roberts on serverless architectures.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How to craft a voice user interface that won’t leave you frustrated.entity_interactions.html
# Displaying How to craft a voice user interface that won’t leave you frustrated.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How to craft a voice user interface that won’t leave you frustrated.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 10 August 2017.entity_interactions.html
# Displaying Four short links: 10 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 10 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 9 August 2017.entity_interactions.html
# Displaying Four short links: 9 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 9 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Deep learning revolutionizes conversational AI.entity_interactions.html
# Displaying Deep learning revolutionizes conversational AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Deep learning revolutionizes conversational AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Cancer detection, one slice at a time.entity_interactions.html
# Displaying Cancer detection, one slice at a time.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Cancer detection, one slice at a time.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Integrating data with AI.entity_interactions.html
# Displaying Integrating data with AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Integrating data with AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering.entity_interactions.html
# Displaying Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 8 August 2017.entity_interactions.html
# Displaying Four short links: 8 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 8 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Why continuous learning is key to AI.entity_interactions.html
# Displaying Why continuous learning is key to AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Why continuous learning is key to AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 7 August 2017.entity_interactions.html
# Displaying Four short links: 7 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 7 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How to move your team closer to clarity.entity_interactions.html
# Displaying How to move your team closer to clarity.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How to move your team closer to clarity.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 4 August 2017.entity_interactions.html
# Displaying Four short links: 4 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 4 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to JupyterHub on Google Cloud.entity_interactions.html
# Displaying JupyterHub on Google Cloud.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/JupyterHub on Google Cloud.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Why AI and machine learning researchers are beginning to embrace PyTorch.entity_interactions.html
# Displaying Why AI and machine learning researchers are beginning to embrace PyTorch.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Why AI and machine learning researchers are beginning to embrace PyTorch.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to A DevOps approach to data management.entity_interactions.html
# Displaying A DevOps approach to data management.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/A DevOps approach to data management.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 3 August 2017.entity_interactions.html
# Displaying Four short links: 3 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 3 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Declaring variables in Kotlin.entity_interactions.html
# Displaying Declaring variables in Kotlin.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Declaring variables in Kotlin.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Building—and scaling—a reliable distributed architecture.entity_interactions.html
# Displaying Building—and scaling—a reliable distributed architecture.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Building—and scaling—a reliable distributed architecture.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Operationalizing security risk.entity_interactions.html
# Displaying Operationalizing security risk.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Operationalizing security risk.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Reinforcement learning for complex goals, using TensorFlow.entity_interactions.html
# Displaying Reinforcement learning for complex goals, using TensorFlow.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Reinforcement learning for complex goals, using TensorFlow.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Jay Jacobs on data analytics and security.entity_interactions.html
# Displaying Jay Jacobs on data analytics and security.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Jay Jacobs on data analytics and security.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 2 August 2017.entity_interactions.html
# Displaying Four short links: 2 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 2 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to The wisdom hierarchy: From signals to artificial intelligence and beyond.entity_interactions.html
# Displaying The wisdom hierarchy: From signals to artificial intelligence and beyond.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/The wisdom hierarchy: From signals to artificial intelligence and beyond.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 1 August 2017.entity_interactions.html
# Displaying Four short links: 1 August 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 1 August 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks.entity_interactions.html
# Displaying How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to From prototype to product with hybrid neural networks.entity_interactions.html
# Displaying From prototype to product with hybrid neural networks.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/From prototype to product with hybrid neural networks.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 31 July 2017.entity_interactions.html
# Displaying Four short links: 31 July 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 31 July 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 28 July 2017.entity_interactions.html
# Displaying Four short links: 28 July 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 28 July 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Eric Freeman and Elisabeth Robson on design patterns.entity_interactions.html
# Displaying Eric Freeman and Elisabeth Robson on design patterns.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Eric Freeman and Elisabeth Robson on design patterns.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to John Whalen on using brain science in design.entity_interactions.html
# Displaying John Whalen on using brain science in design.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/John Whalen on using brain science in design.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to When you hear hooves, think horse, not zebra.entity_interactions.html
# Displaying When you hear hooves, think horse, not zebra.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/When you hear hooves, think horse, not zebra.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks.entity_interactions.html
# Displaying Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 27 July 2017.entity_interactions.html
# Displaying Four short links: 27 July 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 27 July 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to R’s tidytext turns messy text into valuable insight.entity_interactions.html
# Displaying R’s tidytext turns messy text into valuable insight.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/R’s tidytext turns messy text into valuable insight.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 26 July 2017.entity_interactions.html
# Displaying Four short links: 26 July 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 26 July 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Making great hires in your design organization.entity_interactions.html
# Displaying Making great hires in your design organization.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Making great hires in your design organization.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to A lesson in prescriptive modeling.entity_interactions.html
# Displaying A lesson in prescriptive modeling.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/A lesson in prescriptive modeling.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 25 July 2017.entity_interactions.html
# Displaying Four short links: 25 July 2017.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 25 July 2017.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Data science startups focus on AI-enabled efficiency.entity_interactions.html
# Displaying Data science startups focus on AI-enabled efficiency.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Data science startups focus on AI-enabled efficiency.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
